# %% [markdown]
# # Global constants

# %%
GRAIN_TYPE = 'Wheat'
#GRAIN_TYPE = 'newWheatData'
#GRAIN_TYPE = 'CornAdded_Type'
#GRAIN_TYPE = 'cleaned_data'
# GRAIN_TYPE = 'Oats'

# GRAIN_TYPE = 'Barley'
# GRAIN_TYPE = 'Sorghum'
# GRAIN_TYPE = 'Soybeans'
# GRAIN_TYPE = 'Corn'

FILENAME_BEST_MODEL = 'Best models/target_2/hybrid_models/' + GRAIN_TYPE + '_t2_kcv_dnn_mc.h5'

# %%
#Import libraries
import requests
import pandas as pd


#Data visualization
import seaborn as sn
import matplotlib.pyplot as plt
import random
#Data Manipulation
import pandas as pd
import numpy as np

# Machine Learning
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, Activation, BatchNormalization
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split, KFold
np.random.seed(39)
random.seed(39)
tf.random.set_seed(39)
print(tf.__version__)
# Out:
# 2.4.1

# %%
print(tf.config.list_physical_devices('GPU'))
# print(tf.version.VERSION)
# Out:
# []

# %% [markdown]
# ## Helper functions

# %%
def calculate_r_squared(y_true, y_pred):
   corr_matrix = np.corrcoef(y_true, y_pred)
   corr = corr_matrix[0,1]
   R_sq = corr**2
   return R_sq

def plot_loss_curve(history, epoch_size):
    loss_train = history.history['loss']
    loss_val = history.history['val_loss']
    epochs = range(0,epoch_size)
    
    plt.plot(epochs, loss_train, 'g', label='Training loss')
    plt.plot(epochs, loss_val, 'b', label='Validation loss')
    
    plt.title('Training and Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    
    plt.legend()
    plt.show()

def plot_line(metric, title, xlabel):
    plt.figure(figsize=(8,3))
    plt.title(title, fontsize = 16)
    plt.plot(metric)
    plt.xlabel(xlabel, fontsize = 14)
    plt.grid()
    plt.legend(loc= "best")
    plt.show()

def scatter_plot(trueValues, predictions, title):
  plt.figure(figsize=(8,3))
  ax = plt.axes()
  maxVal = max( max(trueValues), max(predictions) )

  ax.scatter(x=predictions, y=trueValues)
  ax.plot([0, 1, maxVal], [0, 1, maxVal], label="Ideal fit")
  print('Maxval here is: ', maxVal)
  plt.title(title, fontsize = 16)
  plt.xlabel("Predictions", fontsize = 14)
  plt.ylabel("Real", fontsize = 14)
  plt.grid()

# %%
#url dataset
URL = "../Datasets/processed/" + GRAIN_TYPE + ".csv"

#read in excel format
df = pd.read_csv(URL)
#df = df[df['Variety'] == 'SOUTH DAKOTA']
#df = df[(df['Density'] >= 0.72) & (df['Density'] <= 0.88)]

print("From USDA: ", URL)


df.head()
# Out:
# From USDA:  ../Datasets/processed/Wheat.csv
#    Unnamed: 0 Variety  Freq  d(cm)    M%  Density     Attn    Phase  \
# 0           0  KANSAS   7.0    8.9  11.3   0.7356   8.8258  -55.973
# 1           1  KANSAS   8.0    8.9  11.3   0.7356  10.2572 -114.289
# 2           2  KANSAS   9.0    8.9  11.3   0.7356  11.5679 -168.171
# 3           3  KANSAS  10.0    8.9  11.3   0.7356  12.8795  134.849
# 4           4  KANSAS  11.0    8.9  11.3   0.7356  13.7649   83.502
#
#    Phase_Corr  Permittivity_real  Permittivity_imaginary
# 0    -415.973              2.416                   0.243
# 1    -474.289              2.412                   0.246
# 2    -528.171              2.395                   0.246
# 3    -585.151              2.390                   0.246
# 4    -636.498              2.371                   0.238

# %% [markdown]
# # 2. Overview of data

# %%
# Data summary
df.describe()
# Out:
#        Unnamed: 0        Freq       d(cm)          M%     Density        Attn  \
# count  806.000000  806.000000  806.000000  806.000000  806.000000  806.000000
# mean   402.500000   10.811414    7.088834   16.189541    0.796298   18.410033
# std    232.816451    3.530055    1.554604    3.794772    0.067384    5.946835
# min      0.000000    5.000000    4.400000   10.260000    0.625400    8.002300
# 25%    201.250000    8.000000    6.500000   13.680000    0.745400   13.524700
# 50%    402.500000   11.000000    7.700000   16.225000    0.801300   18.131600
# 75%    603.750000   13.000000    7.700000   18.810000    0.842000   23.098000
# max    805.000000   18.000000    8.900000   24.410000    0.927800   29.897000
#
#             Phase   Phase_Corr  Permittivity_real  Permittivity_imaginary
# count  806.000000   806.000000         806.000000              806.000000
# mean    -4.604663  -633.488065           2.912112                0.499187
# std    101.951444   219.510760           0.305758                0.186739
# min   -179.335000 -1274.435000           2.340000                0.220000
# 25%    -88.842000  -793.405750           2.688500                0.337000
# 50%     -9.838500  -602.380500           2.861500                0.470500
# 75%     80.957250  -456.055750           3.109750                0.639000
# max    179.048000  -235.044000           4.038000                0.987000

# %%
# Dimension of the dataset
df.shape
# Out:
# (806, 11)

# %%
# Check info about missing values in dataframe
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Variety                   0
# Freq                      0
# d(cm)                     0
# M%                        0
# Density                   0
# Attn                      0
# Phase                     0
# Phase_Corr                0
# Permittivity_real         0
# Permittivity_imaginary    0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Data preparation
#
#
# 1.   Convert dataframe to numpy array for flexibility.
# 2. Split our data into training and testing datasets and store the target values in different variables.
# 3.   Normalize the features by applying some operations in the data sets.

# %%
# Convert to numpy array
df_features = df[['Freq', 
                    'd(cm)', 
                   # 'Attn', 
                    'Phase_Corr', 
                    'Permittivity_real', 
                    'Permittivity_imaginary',
                    ]]

df_targets = df[['M%']]
# df_targets = df[['Density', 'M%']]

dataset_x = df_features.to_numpy()
dataset_y = df_targets.to_numpy()

# %% [markdown]
# ## Splitting dataset to test and train+validate

# %%
from sklearn.preprocessing import MinMaxScaler

#Normalizing the data set
scaler_input = MinMaxScaler()
scaler_output = MinMaxScaler()

# Normalize the entire dataset (input features)
dataset_x_norm = scaler_input.fit_transform(dataset_x)  # Use transform, NOT fit_transform

# Normalize the entire dataset (output targets)
dataset_y_norm = scaler_output.fit_transform(dataset_y)  # Use transform, NOT fit_transform

# %% [markdown]
# ## Normalize datasets

# %%
# Perform train-test split on RAW DATA
X_train, X_test, y_train, y_test = train_test_split(dataset_x_norm, dataset_y_norm, 
                                                    test_size=0.20
                                                   # ,random_state=42
                                                    )

# %% [markdown]
# # K-cross Validation
# * Input features: 7
# * Output targets: 2

# %% [markdown]
# ## Defining model

# %%
from keras import layers, Sequential, regularizers

# Define the model-building function
def my_model():
  my_model = Sequential([
    
    layers.Dense(256, input_shape=(5,), activation='relu',),
    layers.Dense(256, activation='relu', ),
    layers.Dense(256, activation='relu',),
    layers.Dense(256, activation='relu',),

    layers.Dense(1, activation='linear')  # Output layer with 2 neurons for the two regression targets
  ])

  opt = tf.keras.optimizers.Adam(learning_rate=0.00091) # 0.0006 
  my_model.compile(
      optimizer = opt,
      loss = 'mse',
      metrics = ['accuracy']
  )

  return my_model

plot_model(my_model(), show_shapes=True, show_layer_names=True)
my_model().summary()
# Out:
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_173 (Dense)            (None, 256)               1536
# _________________________________________________________________
# dense_174 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_175 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_176 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_177 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 199,169
# Trainable params: 199,169
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Running model with KCV

# %%
from sklearn.model_selection import KFold
import numpy as np
from tensorflow.keras.callbacks import Callback
class MaxAbsErrorCallback(Callback):
    def __init__(self):  
        self.max_abs_errors = np.zeros((K_FOLD_SPLITS, NUM_EPOCHS))  # Initialize array

    def on_epoch_end(self, epoch, logs={}):
        y_pred = self.model.predict(X_test) 
        y_pred = scaler_output.inverse_transform(y_pred) 
        y_true = scaler_output.inverse_transform(y_test) 

        abs_errors = np.abs(y_true[:, 0] - y_pred[:, 0])
        max_abs_error = np.max(abs_errors)

        # Store errors in the pre-allocated Array
        fold_index = cv.get_n_splits() - 1  # Get the current fold index
        self.max_abs_errors[fold_index, epoch] = max_abs_error 
        print(f"Epoch {epoch + 1}: Max Absolute Error = {max_abs_error:.4f}") 

    def on_train_end(self, logs={}):  
        epoch_averages = np.mean(self.max_abs_errors, axis=0)  # Average across folds
        print(min(epoch_averages))
        for epoch_idx, avg_error in enumerate(epoch_averages):
            print(f"Epoch {epoch_idx + 1} Average Max Abs Error: {avg_error:.4f}")

NUM_EPOCHS = 520# 180
BATCH_SIZE = 10
K_FOLD_SPLITS = 10


# Define the cross-validation process to be used inside cross_val_Score evaluation
cv = KFold(n_splits=K_FOLD_SPLITS)

# Handling for accommodating multiple targets
Y = y_train[:,0]

X = X_train

i = 0
arr_loss = list()
min_loss = 1000000
best_model = None
history = None
history_best_model = None


# Perform k-fold cross-validation
for train_indices, test_indices in cv.split(X_train):
  print('####################### Iteration  ', i, ' #######################')
  trainX, testX = np.array(X[train_indices]), np.array(X[test_indices])
  trainY = (Y[train_indices])
  testY = (Y[test_indices])

  model = my_model()
  history = model.fit(trainX, trainY,
            epochs=NUM_EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data = (testX, testY),
            callbacks=[MaxAbsErrorCallback()]  # Add the callback
  )


  #testing on validation set process
  loss, rmse = model.evaluate(x = testX, y = testY, verbose=1)
  
  print(f"Loss = {loss}, rmse = {rmse}" )

  if loss < min_loss:
    best_model = model
    history_best_model = history
    min_loss = loss

  arr_loss.append(loss)
  print('Loss array: ', arr_loss)
  i+=1

# Saving the best model within the k folds
best_model.save('Best models/target_2/single_models/density_kfold_dnn_single')
# Out:
# ####################### Iteration   0  #######################
# Epoch 1/520
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0598 - accuracy: 0.0916 - val_loss: 0.0052 - val_accuracy: 0.0769
# Epoch 1: Max Absolute Error = 4.2642
# Epoch 2/520
# 58/58 [==============================] - 0s 893us/step - loss: 0.0069 - accuracy: 0.0985 - val_loss: 0.0031 - val_accuracy: 0.0769
# Epoch 2: Max Absolute Error = 3.1941
# Epoch 3/520
# 58/58 [==============================] - 0s 868us/step - loss: 0.0047 - accuracy: 0.0897 - val_loss: 0.0030 - val_accuracy: 0.0769
# Epoch 3: Max Absolute Error = 3.1673
# Epoch 4/520
# 58/58 [==============================] - 0s 920us/step - loss: 0.0041 - accuracy: 0.0797 - val_loss: 0.0027 - val_accuracy: 0.0769
# Epoch 4: Max Absolute Error = 3.7073
# Epoch 5/520
# 58/58 [==============================] - 0s 878us/step - loss: 0.0044 - accuracy: 0.0847 - val_loss: 0.0043 - val_accuracy: 0.0769
# Epoch 5: Max Absolute Error = 2.3750
# Epoch 6/520
# 58/58 [==============================] - 0s 903us/step - loss: 0.0033 - accuracy: 0.0718 - val_loss: 0.0030 - val_accuracy: 0.0769
# Epoch 6: Max Absolute Error = 3.3426
# Epoch 7/520
# 58/58 [==============================] - 0s 866us/step - loss: 0.0038 - accuracy: 0.0900 - val_loss: 0.0025 - val_accuracy: 0.0769
# Epoch 7: Max Absolute Error = 2.7742
# Epoch 8/520
# 58/58 [==============================] - 0s 894us/step - loss: 0.0035 - accuracy: 0.0898 - val_loss: 0.0027 - val_accuracy: 0.0769
# Epoch 8: Max Absolute Error = 3.0585
# Epoch 9/520
# 58/58 [==============================] - 0s 896us/step - loss: 0.0031 - accuracy: 0.0724 - val_loss: 0.0030 - val_accuracy: 0.0769
# Epoch 9: Max Absolute Error = 2.6804
# Epoch 10/520
# 58/58 [==============================] - 0s 971us/step - loss: 0.0038 - accuracy: 0.0965 - val_loss: 0.0033 - val_accuracy: 0.0769
# Epoch 10: Max Absolute Error = 2.4483
# Epoch 11/520
# 58/58 [==============================] - 0s 924us/step - loss: 0.0030 - accuracy: 0.0824 - val_loss: 0.0030 - val_accuracy: 0.0769
# Epoch 11: Max Absolute Error = 2.6268
# Epoch 12/520
# 58/58 [==============================] - 0s 897us/step - loss: 0.0031 - accuracy: 0.0864 - val_loss: 0.0036 - val_accuracy: 0.0769
# Epoch 12: Max Absolute Error = 3.8989
# Epoch 13/520
# 58/58 [==============================] - 0s 945us/step - loss: 0.0039 - accuracy: 0.0880 - val_loss: 0.0055 - val_accuracy: 0.0769
# Epoch 13: Max Absolute Error = 2.5121
# Epoch 14/520
# 58/58 [==============================] - 0s 878us/step - loss: 0.0036 - accuracy: 0.0762 - val_loss: 0.0024 - val_accuracy: 0.0769
# Epoch 14: Max Absolute Error = 2.9187
# Epoch 15/520
# 58/58 [==============================] - 0s 869us/step - loss: 0.0033 - accuracy: 0.0846 - val_loss: 0.0026 - val_accuracy: 0.0769
# Epoch 15: Max Absolute Error = 3.5982
# Epoch 16/520
- val_loss: 0.0014 - val_accuracy: 0.0769
# Epoch 242: Max Absolute Error = 3.3734
# Epoch 243/520
# 58/58 [==============================] - 0s 864us/step - loss: 0.0012 - accuracy: 0.0755 - val_loss: 0.0027 - val_accuracy: 0.0769
# Epoch 243: Max Absolute Error = 4.3265
# Epoch 244/520
# 58/58 [==============================] - 0s 879us/step - loss: 0.0020 - accuracy: 0.0893 - val_loss: 0.0022 - val_accuracy: 0.0769
# Epoch 244: Max Absolute Error = 3.0235
# Epoch 245/520
# 58/58 [==============================] - 0s 848us/step - loss: 0.0015 - accuracy: 0.0791 - val_loss: 0.0017 - val_accuracy: 0.0769
# Epoch 245: Max Absolute Error = 4.0522
# Epoch 246/520
# 58/58 [==============================] - 0s 878us/step - loss: 0.0029 - accuracy: 0.0847 - val_loss: 0.0010 - val_accuracy: 0.0769
# Epoch 246: Max Absolute Error = 3.2803
# Epoch 247/520
# 58/58 [==============================] - 0s 902us/step - loss: 0.0020 - accuracy: 0.0891 - val_loss: 0.0014 - val_accuracy: 0.0769
# Epoch 247: Max Absolute Error = 2.9802
# Epoch 248/520
# 58/58 [==============================] - 0s 944us/step - loss: 0.0018 - accuracy: 0.0891 - val_loss: 0.0011 - val_accuracy: 0.0769
# Epoch 248: Max Absolute Error = 3.1531
# Epoch 249/520
# 58/58 [==============================] - 0s 927us/step - loss: 0.0015 - accuracy: 0.0905 - val_loss: 0.0014 - val_accuracy: 0.0769
# Epoch 249: Max Absolute Error = 3.2456
# Epoch 250/520
# 58/58 [==============================] - 0s 878us/step - loss: 0.0022 - accuracy: 0.0877 - val_loss: 0.0012 - val_accuracy: 0.0769
# Epoch 250: Max Absolute Error = 3.1103
# Epoch 251/520
# 58/58 [==============================] - 0s 891us/step - loss: 0.0017 - accuracy: 0.0800 - val_loss: 0.0016 - val_accuracy: 0.0769
# Epoch 251: Max Absolute Error = 2.7487
# Epoch 252/520
# 58/58 [==============================] - 0s 882us/step - loss: 0.0015 - accuracy: 0.0858 - val_loss: 0.0026 - val_accuracy: 0.0769
# Epoch 252: Max Absolute Error = 4.5327
# Epoch 253/520
# 58/58 [==============================] - 0s 950us/step - loss: 0.0020 - accuracy: 0.1004 - val_loss: 0.0013 - val_accuracy: 0.0769
# Epoch 253: Max Absolute Error = 3.1966
# Epoch 254/520
# 58/58 [==============================] - 0s 901us/step - loss: 0.0014 - accuracy: 0.0693 - val_loss: 0.0029 - val_accuracy: 0.0769
# Epoch 254: Max Absolute Error = 4.1086
# Epoch 255/520
# 58/58 [==============================] - 0s 985us/step - loss: 0.0022 - accuracy: 0.0788 - val_loss: 0.0029 - val_accuracy: 0.0769
# Epoch 255: Max Absolute Error = 3.5364
# Epoch 256/520
# 58/58 [==============================] - 0s 872us/step - loss: 0.0020 - accuracy: 0.0752 - val_loss: 0.0026 - val_accuracy: 0.0769
# Epoch 256: Max Absolute Error = 5.3851
# Epoch 257/520
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 0.0916 - val_loss: 0.0019 - val_accuracy: 0.0769
# Epoch 257: Max Absolute Error = 2.8429
# Epoch 258/520
# 58/58 [==============================] - 0s 908us/step - loss: 0.0017 - accuracy: 0.0773 - val_loss: 0.0014 - val_accuracy: 0.0769
# Epoch 258: Max Absolute Error = 3.1146
# Epoch 259/520
# 58/58 [==============================] - 0s 915us/step - loss: 0.0014 - accuracy: 0.0702 - val_loss: 0.0011 - val_accuracy: 0.0769
# Epoch 259: Max Absolute Error = 3.2030
# Epoch 260/520
# Epoch 499 Average Max Abs Error: 0.3473
# Epoch 500 Average Max Abs Error: 0.3606
# Epoch 501 Average Max Abs Error: 0.2953
# Epoch 502 Average Max Abs Error: 0.3919
# Epoch 503 Average Max Abs Error: 0.3294
# Epoch 504 Average Max Abs Error: 0.3522
# Epoch 505 Average Max Abs Error: 0.4238
# Epoch 506 Average Max Abs Error: 0.3283
# Epoch 507 Average Max Abs Error: 0.2759
# Epoch 508 Average Max Abs Error: 0.3225
# Epoch 509 Average Max Abs Error: 0.2876
# Epoch 510 Average Max Abs Error: 0.4514
# Epoch 511 Average Max Abs Error: 0.3472
# Epoch 512 Average Max Abs Error: 0.3055
# Epoch 513 Average Max Abs Error: 0.4247
# Epoch 514 Average Max Abs Error: 0.3233
# Epoch 515 Average Max Abs Error: 0.3454
# Epoch 516 Average Max Abs Error: 0.3837
# Epoch 517 Average Max Abs Error: 0.3157
# Epoch 518 Average Max Abs Error: 0.3105
# Epoch 519 Average Max Abs Error: 0.3253
# Epoch 520 Average Max Abs Error: 0.3140
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0029 - accuracy: 0.0781
# Loss = 0.0029161933343857527, rmse = 0.078125
# Loss array:  [0.0013345431070774794, 0.0019668268505483866, 0.0015876258257776499, 0.0028107822872698307, 0.0014876544009894133, 0.004087267909198999, 0.0028934497386217117, 0.0036140787415206432, 0.0018156159203499556, 0.0029161933343857527]
# INFO:tensorflow:Assets written to: Best models/target_2/single_models/density_kfold_dnn_single/assets

# %% [markdown]
# # Results
# - Plot of k-cross validation performance
# - Scatter Plot of prediction results against true values

# %%
# Loss across k folds
plot_line(arr_loss, "Loss across k-folds", "Value of k")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Loss curves

# %%
def plot_loss_curve(history, epoch_size):
    loss_train = history.history['loss']
    loss_val = history.history['val_loss']
    epochs = range(0,epoch_size)
    
    plt.plot(epochs, loss_train, 'g', label='Training loss')
    plt.plot(epochs, loss_val, 'b', label='Validation loss')
    
    plt.title('Training and Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    
    plt.legend()
    plt.show()



# Loss across k folds
plot_line(arr_loss, "Loss across k-folds", "Value of k")

# Training and Validation Loss
plot_loss_curve(history_best_model, NUM_EPOCHS)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Prediction on Test Dataset

# %%
import time

start_time = time.time()
Y_pred_normalized = best_model.predict(X_test)
end_time = time.time()
Y_pred_normalized_entire = best_model.predict(dataset_x_norm)
# Calculate elapsed time in seconds
elapsed_time = end_time - start_time
print("Elapsed time:", round(elapsed_time, 3), "seconds")


Y_pred = scaler_output.inverse_transform(Y_pred_normalized)
Y_pred_entire = scaler_output.inverse_transform(Y_pred_normalized_entire)
Y_actual = scaler_output.inverse_transform(y_test)
Y_actual_entire = np.array(df_targets)
# Moisture Content
scatter_plot(trueValues=Y_actual[:,0], 
             predictions=Y_pred[:,0], 
             title="Moisture Content")
a, b = np.polyfit(Y_pred[:, 0], Y_actual[:, 0], 1) # y = ax + b
x_best_fit = np.arange(0, max(max(Y_pred[:,0]), max(Y_actual[:,0])), 1)
plt.plot(x_best_fit, a*x_best_fit + b, c='red', label='Best fit')
plt.legend()
plt.savefig('../Poster/Results/obj_3_MC.svg', dpi=300,
                bbox_inches='tight',
                transparent=True)
# Out:
# Elapsed time: 0.0231 seconds
# Maxval here is:  25.855585

# %% [markdown]
# # Error analysis
# - R squared calculation
# - Mean accuracy error

# %% [markdown]
# ### R squared calculation

# %%
from sklearn.metrics import r2_score

# MOISTURE CONTENT
#   - R-squared
# mc_r2_score = r2_score(Y_actual[:, 0], Y_pred[:, 0])
mc_r2_score = calculate_r_squared(y_true=Y_actual[:, 0], y_pred=Y_pred[:, 0])
print("{:#.4g}".format(mc_r2_score))
# Out:
# 0.9767

# %% [markdown]
# ### RMSE

# %%
from sklearn.metrics import mean_squared_error
from sigfig import round

#MC
rmse_mc = np.sqrt(mean_squared_error(Y_actual[:, 0], Y_pred[:, 0]))
print('RMSE_MC: ', "{0:.4g}".format(rmse_mc))
# Out:
# RMSE_MC:  0.5757

# %% [markdown]
# Now we will compare with the results from Trabelsi's paper. This is single moisture prediction
#
# R^2 : 0.993\
# Mean Squared Error: 0.028\
# Mean absolute Error: 0.135\
# Min. Absolute Error: 0.004\
# Max Absolute Error: 0.441

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,max_error, r2_score
from sigfig import round

mc_r2_score = r2_score(y_true=Y_actual[:, 0], y_pred=Y_pred[:, 0])
print("R^2: {:#.4g}".format(mc_r2_score))
mse_mc = mean_squared_error(Y_actual[:, 0], Y_pred[:, 0], squared=True)
print('Mean Squared Error: ', "{0:.4g}".format(mse_mc))
mae_mc = mean_absolute_error(Y_actual[:, 0], Y_pred[:, 0])
print('Mean Absolute Error: ', "{0:.4g}".format(mae_mc))

sums = []
for i in range(len(Y_actual[:,0])):
    sum = Y_actual[:,0][i] - Y_pred[:,0][i]
    #print(Y_actual[:,0][i]," - ",Y_pred[:,0][i],'=',sum)
    sums.append(abs(sum))
print("Min Absolute Error: ",min(sums))
print("Max Absolute Error: ",max(sums))
# Out:
# R^2: 0.9760
# Mean Squared Error:  0.3315
# Mean Absolute Error:  0.3131
# Min Absolute Error:  5.203247070184602e-05
# Max Absolute Error:  3.0589505767822267

# %%
mc_r2_score = r2_score(Y_actual_entire[:, 0], Y_pred_entire[:, 0])
print("R^2: {:#.4g}".format(mc_r2_score))
mse_mc = mean_squared_error(Y_actual_entire[:, 0], Y_pred_entire[:, 0], squared=True)
print('Mean Squared Error: ', "{0:.4g}".format(mse_mc))
mae_mc = mean_absolute_error(Y_actual_entire[:, 0], Y_pred_entire[:, 0])
print('Mean Absolute Error: ', "{0:.4g}".format(mae_mc))

sums = []
for i in range(len(Y_actual_entire[:,0])):
    sum = Y_actual_entire[:,0][i] - Y_pred_entire[:,0][i]
    #print(Y_actual[:,0][i]," - ",Y_pred[:,0][i],'=',sum)
    sums.append(abs(sum))
print("Min Absolute Error: ",min(sums))
print("Max Absolute Error: ",max(sums))
# Out:
# R^2: 0.9805
# Mean Squared Error:  0.2809
# Mean Absolute Error:  0.2718
# Min Absolute Error:  5.203247070184602e-05
# Max Absolute Error:  3.0589505767822267
