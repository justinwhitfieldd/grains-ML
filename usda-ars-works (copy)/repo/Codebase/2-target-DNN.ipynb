# %% [markdown]
# # Global constants

# %%
#GRAIN_TYPE = 'Wheat'
#GRAIN_TYPE = 'newWheatData'
#GRAIN_TYPE = 'CornAdded_Type'
GRAIN_TYPE = 'cleaned_data'
# GRAIN_TYPE = 'Oats'

# GRAIN_TYPE = 'Barley'
# GRAIN_TYPE = 'Sorghum'
# GRAIN_TYPE = 'Soybeans'
# GRAIN_TYPE = 'Corn'

FILENAME_BEST_MODEL = 'Best models/target_2/hybrid_models/' + GRAIN_TYPE + '_t2_kcv_dnn_mc.h5'

# %%
#Import libraries
import requests
import pydot
import pandas as pd


#Data visualization
import seaborn as sn
import matplotlib.pyplot as plt
import random
#Data Manipulation
import pandas as pd
import numpy as np

# Machine Learning
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, Activation, BatchNormalization
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split, KFold
np.random.seed(39)
random.seed(39)
tf.random.set_seed(39)
print(tf.__version__)
# Out:
# 2.4.1

# %%
print(tf.config.list_physical_devices('GPU'))
# print(tf.version.VERSION)
# Out:
# []

# %% [markdown]
# ## Helper functions

# %%
def calculate_r_squared(y_true, y_pred):
   corr_matrix = np.corrcoef(y_true, y_pred)
   corr = corr_matrix[0,1]
   R_sq = corr**2
   return R_sq

def plot_loss_curve(history, epoch_size):
    loss_train = history.history['loss']
    loss_val = history.history['val_loss']
    epochs = range(0,epoch_size)
    
    plt.plot(epochs, loss_train, 'g', label='Training loss')
    plt.plot(epochs, loss_val, 'b', label='Validation loss')
    
    plt.title('Training and Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    
    plt.legend()
    plt.show()

def plot_line(metric, title, xlabel):
    plt.figure(figsize=(8,3))
    plt.title(title, fontsize = 16)
    plt.plot(metric)
    plt.xlabel(xlabel, fontsize = 14)
    plt.grid()
    plt.legend(loc= "best")
    plt.show()

def scatter_plot(trueValues, predictions, title):
  plt.figure(figsize=(8,3))
  ax = plt.axes()
  maxVal = max( max(trueValues), max(predictions) )

  ax.scatter(x=predictions, y=trueValues)
  ax.plot([0, 1, maxVal], [0, 1, maxVal], label="Ideal fit")
  print('Maxval here is: ', maxVal)
  plt.title(title, fontsize = 16)
  plt.xlabel("Predictions", fontsize = 14)
  plt.ylabel("Real", fontsize = 14)
  plt.grid()

# %%
#url dataset
URL = "../Datasets/processed/" + GRAIN_TYPE + ".csv"

#read in excel format
df = pd.read_csv(URL)
#df = df[df['Variety'] == 'SOUTH DAKOTA']
#df = df[(df['Density'] >= 0.72) & (df['Density'] <= 0.88)]

print("From USDA: ", URL)


df.head()
# Out:
# From USDA:  ../Datasets/processed/cleaned_data.csv
#   Variety  Freq  d(cm)    M%  Density     Attn    Phase  Phase_Corr  \
# 0  KANSAS   7.0    8.9  11.3   0.7356   8.8258  -55.973    -415.973
# 1  KANSAS   8.0    8.9  11.3   0.7356  10.2572 -114.289    -474.289
# 2  KANSAS   9.0    8.9  11.3   0.7356  11.5679 -168.171    -528.171
# 3  KANSAS  10.0    8.9  11.3   0.7356  12.8795  134.849    -585.151
# 4  KANSAS  11.0    8.9  11.3   0.7356  13.7649   83.502    -636.498
#
#    Permittivity_real  Permittivity_imaginary       Type  Phase/Attn  \
# 0              2.416                   0.243  15.855506   -6.341975
# 1              2.412                   0.246  15.855506  -11.142320
# 2              2.395                   0.246  15.855506  -14.537729
# 3              2.390                   0.246  15.855506   10.470049
# 4              2.371                   0.238  15.855506    6.066299
#
#    Freq*d(cm)  Freq*Attn
# 0        62.3    61.7806
# 1        71.2    82.0576
# 2        80.1   104.1111
# 3        89.0   128.7950
# 4        97.9   151.4139

# %% [markdown]
# # 2. Overview of data

# %%
# Data summary
df.describe()
# Out:
#              Freq       d(cm)          M%     Density        Attn       Phase  \
# count  806.000000  806.000000  806.000000  806.000000  806.000000  806.000000
# mean    10.811414    7.088834   16.189541    0.796298   18.410033   -4.604663
# std      3.530055    1.554604    3.794772    0.067384    5.946835  101.951444
# min      5.000000    4.400000   10.260000    0.625400    8.002300 -179.335000
# 25%      8.000000    6.500000   13.680000    0.745400   13.524700  -88.842000
# 50%     11.000000    7.700000   16.225000    0.801300   18.131600   -9.838500
# 75%     13.000000    7.700000   18.810000    0.842000   23.098000   80.957250
# max     18.000000    8.900000   24.410000    0.927800   29.897000  179.048000
#
#         Phase_Corr  Permittivity_real  Permittivity_imaginary        Type  \
# count   806.000000         806.000000              806.000000  806.000000
# mean   -633.488065           2.912112                0.499187   16.189541
# std     219.510760           0.305758                0.186739    0.629743
# min   -1274.435000           2.340000                0.220000   15.352809
# 25%    -793.405750           2.688500                0.337000   15.855506
# 50%    -602.380500           2.861500                0.470500   16.400366
# 75%    -456.055750           3.109750                0.639000   16.401988
# max    -235.044000           4.038000                0.987000   17.344167
#
#        Phase/Attn  Freq*d(cm)   Freq*Attn
# count  806.000000  806.000000  806.000000
# mean    -0.377074   77.159677  215.799030
# std      6.071761   32.552200  124.108325
# min    -17.418676   22.000000   40.011500
# 25%     -5.077754   52.800000  107.817375
# 50%     -0.589378   71.200000  195.600450
# 75%      4.300734  100.100000  310.863000
# max     14.827701  160.200000  538.146000

# %%
# Dimension of the dataset
df.shape
# Out:
# (806, 14)

# %%
# Check info about missing values in dataframe
df.isnull().sum()
# Out:
# Variety                   0
# Freq                      0
# d(cm)                     0
# M%                        0
# Density                   0
# Attn                      0
# Phase                     0
# Phase_Corr                0
# Permittivity_real         0
# Permittivity_imaginary    0
# Type                      0
# Phase/Attn                0
# Freq*d(cm)                0
# Freq*Attn                 0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Data preparation
#
#
# 1.   Convert dataframe to numpy array for flexibility.
# 2. Split our data into training and testing datasets and store the target values in different variables.
# 3.   Normalize the features by applying some operations in the data sets.

# %%
# Convert to numpy array
df_features = df[['Freq', 
                    'd(cm)', 
                   # 'Attn', 
                    'Phase_Corr', 
                    'Permittivity_real', 
                    'Permittivity_imaginary',
                    'Type',
                    ]]

df_targets = df[['M%', 'Density']]
# df_targets = df[['Density', 'M%']]

dataset_x = df_features.to_numpy()
dataset_y = df_targets.to_numpy()

# %% [markdown]
# ## Splitting dataset to test and train+validate

# %%
# Perform train-test split on RAW DATA
X_trainVal, X_test, y_trainVal, y_test = train_test_split(dataset_x, dataset_y, 
                                                    test_size=0.20
                                                    ,random_state=42
                                                    )

X_train, X_val, y_train, y_val = train_test_split(X_trainVal, y_trainVal, 
                                                    test_size=0.20 #validation split
                                                    ,random_state=42
                                                    )

# %% [markdown]
# ## Normalize datasets

# %%
from sklearn.preprocessing import MinMaxScaler

#Normalizing the data set
scaler_input = MinMaxScaler()
scaler_output = MinMaxScaler()

# Normalize Train set
X_train_norm = scaler_input.fit_transform(X_train)
y_train_norm = scaler_output.fit_transform(y_train)

# Normalize Validation set
X_val_norm = scaler_input.fit_transform(X_val)
y_val_norm = scaler_output.fit_transform(y_val)

# Normalize the entire dataset (input features)
dataset_x_norm = scaler_input.transform(dataset_x)  # Use transform, NOT fit_transform

# Normalize the entire dataset (output targets)
dataset_y_norm = scaler_output.transform(dataset_y)  # Use transform, NOT fit_transform

# %% [markdown]
# # K-cross Validation
# * Input features: 7
# * Output targets: 2

# %% [markdown]
# ## Defining model

# %%
from keras import layers, Sequential, regularizers

# Define the model-building function
def my_model():
  my_model = Sequential([
    
    layers.Dense(450, input_shape=(6,), activation='relu',),
    layers.Dense(450, activation='relu', ),
    layers.Dense(450, activation='relu',),
    layers.Dense(450, activation='relu',),
    layers.Dense(450, activation='relu',),
    layers.Dense(450, activation='relu',),
    layers.Dense(2, activation='linear')  # Output layer with 2 neurons for the two regression targets
  ])

  opt = tf.keras.optimizers.Adam(learning_rate=0.002898773627262781) # 0.0006 
  my_model.compile(
      optimizer = opt,
      loss = 'mse',
      metrics = ['accuracy']
  )

  return my_model

plot_model(my_model(), show_shapes=True, show_layer_names=True)
my_model().summary()
# Out:
# Model: "sequential_85"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_559 (Dense)            (None, 450)               3150
# _________________________________________________________________
# dense_560 (Dense)            (None, 450)               202950
# _________________________________________________________________
# dense_561 (Dense)            (None, 450)               202950
# _________________________________________________________________
# dense_562 (Dense)            (None, 450)               202950
# _________________________________________________________________
# dense_563 (Dense)            (None, 450)               202950
# _________________________________________________________________
# dense_564 (Dense)            (None, 450)               202950
# _________________________________________________________________
# dense_565 (Dense)            (None, 2)                 902
# =================================================================
# Total params: 1,018,802
# Trainable params: 1,018,802
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Running model with KCV

# %%
from sklearn.model_selection import KFold
import numpy as np

NUM_EPOCHS = 300# 180
BATCH_SIZE = 10
K_FOLD_SPLITS = 10


# Define the cross-validation process to be used inside cross_val_Score evaluation
cv = KFold(n_splits=K_FOLD_SPLITS)

# Handling for accommodating multiple targets
Y1 = y_train_norm[:,0]
Y2 = y_train_norm[:,1]
targets = (Y1, Y2)

X = X_train_norm

i = 0
arr_loss = list()
arr_rmse = list()
min_loss = 1000000
best_model = None
history = None
history_best_model = None

# Perform k-fold cross-validation
for train_indices, test_indices in cv.split(X_train):
  print('####################### Iteration  ', i, ' #######################')
  trainX, valX = np.array(X[train_indices]), np.array(X[test_indices])
  trainY = np.vstack((Y1[train_indices], Y2[train_indices])).T
  valY = np.vstack((Y1[test_indices], Y2[test_indices])).T

  model = my_model()
  history = model.fit(trainX, trainY,
            epochs=NUM_EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data = (valX, valY)
  )


  #testing on validation set process
  loss, rmse = model.evaluate(x = valX, y = valY, verbose=1)
  print(f"Loss = {loss}, rmse = {rmse}" )

  if loss < min_loss:
    best_model = model
    history_best_model = history
    min_loss = loss

  arr_loss.append(loss)
  arr_rmse.append(rmse)
  print('Loss array: ', arr_loss)
  i+=1

# Saving the best model within the k folds
best_model.save(FILENAME_BEST_MODEL)
# Out:
# ####################### Iteration   0  #######################
# Epoch 1/280
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4324 - accuracy: 0.6595 - val_loss: 0.0240 - val_accuracy: 0.8269
# Epoch 2/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.8709 - val_loss: 0.0079 - val_accuracy: 0.9231
# Epoch 3/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 0.9256 - val_loss: 0.0119 - val_accuracy: 0.8846
# Epoch 4/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 0.9182 - val_loss: 0.0067 - val_accuracy: 0.9231
# Epoch 5/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 0.9107 - val_loss: 0.0093 - val_accuracy: 0.9231
# Epoch 6/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9144 - val_loss: 0.0037 - val_accuracy: 0.9423
# Epoch 7/280
#  1/47 [..............................] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 0.9628 - val_loss: 0.0133 - val_accuracy: 0.8462
# Epoch 8/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.8851 - val_loss: 0.0104 - val_accuracy: 0.9423
# Epoch 9/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.9187 - val_loss: 0.0064 - val_accuracy: 0.9423
# Epoch 10/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 0.9488 - val_loss: 0.0054 - val_accuracy: 0.9423
# Epoch 11/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 0.9663 - val_loss: 0.0030 - val_accuracy: 0.9423
# Epoch 12/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 0.9652 - val_loss: 0.0058 - val_accuracy: 0.9423
# Epoch 13/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 0.9297 - val_loss: 0.0038 - val_accuracy: 0.9231
# Epoch 14/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 0.9570 - val_loss: 0.0027 - val_accuracy: 0.9615
# Epoch 15/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 0.9810 - val_loss: 0.0020 - val_accuracy: 0.9423
# Epoch 16/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9647 - val_loss: 0.0021 - val_accuracy: 0.9808
# Epoch 17/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9749 - val_loss: 0.0048 - val_accuracy: 0.9615
# Epoch 18/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 0.9476 - val_loss: 0.0045 - val_accuracy: 0.9615
# Epoch 19/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 0.9709 - val_loss: 0.0022 - val_accuracy: 0.9808
# Epoch 20/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 0.9733 - val_loss: 0.0072 - val_accuracy: 0.9231
# Epoch 21/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 0.9459 - val_loss: 0.0024 - val_accuracy: 0.9231
# Epoch 22/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9818 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 23/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.9771 - val_loss: 0.0013 - val_accuracy: 0.9615
# Epoch 24/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.6814e-04 - accuracy: 0.9736 - val_loss: 9.8461e-04 - val_accuracy: 0.9808
# Epoch 25/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9700 - val_loss: 0.0013 - val_accuracy: 0.9615
# Epoch 26/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.4919e-04 - accuracy: 0.9844 - val_loss: 0.0018 - val_accuracy: 0.9808
# Epoch 27/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9891 - val_loss: 0.0012 - val_accuracy: 0.9808
# Epoch 28/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.4029e-04 - accuracy: 0.9852 - val_loss: 0.0011 - val_accuracy: 0.9808
# Epoch 29/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 0.9794 - val_loss: 0.0030 - val_accuracy: 0.9808
# Epoch 30/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 0.9418 - val_loss: 0.0029 - val_accuracy: 0.9808
# Epoch 31/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 0.9446 - val_loss: 0.0030 - val_accuracy: 0.9423
# Epoch 32/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.9714 - val_loss: 0.0021 - val_accuracy: 0.9808
# Epoch 33/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 0.9688 - val_loss: 0.0030 - val_accuracy: 0.9423
# Epoch 34/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 0.9605 - val_loss: 0.0032 - val_accuracy: 0.9808
# Epoch 35/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 0.9824 - val_loss: 0.0024 - val_accuracy: 0.9808
# Epoch 36/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9779 - val_loss: 0.0022 - val_accuracy: 0.9615
# Epoch 37/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9606 - val_loss: 0.0020 - val_accuracy: 0.9615
# Epoch 38/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 0.9771 - val_loss: 0.0025 - val_accuracy: 0.9808
# Epoch 39/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9821 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 40/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9718 - val_loss: 0.0015 - val_accuracy: 0.9808
# Epoch 41/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 0.9521 - val_loss: 0.0116 - val_accuracy: 0.9808
# Epoch 42/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.9709 - val_loss: 0.0024 - val_accuracy: 0.9808
# Epoch 43/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 0.9652 - val_loss: 0.0011 - val_accuracy: 0.9808
# Epoch 44/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 0.9737 - val_loss: 0.0017 - val_accuracy: 0.9615
# Epoch 45/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 0.9531 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 46/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 0.9728 - val_loss: 0.0016 - val_accuracy: 0.9808
# Epoch 47/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 0.9649 - val_loss: 0.0018 - val_accuracy: 0.9615
# Epoch 48/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.6554e-04 - accuracy: 0.9932 - val_loss: 0.0012 - val_accuracy: 0.9808
# Epoch 49/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.6229e-04 - accuracy: 0.9910 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 50/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.4397e-04 - accuracy: 0.9917 - val_loss: 7.6609e-04 - val_accuracy: 1.0000
# Epoch 51/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.0896e-04 - accuracy: 0.9917 - val_loss: 5.9178e-04 - val_accuracy: 0.9808
# Epoch 52/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.4838e-04 - accuracy: 0.9909 - val_loss: 8.4148e-04 - val_accuracy: 0.9808
# Epoch 53/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9760 - val_loss: 0.0015 - val_accuracy: 0.9615
# Epoch 54/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 0.9236 - val_loss: 0.0031 - val_accuracy: 0.9808
# Epoch 55/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 0.9599 - val_loss: 0.0045 - val_accuracy: 0.9615
# Epoch 56/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 0.9573 - val_loss: 0.0024 - val_accuracy: 0.9423
# Epoch 57/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 0.9710 - val_loss: 0.0019 - val_accuracy: 0.9231
# Epoch 58/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9879 - val_loss: 8.0243e-04 - val_accuracy: 0.9808
# Epoch 59/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.0454e-04 - accuracy: 0.9893 - val_loss: 0.0013 - val_accuracy: 0.9808
# Epoch 60/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.6129e-04 - accuracy: 0.9825 - val_loss: 9.7956e-04 - val_accuracy: 0.9808
# Epoch 61/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.2981e-04 - accuracy: 0.9964 - val_loss: 8.0517e-04 - val_accuracy: 0.9808
# Epoch 62/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.7098e-04 - accuracy: 0.9917 - val_loss: 0.0012 - val_accuracy: 0.9615
# Epoch 63/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 0.9706 - val_loss: 8.5860e-04 - val_accuracy: 0.9615
# Epoch 64/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.6740e-04 - accuracy: 0.9892 - val_loss: 7.5868e-04 - val_accuracy: 0.9808
# Epoch 65/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.8766e-04 - accuracy: 0.9873 - val_loss: 8.4665e-04 - val_accuracy: 0.9615
# Epoch 66/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.8397e-04 - accuracy: 0.9753 - val_loss: 7.8523e-04 - val_accuracy: 0.9615
# Epoch 67/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.0413e-04 - accuracy: 0.9752 - val_loss: 0.0010 - val_accuracy: 0.9808
# Epoch 68/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.9272e-04 - accuracy: 0.9814 - val_loss: 0.0012 - val_accuracy: 0.9808
# Epoch 69/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.4259e-04 - accuracy: 1.0000 - val_loss: 7.6378e-04 - val_accuracy: 0.9808
# Epoch 70/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.8519e-04 - accuracy: 0.9802 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 71/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9787 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 72/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 0.9676 - val_loss: 0.0021 - val_accuracy: 0.9615
# Epoch 73/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9690 - val_loss: 0.0045 - val_accuracy: 0.9423
# Epoch 74/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.9733 - val_loss: 0.0020 - val_accuracy: 0.9808
# Epoch 75/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9782 - val_loss: 0.0041 - val_accuracy: 0.9615
# Epoch 76/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 0.9619 - val_loss: 0.0024 - val_accuracy: 0.9423
# Epoch 77/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 0.9523 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 78/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9848 - val_loss: 0.0016 - val_accuracy: 0.9808
# Epoch 79/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9805 - val_loss: 0.0017 - val_accuracy: 0.9808
# Epoch 80/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 0.9708 - val_loss: 0.0017 - val_accuracy: 0.9808
# Epoch 81/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.6409e-04 - accuracy: 0.9815 - val_loss: 8.8085e-04 - val_accuracy: 1.0000
# Epoch 82/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.7654e-04 - accuracy: 0.9824 - val_loss: 0.0014 - val_accuracy: 0.9423
# Epoch 83/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9694 - val_loss: 0.0023 - val_accuracy: 0.9808
# Epoch 84/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9724 - val_loss: 0.0022 - val_accuracy: 0.9231
# Epoch 85/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.3197e-04 - accuracy: 0.9812 - val_loss: 0.0016 - val_accuracy: 0.9615
# Epoch 86/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.9912e-04 - accuracy: 0.9793 - val_loss: 0.0011 - val_accuracy: 0.9808
# Epoch 87/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 0.9822 - val_loss: 0.0013 - val_accuracy: 0.9808
# Epoch 88/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.8942e-04 - accuracy: 0.9869 - val_loss: 0.0016 - val_accuracy: 0.9615
# Epoch 89/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9602 - val_loss: 0.0024 - val_accuracy: 0.9808
# Epoch 90/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.9824 - val_loss: 0.0022 - val_accuracy: 0.9615
# Epoch 91/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.9613 - val_loss: 0.0015 - val_accuracy: 0.9615
# Epoch 92/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.1276e-04 - accuracy: 0.9778 - val_loss: 0.0014 - val_accuracy: 0.9808
# Epoch 93/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 0.9711 - val_loss: 0.0015 - val_accuracy: 0.9808
# Epoch 94/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.4122e-04 - accuracy: 0.9879 - val_loss: 7.8916e-04 - val_accuracy: 0.9808
# Epoch 95/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.3548e-04 - accuracy: 0.9907 - val_loss: 6.7416e-04 - val_accuracy: 0.9808
# Epoch 96/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.5968e-04 - accuracy: 0.9850 - val_loss: 9.9535e-04 - val_accuracy: 0.9808
# Epoch 97/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.8904e-04 - accuracy: 0.9925 - val_loss: 7.7318e-04 - val_accuracy: 0.9808
# Epoch 98/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.0513e-04 - accuracy: 0.9894 - val_loss: 0.0013 - val_accuracy: 0.9808
# Epoch 99/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.1729e-04 - accuracy: 0.9886 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 100/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.4647e-04 - accuracy: 0.9890 - val_loss: 0.0011 - val_accuracy: 0.9808
# Epoch 101/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.7786e-04 - accuracy: 0.9631 - val_loss: 0.0013 - val_accuracy: 0.9808
# Epoch 102/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.0039e-04 - accuracy: 0.9964 - val_loss: 6.2477e-04 - val_accuracy: 1.0000
# Epoch 103/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.7577e-04 - accuracy: 0.9853 - val_loss: 0.0010 - val_accuracy: 0.9808
# Epoch 104/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.4521e-04 - accuracy: 0.9736 - val_loss: 0.0016 - val_accuracy: 0.9808
# Epoch 105/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9715 - val_loss: 0.0030 - val_accuracy: 0.9615
# Epoch 106/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 0.9344 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 107/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9648 - val_loss: 0.0038 - val_accuracy: 0.9615
# Epoch 108/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9536 - val_loss: 0.0027 - val_accuracy: 0.9423
# Epoch 109/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 0.9609 - val_loss: 0.0035 - val_accuracy: 0.9423
# Epoch 110/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 0.9607 - val_loss: 0.0044 - val_accuracy: 0.9615
# Epoch 111/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.9687 - val_loss: 0.0021 - val_accuracy: 0.9231
# Epoch 112/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9587 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 113/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 0.9490 - val_loss: 0.0015 - val_accuracy: 0.9808
# Epoch 114/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.4590e-04 - accuracy: 0.9629 - val_loss: 0.0011 - val_accuracy: 0.9808
# Epoch 115/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.1096e-04 - accuracy: 0.9873 - val_loss: 8.3338e-04 - val_accuracy: 1.0000
# Epoch 116/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.4617e-04 - accuracy: 0.9950 - val_loss: 0.0014 - val_accuracy: 0.9808
# Epoch 117/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.3780e-04 - accuracy: 0.9862 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 118/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.6727e-04 - accuracy: 0.9871 - val_loss: 0.0018 - val_accuracy: 0.9615
# Epoch 119/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.1325e-04 - accuracy: 0.9888 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 120/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.8307e-04 - accuracy: 0.9799 - val_loss: 7.6955e-04 - val_accuracy: 0.9808
# Epoch 121/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.8438e-04 - accuracy: 0.9848 - val_loss: 8.6272e-04 - val_accuracy: 0.9808
# Epoch 122/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.9870e-04 - accuracy: 0.9953 - val_loss: 4.5017e-04 - val_accuracy: 0.9808
# Epoch 123/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.5574e-04 - accuracy: 0.9908 - val_loss: 8.3568e-04 - val_accuracy: 1.0000
# Epoch 124/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.3012e-04 - accuracy: 0.9926 - val_loss: 8.9726e-04 - val_accuracy: 0.9808
# Epoch 125/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.7073e-04 - accuracy: 0.9878 - val_loss: 8.7713e-04 - val_accuracy: 1.0000
# Epoch 126/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.7358e-04 - accuracy: 0.9970 - val_loss: 0.0011 - val_accuracy: 0.9808
# Epoch 127/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.2084e-04 - accuracy: 0.9881 - val_loss: 9.3140e-04 - val_accuracy: 1.0000
# Epoch 128/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.3280e-04 - accuracy: 0.9902 - val_loss: 0.0013 - val_accuracy: 0.9423
# Epoch 129/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.3373e-04 - accuracy: 0.9810 - val_loss: 0.0041 - val_accuracy: 0.9038
# Epoch 130/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 0.9301 - val_loss: 0.0021 - val_accuracy: 0.9423
# Epoch 131/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 0.9642 - val_loss: 0.0021 - val_accuracy: 0.9615
# Epoch 132/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 0.9474 - val_loss: 0.0025 - val_accuracy: 0.9808
# Epoch 133/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 0.9707 - val_loss: 0.0013 - val_accuracy: 0.9808
# Epoch 134/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9823 - val_loss: 0.0015 - val_accuracy: 0.9808
# Epoch 135/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.6630e-04 - accuracy: 0.9818 - val_loss: 6.8806e-04 - val_accuracy: 0.9808
# Epoch 136/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.5549e-04 - accuracy: 0.9987 - val_loss: 7.6181e-04 - val_accuracy: 1.0000
# Epoch 137/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.0212e-04 - accuracy: 0.9996 - val_loss: 4.2479e-04 - val_accuracy: 1.0000
# Epoch 138/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.2008e-04 - accuracy: 0.9962 - val_loss: 6.4823e-04 - val_accuracy: 0.9808
# Epoch 139/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.2605e-04 - accuracy: 0.9805 - val_loss: 9.3362e-04 - val_accuracy: 0.9615
# Epoch 140/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.7560e-04 - accuracy: 0.9563 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 141/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.3526e-04 - accuracy: 0.9874 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 142/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9703 - val_loss: 0.0027 - val_accuracy: 0.9615
# Epoch 143/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.9663 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 144/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9660 - val_loss: 0.0015 - val_accuracy: 0.9808
# Epoch 145/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.7621e-04 - accuracy: 0.9859 - val_loss: 7.6161e-04 - val_accuracy: 0.9808
# Epoch 146/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.4668e-04 - accuracy: 0.9846 - val_loss: 0.0019 - val_accuracy: 0.9615
# Epoch 147/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.5467e-04 - accuracy: 0.9783 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 148/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.4764e-04 - accuracy: 0.9829 - val_loss: 8.6453e-04 - val_accuracy: 0.9808
# Epoch 149/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9785 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 150/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.7388e-04 - accuracy: 0.9869 - val_loss: 0.0016 - val_accuracy: 0.9808
# Epoch 151/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 0.9818 - val_loss: 0.0018 - val_accuracy: 0.9808
# Epoch 152/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 0.9566 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 153/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9789 - val_loss: 0.0072 - val_accuracy: 0.9423
# Epoch 154/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 0.9648 - val_loss: 0.0036 - val_accuracy: 0.9808
# Epoch 155/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 0.9793 - val_loss: 0.0012 - val_accuracy: 0.9808
# Epoch 156/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.9681e-04 - accuracy: 0.9809 - val_loss: 7.0216e-04 - val_accuracy: 1.0000
# Epoch 157/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.6676e-04 - accuracy: 0.9977 - val_loss: 8.0563e-04 - val_accuracy: 1.0000
# Epoch 158/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.5734e-04 - accuracy: 0.9951 - val_loss: 6.4239e-04 - val_accuracy: 0.9808
# Epoch 159/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9631 - val_loss: 8.3689e-04 - val_accuracy: 0.9808
# Epoch 160/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.0329e-04 - accuracy: 0.9860 - val_loss: 6.0266e-04 - val_accuracy: 0.9808
# Epoch 161/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.0148e-04 - accuracy: 0.9903 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 162/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.7689e-04 - accuracy: 0.9752 - val_loss: 0.0013 - val_accuracy: 0.9808
# Epoch 163/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.6944e-04 - accuracy: 0.9971 - val_loss: 6.6141e-04 - val_accuracy: 1.0000
# Epoch 164/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.7884e-04 - accuracy: 0.9970 - val_loss: 7.2301e-04 - val_accuracy: 1.0000
# Epoch 165/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.4143e-04 - accuracy: 1.0000 - val_loss: 4.5030e-04 - val_accuracy: 1.0000
# Epoch 166/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.1240e-04 - accuracy: 0.9939 - val_loss: 5.1800e-04 - val_accuracy: 1.0000
# Epoch 167/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.4818e-04 - accuracy: 0.9969 - val_loss: 0.0013 - val_accuracy: 0.9808
# Epoch 168/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9777 - val_loss: 0.0026 - val_accuracy: 0.9423
# Epoch 169/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9593 - val_loss: 0.0012 - val_accuracy: 0.9808
# Epoch 170/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.6839e-04 - accuracy: 0.9646 - val_loss: 9.2771e-04 - val_accuracy: 0.9808
# Epoch 171/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.2846e-04 - accuracy: 0.9999 - val_loss: 5.3367e-04 - val_accuracy: 0.9808
# Epoch 172/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.0440e-04 - accuracy: 0.9856 - val_loss: 0.0011 - val_accuracy: 0.9615
# Epoch 173/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.7558e-04 - accuracy: 0.9892 - val_loss: 0.0013 - val_accuracy: 0.9808
# Epoch 174/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9919 - val_loss: 7.0360e-04 - val_accuracy: 0.9808
# Epoch 175/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.3477e-04 - accuracy: 0.9648 - val_loss: 0.0013 - val_accuracy: 0.9808
# Epoch 176/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.0983e-04 - accuracy: 0.9824 - val_loss: 5.6642e-04 - val_accuracy: 0.9808
# Epoch 177/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.4223e-04 - accuracy: 1.0000 - val_loss: 4.9124e-04 - val_accuracy: 0.9808
# Epoch 178/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9761 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 179/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9589 - val_loss: 0.0014 - val_accuracy: 0.9615
# Epoch 180/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.6892e-04 - accuracy: 0.9708 - val_loss: 0.0017 - val_accuracy: 0.9808
# Epoch 181/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.5693e-04 - accuracy: 0.9784 - val_loss: 0.0035 - val_accuracy: 0.9231
# Epoch 182/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9690 - val_loss: 6.4598e-04 - val_accuracy: 0.9808
# Epoch 183/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.8077e-04 - accuracy: 0.9878 - val_loss: 3.6487e-04 - val_accuracy: 1.0000
# Epoch 184/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.4781e-04 - accuracy: 0.9873 - val_loss: 4.5073e-04 - val_accuracy: 0.9808
# Epoch 185/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.6449e-04 - accuracy: 0.9996 - val_loss: 4.7436e-04 - val_accuracy: 1.0000
# Epoch 186/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.7181e-04 - accuracy: 0.9993 - val_loss: 4.2800e-04 - val_accuracy: 1.0000
# Epoch 187/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.6496e-04 - accuracy: 0.9815 - val_loss: 7.7586e-04 - val_accuracy: 0.9615
# Epoch 188/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.4570e-04 - accuracy: 0.9890 - val_loss: 3.9667e-04 - val_accuracy: 0.9808
# Epoch 189/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.4742e-04 - accuracy: 0.9915 - val_loss: 0.0019 - val_accuracy: 0.9808
# Epoch 190/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9794 - val_loss: 0.0021 - val_accuracy: 0.9808
# Epoch 191/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.3877e-04 - accuracy: 0.9898 - val_loss: 0.0010 - val_accuracy: 0.9615
# Epoch 192/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9695 - val_loss: 0.0021 - val_accuracy: 0.9423
# Epoch 193/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9803 - val_loss: 0.0012 - val_accuracy: 0.9615
# Epoch 194/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 0.9533 - val_loss: 0.0033 - val_accuracy: 0.9615
# Epoch 195/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 0.9669 - val_loss: 0.0017 - val_accuracy: 0.9808
# Epoch 196/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 0.9601 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 197/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 0.9520 - val_loss: 0.0018 - val_accuracy: 0.9615
# Epoch 198/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9690 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 199/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9610 - val_loss: 0.0018 - val_accuracy: 0.9423
# Epoch 200/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 0.9765 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 201/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.9929e-04 - accuracy: 0.9807 - val_loss: 4.9111e-04 - val_accuracy: 1.0000
# Epoch 202/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.3550e-04 - accuracy: 0.9990 - val_loss: 4.1511e-04 - val_accuracy: 0.9808
# Epoch 203/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.0616e-04 - accuracy: 0.9913 - val_loss: 5.4944e-04 - val_accuracy: 1.0000
# Epoch 204/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.4194e-04 - accuracy: 0.9993 - val_loss: 4.3035e-04 - val_accuracy: 1.0000
# Epoch 205/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.5025e-05 - accuracy: 0.9992 - val_loss: 4.9373e-04 - val_accuracy: 0.9808
# Epoch 206/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.1251e-04 - accuracy: 0.9982 - val_loss: 5.1767e-04 - val_accuracy: 1.0000
# Epoch 207/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.2250e-05 - accuracy: 1.0000 - val_loss: 5.4206e-04 - val_accuracy: 1.0000
# Epoch 208/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.5981e-05 - accuracy: 1.0000 - val_loss: 2.4079e-04 - val_accuracy: 0.9808
# Epoch 209/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.0588e-04 - accuracy: 1.0000 - val_loss: 6.5011e-04 - val_accuracy: 1.0000
# Epoch 210/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.1664e-04 - accuracy: 0.9992 - val_loss: 4.2082e-04 - val_accuracy: 1.0000
# Epoch 211/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.1948e-05 - accuracy: 0.9991 - val_loss: 1.7405e-04 - val_accuracy: 1.0000
# Epoch 212/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.9994e-05 - accuracy: 0.9987 - val_loss: 3.8019e-04 - val_accuracy: 1.0000
# Epoch 213/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.4364e-05 - accuracy: 0.9995 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 214/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.6766e-04 - accuracy: 0.9961 - val_loss: 4.9224e-04 - val_accuracy: 1.0000
# Epoch 215/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.2027e-04 - accuracy: 1.0000 - val_loss: 5.2114e-04 - val_accuracy: 0.9808
# Epoch 216/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.4908e-04 - accuracy: 0.9961 - val_loss: 8.2829e-04 - val_accuracy: 1.0000
# Epoch 217/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.1083e-04 - accuracy: 0.9979 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 218/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.7619e-04 - accuracy: 1.0000 - val_loss: 7.9120e-04 - val_accuracy: 1.0000
# Epoch 219/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.7036e-04 - accuracy: 0.9942 - val_loss: 0.0018 - val_accuracy: 0.9808
# Epoch 220/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.9424e-04 - accuracy: 0.9987 - val_loss: 2.7346e-04 - val_accuracy: 1.0000
# Epoch 221/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.6955e-04 - accuracy: 0.9934 - val_loss: 0.0015 - val_accuracy: 0.9615
# Epoch 222/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 0.9671 - val_loss: 0.0021 - val_accuracy: 0.9615
# Epoch 223/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9829 - val_loss: 0.0024 - val_accuracy: 0.9423
# Epoch 224/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9709 - val_loss: 0.0027 - val_accuracy: 0.9423
# Epoch 225/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.3190e-04 - accuracy: 0.9589 - val_loss: 8.5163e-04 - val_accuracy: 0.9615
# Epoch 226/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.6457e-04 - accuracy: 0.9865 - val_loss: 7.5727e-04 - val_accuracy: 0.9808
# Epoch 227/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.3142e-04 - accuracy: 0.9987 - val_loss: 8.6802e-04 - val_accuracy: 0.9808
# Epoch 228/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.5660e-04 - accuracy: 0.9993 - val_loss: 7.6079e-04 - val_accuracy: 1.0000
# Epoch 229/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.2560e-04 - accuracy: 1.0000 - val_loss: 4.7310e-04 - val_accuracy: 0.9808
# Epoch 230/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.4378e-04 - accuracy: 1.0000 - val_loss: 2.9695e-04 - val_accuracy: 1.0000
# Epoch 231/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.9294e-05 - accuracy: 1.0000 - val_loss: 8.0755e-04 - val_accuracy: 1.0000
# Epoch 232/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.8565e-05 - accuracy: 1.0000 - val_loss: 2.7189e-04 - val_accuracy: 1.0000
# Epoch 233/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.1074e-05 - accuracy: 1.0000 - val_loss: 2.6708e-04 - val_accuracy: 1.0000
# Epoch 234/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.3761e-05 - accuracy: 0.9990 - val_loss: 3.4651e-04 - val_accuracy: 1.0000
# Epoch 235/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.1873e-05 - accuracy: 1.0000 - val_loss: 2.0227e-04 - val_accuracy: 1.0000
# Epoch 236/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.6966e-05 - accuracy: 1.0000 - val_loss: 3.2333e-04 - val_accuracy: 1.0000
# Epoch 237/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.7090e-05 - accuracy: 1.0000 - val_loss: 3.5046e-04 - val_accuracy: 1.0000
# Epoch 238/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.2240e-05 - accuracy: 1.0000 - val_loss: 2.8587e-04 - val_accuracy: 1.0000
# Epoch 239/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.8077e-05 - accuracy: 1.0000 - val_loss: 9.0328e-04 - val_accuracy: 1.0000
# Epoch 240/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.7369e-04 - accuracy: 0.9970 - val_loss: 5.0404e-04 - val_accuracy: 1.0000
# Epoch 241/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.8961e-04 - accuracy: 1.0000 - val_loss: 6.7892e-04 - val_accuracy: 1.0000
# Epoch 242/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.5323e-05 - accuracy: 1.0000 - val_loss: 4.0827e-04 - val_accuracy: 1.0000
# Epoch 243/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.4891e-05 - accuracy: 1.0000 - val_loss: 3.9377e-04 - val_accuracy: 1.0000
# Epoch 244/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.0726e-04 - accuracy: 0.9991 - val_loss: 3.8896e-04 - val_accuracy: 1.0000
# Epoch 245/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.6061e-05 - accuracy: 1.0000 - val_loss: 2.6617e-04 - val_accuracy: 1.0000
# Epoch 246/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.3475e-05 - accuracy: 1.0000 - val_loss: 2.3323e-04 - val_accuracy: 1.0000
# Epoch 247/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.6943e-05 - accuracy: 0.9990 - val_loss: 5.9139e-04 - val_accuracy: 1.0000
# Epoch 248/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.4429e-04 - accuracy: 0.9961 - val_loss: 4.1214e-04 - val_accuracy: 0.9808
# Epoch 249/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.2510e-05 - accuracy: 0.9976 - val_loss: 3.7418e-04 - val_accuracy: 1.0000
# Epoch 250/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.5102e-05 - accuracy: 1.0000 - val_loss: 3.1315e-04 - val_accuracy: 1.0000
# Epoch 251/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.2057e-05 - accuracy: 0.9987 - val_loss: 3.0165e-04 - val_accuracy: 1.0000
# Epoch 252/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.1271e-05 - accuracy: 1.0000 - val_loss: 8.2462e-04 - val_accuracy: 1.0000
# Epoch 253/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9811 - val_loss: 0.0049 - val_accuracy: 0.9231
# Epoch 254/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 0.9745 - val_loss: 0.0055 - val_accuracy: 0.9423
# Epoch 255/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 0.9481 - val_loss: 0.0034 - val_accuracy: 0.9615
# Epoch 256/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9826 - val_loss: 0.0013 - val_accuracy: 0.9615
# Epoch 257/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.4921e-04 - accuracy: 0.9874 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 258/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.2718e-04 - accuracy: 0.9809 - val_loss: 4.7750e-04 - val_accuracy: 1.0000
# Epoch 259/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.1334e-04 - accuracy: 0.9969 - val_loss: 8.1087e-04 - val_accuracy: 0.9615
# Epoch 260/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.3360e-04 - accuracy: 0.9938 - val_loss: 4.6673e-04 - val_accuracy: 1.0000
# Epoch 261/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.5836e-04 - accuracy: 0.9857 - val_loss: 3.2733e-04 - val_accuracy: 1.0000
# Epoch 262/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.2541e-04 - accuracy: 0.9975 - val_loss: 3.9776e-04 - val_accuracy: 1.0000
# Epoch 263/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.9301e-04 - accuracy: 0.9826 - val_loss: 6.7130e-04 - val_accuracy: 0.9808
# Epoch 264/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.7367e-04 - accuracy: 0.9959 - val_loss: 0.0040 - val_accuracy: 0.9038
# Epoch 265/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 0.9593 - val_loss: 0.0022 - val_accuracy: 0.9615
# Epoch 266/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.9608 - val_loss: 9.7495e-04 - val_accuracy: 1.0000
# Epoch 267/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.4784e-04 - accuracy: 0.9892 - val_loss: 0.0019 - val_accuracy: 0.9808
# Epoch 268/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.6389e-04 - accuracy: 0.9892 - val_loss: 5.5813e-04 - val_accuracy: 1.0000
# Epoch 269/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.7760e-04 - accuracy: 0.9933 - val_loss: 7.6728e-04 - val_accuracy: 1.0000
# Epoch 270/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.1720e-04 - accuracy: 0.9991 - val_loss: 5.2268e-04 - val_accuracy: 0.9615
# Epoch 271/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.5947e-04 - accuracy: 0.9916 - val_loss: 6.7209e-04 - val_accuracy: 0.9808
# Epoch 272/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.2565e-04 - accuracy: 0.9988 - val_loss: 4.6909e-04 - val_accuracy: 1.0000
# Epoch 273/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.3207e-04 - accuracy: 1.0000 - val_loss: 3.7526e-04 - val_accuracy: 1.0000
# Epoch 274/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.6637e-05 - accuracy: 0.9958 - val_loss: 2.9741e-04 - val_accuracy: 1.0000
# Epoch 275/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.5799e-05 - accuracy: 1.0000 - val_loss: 5.1700e-04 - val_accuracy: 1.0000
# Epoch 276/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.7903e-05 - accuracy: 0.9980 - val_loss: 5.3123e-04 - val_accuracy: 1.0000
# Epoch 277/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.7072e-05 - accuracy: 1.0000 - val_loss: 4.4061e-04 - val_accuracy: 1.0000
# Epoch 278/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.0002e-05 - accuracy: 1.0000 - val_loss: 3.7433e-04 - val_accuracy: 1.0000
# Epoch 279/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.7606e-05 - accuracy: 1.0000 - val_loss: 4.2183e-04 - val_accuracy: 1.0000
# Epoch 280/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.5999e-05 - accuracy: 1.0000 - val_loss: 4.0054e-04 - val_accuracy: 1.0000
# 2/2 [==============================] - 0s 936us/step - loss: 4.0054e-04 - accuracy: 1.0000
# Loss = 0.0004005357332061976, rmse = 1.0
# Loss array:  [0.0004005357332061976]
# ####################### Iteration   1  #######################
# Epoch 1/280
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3893 - accuracy: 0.6376 - val_loss: 0.0335 - val_accuracy: 0.8654
# Epoch 2/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 0.8396 - val_loss: 0.0086 - val_accuracy: 0.9808
# Epoch 3/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.9181 - val_loss: 0.0063 - val_accuracy: 0.9615
# Epoch 4/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 0.9041 - val_loss: 0.0092 - val_accuracy: 0.9615
# Epoch 5/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.8852 - val_loss: 0.0089 - val_accuracy: 0.9615
# Epoch 6/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9010 - val_loss: 0.0031 - val_accuracy: 0.9615
# Epoch 7/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 0.9537 - val_loss: 0.0043 - val_accuracy: 0.9808
# Epoch 8/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 0.9260 - val_loss: 0.0046 - val_accuracy: 0.9808
# Epoch 9/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 0.8993 - val_loss: 0.0034 - val_accuracy: 0.9808
# Epoch 10/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 0.9565 - val_loss: 0.0023 - val_accuracy: 0.9808
# Epoch 11/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.9470 - val_loss: 0.0028 - val_accuracy: 0.9808
# Epoch 12/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 0.9391 - val_loss: 0.0069 - val_accuracy: 0.9808
# Epoch 13/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 0.9468 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 14/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 0.9658 - val_loss: 0.0046 - val_accuracy: 0.9615
# Epoch 15/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 0.9714 - val_loss: 0.0023 - val_accuracy: 0.9808
# Epoch 16/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9614 - val_loss: 0.0028 - val_accuracy: 0.9808
# Epoch 17/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 0.9585 - val_loss: 0.0022 - val_accuracy: 0.9808
# Epoch 18/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 0.9682 - val_loss: 0.0014 - val_accuracy: 0.9808
# Epoch 19/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9724 - val_loss: 0.0019 - val_accuracy: 0.9808
# Epoch 20/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9752 - val_loss: 0.0014 - val_accuracy: 0.9615
# Epoch 21/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9764 - val_loss: 0.0017 - val_accuracy: 0.9615
# Epoch 22/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.9674 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 23/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9648 - val_loss: 0.0018 - val_accuracy: 0.9808
# Epoch 24/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 0.9622 - val_loss: 0.0036 - val_accuracy: 0.9808
# Epoch 25/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 0.9382 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 26/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 0.9560 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 27/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 0.9803 - val_loss: 0.0013 - val_accuracy: 0.9808
# Epoch 28/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9800 - val_loss: 0.0014 - val_accuracy: 0.9808
# Epoch 29/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 0.9663 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 30/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9532 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 31/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 0.9712 - val_loss: 0.0021 - val_accuracy: 0.9615
# Epoch 32/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9523 - val_loss: 0.0028 - val_accuracy: 0.9808
# Epoch 33/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 0.9476 - val_loss: 0.0041 - val_accuracy: 0.9808
# Epoch 34/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 0.9513 - val_loss: 0.0028 - val_accuracy: 0.9808
# Epoch 35/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 0.9834 - val_loss: 0.0017 - val_accuracy: 0.9808
# Epoch 36/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 0.9497 - val_loss: 0.0012 - val_accuracy: 0.9808
# Epoch 37/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9853 - val_loss: 0.0013 - val_accuracy: 0.9808
# Epoch 38/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.3331e-04 - accuracy: 0.9797 - val_loss: 9.9846e-04 - val_accuracy: 0.9808
# Epoch 39/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9769 - val_loss: 0.0012 - val_accuracy: 0.9808
# Epoch 40/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.8113e-04 - accuracy: 0.9816 - val_loss: 0.0016 - val_accuracy: 0.9808
# Epoch 41/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 0.9716 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 42/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9887 - val_loss: 0.0029 - val_accuracy: 0.9808
# Epoch 43/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9666 - val_loss: 0.0011 - val_accuracy: 0.9808
# Epoch 44/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 0.9522 - val_loss: 0.0021 - val_accuracy: 0.9808
# Epoch 45/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 0.9354 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 46/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9786 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 47/280
# ...
# Epoch 177/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.1318e-04 - accuracy: 0.9999 - val_loss: 3.8779e-04 - val_accuracy: 1.0000
# Epoch 178/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.6204e-04 - accuracy: 1.0000 - val_loss: 6.7881e-04 - val_accuracy: 1.0000
# Epoch 179/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.1853e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 180/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9824 - val_loss: 8.3020e-04 - val_accuracy: 1.0000
# Epoch 181/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 0.9133 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 182/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 0.9820 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 183/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 0.9529 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 184/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9747 - val_loss: 0.0011 - val_accuracy: 0.9608
# Epoch 185/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9832 - val_loss: 7.6920e-04 - val_accuracy: 1.0000
# Epoch 186/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.9103e-04 - accuracy: 0.9806 - val_loss: 5.6252e-04 - val_accuracy: 1.0000
# Epoch 187/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.2958e-04 - accuracy: 0.9977 - val_loss: 5.0784e-04 - val_accuracy: 1.0000
# Epoch 188/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.0061e-04 - accuracy: 0.9997 - val_loss: 4.6084e-04 - val_accuracy: 1.0000
# Epoch 189/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.9004e-04 - accuracy: 0.9959 - val_loss: 8.5327e-04 - val_accuracy: 1.0000
# Epoch 190/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.9898e-04 - accuracy: 0.9880 - val_loss: 3.0539e-04 - val_accuracy: 1.0000
# Epoch 191/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.9817e-04 - accuracy: 0.9950 - val_loss: 5.6022e-04 - val_accuracy: 1.0000
# Epoch 192/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.1224e-04 - accuracy: 1.0000 - val_loss: 3.0573e-04 - val_accuracy: 1.0000
# Epoch 193/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.9465e-04 - accuracy: 0.9898 - val_loss: 6.7309e-04 - val_accuracy: 1.0000
# Epoch 194/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.0334e-04 - accuracy: 0.9763 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 195/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.7063e-04 - accuracy: 0.9913 - val_loss: 0.0011 - val_accuracy: 0.9804
# Epoch 196/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9608 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 197/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.4196e-04 - accuracy: 0.9765 - val_loss: 7.6346e-04 - val_accuracy: 1.0000
# Epoch 198/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.3899e-04 - accuracy: 1.0000 - val_loss: 5.0066e-04 - val_accuracy: 1.0000
# Epoch 199/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.3322e-04 - accuracy: 0.9989 - val_loss: 4.4446e-04 - val_accuracy: 1.0000
# Epoch 200/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.2039e-04 - accuracy: 0.9939 - val_loss: 7.5089e-04 - val_accuracy: 1.0000
# Epoch 201/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.9464e-04 - accuracy: 0.9979 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 202/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 0.9846 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 203/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.2130e-04 - accuracy: 0.9907 - val_loss: 4.1328e-04 - val_accuracy: 1.0000
# Epoch 204/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.0909e-04 - accuracy: 1.0000 - val_loss: 2.5680e-04 - val_accuracy: 1.0000
# Epoch 205/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.4422e-04 - accuracy: 1.0000 - val_loss: 3.1044e-04 - val_accuracy: 1.0000
# Epoch 206/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.9823e-04 - accuracy: 0.9975 - val_loss: 2.3000e-04 - val_accuracy: 1.0000
# Epoch 207/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.8773e-04 - accuracy: 0.9989 - val_loss: 5.8131e-04 - val_accuracy: 1.0000
# Epoch 208/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.5432e-04 - accuracy: 1.0000 - val_loss: 4.9295e-04 - val_accuracy: 1.0000
# Epoch 209/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.3869e-04 - accuracy: 1.0000 - val_loss: 6.3828e-04 - val_accuracy: 1.0000
# Epoch 210/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.0077e-04 - accuracy: 1.0000 - val_loss: 3.3971e-04 - val_accuracy: 1.0000
# Epoch 211/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.1723e-05 - accuracy: 0.9999 - val_loss: 4.1162e-04 - val_accuracy: 1.0000
# Epoch 212/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.2757e-04 - accuracy: 0.9996 - val_loss: 0.0013 - val_accuracy: 0.9804
# Epoch 213/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 0.9729 - val_loss: 8.4193e-04 - val_accuracy: 1.0000
# Epoch 214/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.9440e-04 - accuracy: 0.9968 - val_loss: 7.9004e-04 - val_accuracy: 1.0000
# Epoch 215/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.7088e-04 - accuracy: 0.9844 - val_loss: 9.0326e-04 - val_accuracy: 1.0000
# Epoch 216/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.5394e-04 - accuracy: 0.9756 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 217/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9716 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 218/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 0.9766 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 219/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 0.9702 - val_loss: 4.0169e-04 - val_accuracy: 0.9804
# Epoch 220/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.4810e-04 - accuracy: 0.9895 - val_loss: 4.4736e-04 - val_accuracy: 1.0000
# Epoch 221/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.4082e-04 - accuracy: 0.9958 - val_loss: 3.4087e-04 - val_accuracy: 1.0000
# Epoch 222/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.3678e-04 - accuracy: 0.9996 - val_loss: 3.0945e-04 - val_accuracy: 1.0000
# Epoch 223/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.3868e-04 - accuracy: 1.0000 - val_loss: 2.8833e-04 - val_accuracy: 1.0000
# Epoch 224/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.5804e-05 - accuracy: 1.0000 - val_loss: 4.1170e-04 - val_accuracy: 1.0000
# Epoch 225/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.6922e-04 - accuracy: 0.9980 - val_loss: 6.0369e-04 - val_accuracy: 1.0000
# Epoch 226/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.2032e-04 - accuracy: 0.9828 - val_loss: 2.6332e-04 - val_accuracy: 1.0000
# Epoch 227/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.0077e-04 - accuracy: 1.0000 - val_loss: 3.2163e-04 - val_accuracy: 1.0000
# Epoch 228/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.6814e-05 - accuracy: 0.9996 - val_loss: 1.6024e-04 - val_accuracy: 1.0000
# Epoch 229/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.2870e-05 - accuracy: 1.0000 - val_loss: 2.5253e-04 - val_accuracy: 1.0000
# Epoch 230/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.9113e-05 - accuracy: 1.0000 - val_loss: 1.7368e-04 - val_accuracy: 1.0000
# Epoch 231/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.6648e-05 - accuracy: 1.0000 - val_loss: 1.7575e-04 - val_accuracy: 1.0000
# Epoch 232/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.7534e-05 - accuracy: 0.9983 - val_loss: 2.6735e-04 - val_accuracy: 1.0000
# Epoch 233/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.7072e-05 - accuracy: 1.0000 - val_loss: 1.7254e-04 - val_accuracy: 1.0000
# Epoch 234/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.3712e-04 - accuracy: 1.0000 - val_loss: 3.9056e-04 - val_accuracy: 1.0000
# Epoch 235/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.9371e-05 - accuracy: 1.0000 - val_loss: 1.1339e-04 - val_accuracy: 1.0000
# Epoch 236/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.9561e-05 - accuracy: 1.0000 - val_loss: 1.3721e-04 - val_accuracy: 1.0000
# Epoch 237/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.2281e-04 - accuracy: 1.0000 - val_loss: 1.0232e-04 - val_accuracy: 1.0000
# Epoch 238/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.9525e-05 - accuracy: 0.9990 - val_loss: 2.0106e-04 - val_accuracy: 1.0000
# Epoch 239/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.9801e-05 - accuracy: 1.0000 - val_loss: 1.4963e-04 - val_accuracy: 1.0000
# Epoch 240/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.1740e-04 - accuracy: 1.0000 - val_loss: 1.5375e-04 - val_accuracy: 1.0000
# Epoch 241/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.1459e-04 - accuracy: 0.9938 - val_loss: 1.1048e-04 - val_accuracy: 1.0000
# Epoch 242/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.8954e-05 - accuracy: 1.0000 - val_loss: 2.1330e-04 - val_accuracy: 1.0000
# Epoch 243/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.9002e-04 - accuracy: 0.9989 - val_loss: 8.9820e-04 - val_accuracy: 1.0000
# Epoch 244/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9738 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 245/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 0.9507 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 246/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 0.9563 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 247/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 0.9590 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 248/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.4900e-04 - accuracy: 0.9921 - val_loss: 5.5168e-04 - val_accuracy: 1.0000
# Epoch 249/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.7095e-04 - accuracy: 0.9973 - val_loss: 4.0064e-04 - val_accuracy: 1.0000
# Epoch 250/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.3180e-04 - accuracy: 0.9921 - val_loss: 3.8292e-04 - val_accuracy: 1.0000
# Epoch 251/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.7051e-04 - accuracy: 0.9896 - val_loss: 5.1489e-04 - val_accuracy: 1.0000
# Epoch 252/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.9581e-04 - accuracy: 0.9714 - val_loss: 6.3841e-04 - val_accuracy: 1.0000
# Epoch 253/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.0096e-04 - accuracy: 0.9961 - val_loss: 4.8107e-04 - val_accuracy: 1.0000
# Epoch 254/280
# 47/47 [==============================] - 0s 2ms/step - loss: 2.1675e-04 - accuracy: 0.9989 - val_loss: 3.4100e-04 - val_accuracy: 1.0000
# Epoch 255/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.3906e-04 - accuracy: 0.9993 - val_loss: 4.5808e-04 - val_accuracy: 1.0000
# Epoch 256/280
# 47/47 [==============================] - 0s 2ms/step - loss: 1.5043e-04 - accuracy: 1.0000 - val_loss: 2.6514e-04 - val_accuracy: 1.0000
# Epoch 257/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.3926e-05 - accuracy: 1.0000 - val_loss: 3.1243e-04 - val_accuracy: 1.0000
# Epoch 258/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.1394e-05 - accuracy: 1.0000 - val_loss: 1.6768e-04 - val_accuracy: 1.0000
# Epoch 259/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.8430e-05 - accuracy: 1.0000 - val_loss: 1.4247e-04 - val_accuracy: 1.0000
# Epoch 260/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.5877e-05 - accuracy: 1.0000 - val_loss: 1.4527e-04 - val_accuracy: 1.0000
# Epoch 261/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.9430e-05 - accuracy: 1.0000 - val_loss: 2.4658e-04 - val_accuracy: 1.0000
# Epoch 262/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.4465e-05 - accuracy: 1.0000 - val_loss: 2.0392e-04 - val_accuracy: 1.0000
# Epoch 263/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.9850e-05 - accuracy: 1.0000 - val_loss: 1.7892e-04 - val_accuracy: 1.0000
# Epoch 264/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.1521e-05 - accuracy: 1.0000 - val_loss: 1.2428e-04 - val_accuracy: 1.0000
# Epoch 265/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.4126e-05 - accuracy: 1.0000 - val_loss: 1.2509e-04 - val_accuracy: 1.0000
# Epoch 266/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.1469e-05 - accuracy: 1.0000 - val_loss: 2.5221e-04 - val_accuracy: 1.0000
# Epoch 267/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.8287e-05 - accuracy: 1.0000 - val_loss: 1.1636e-04 - val_accuracy: 1.0000
# Epoch 268/280
# 47/47 [==============================] - 0s 2ms/step - loss: 4.3394e-05 - accuracy: 1.0000 - val_loss: 1.5398e-04 - val_accuracy: 1.0000
# Epoch 269/280
# 47/47 [==============================] - 0s 2ms/step - loss: 7.7277e-05 - accuracy: 1.0000 - val_loss: 1.5586e-04 - val_accuracy: 1.0000
# Epoch 270/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.7953e-05 - accuracy: 1.0000 - val_loss: 1.0369e-04 - val_accuracy: 1.0000
# Epoch 271/280
# 47/47 [==============================] - 0s 2ms/step - loss: 3.5581e-05 - accuracy: 1.0000 - val_loss: 1.8545e-04 - val_accuracy: 1.0000
# Epoch 272/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.2197e-05 - accuracy: 1.0000 - val_loss: 1.9768e-04 - val_accuracy: 1.0000
# Epoch 273/280
# 47/47 [==============================] - 0s 2ms/step - loss: 6.1717e-05 - accuracy: 1.0000 - val_loss: 4.9492e-04 - val_accuracy: 1.0000
# Epoch 274/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 0.9754 - val_loss: 0.0063 - val_accuracy: 0.9804
# Epoch 275/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 0.9812 - val_loss: 0.0022 - val_accuracy: 0.9608
# Epoch 276/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 0.9846 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 277/280
# 47/47 [==============================] - 0s 2ms/step - loss: 9.6879e-04 - accuracy: 0.9644 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 278/280
# 47/47 [==============================] - 0s 2ms/step - loss: 5.3769e-04 - accuracy: 0.9921 - val_loss: 8.2261e-04 - val_accuracy: 1.0000
# Epoch 279/280
# 47/47 [==============================] - 0s 2ms/step - loss: 8.6808e-04 - accuracy: 0.9926 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 280/280
# 47/47 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9864 - val_loss: 9.8118e-04 - val_accuracy: 1.0000
# 2/2 [==============================] - 0s 1ms/step - loss: 9.8118e-04 - accuracy: 1.0000
# Loss = 0.0009811845375224948, rmse = 1.0
# Loss array:  [0.0004005357332061976, 0.00018819698016159236, 0.002182263880968094, 0.0030274437740445137, 0.0011807511327788234, 0.00903567299246788, 0.0002822339884005487, 0.0004707571060862392, 0.00025398549041710794, 0.0009811845375224948]

# %% [markdown]
# # Results
# - Plot of k-cross validation performance
# - Scatter Plot of prediction results against true values

# %%
# Loss across k folds
plot_line(arr_loss, "Loss across k-folds", "Value of k")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Loss curves

# %%
# Training and Validation Loss
plot_loss_curve(history_best_model, NUM_EPOCHS)

# %% [markdown]
# # Prediction on Test Dataset

# %%
# Normalize the test dataset
X_test_norm = scaler_input.transform(X_test)
y_test_norm = scaler_output.transform(y_test)

# %%
import time

start_time = time.time()
Y_pred_normalized = best_model.predict(X_test_norm)
end_time = time.time()
Y_pred_normalized_entire = best_model.predict(dataset_x_norm)
# Calculate elapsed time in seconds
elapsed_time = end_time - start_time
print("Elapsed time:", round(elapsed_time, 3), "seconds")


Y_pred = scaler_output.inverse_transform(Y_pred_normalized)
Y_pred_entire = scaler_output.inverse_transform(Y_pred_normalized_entire)
Y_actual = np.array(y_test)
Y_actual_entire = np.array(df_targets)
# Moisture Content
scatter_plot(trueValues=Y_actual[:,0], 
             predictions=Y_pred[:,0], 
             title="Moisture Content")
a, b = np.polyfit(Y_pred[:, 0], Y_actual[:, 0], 1) # y = ax + b
x_best_fit = np.arange(0, max(max(Y_pred[:,0]), max(Y_actual[:,0])), 1)
plt.plot(x_best_fit, a*x_best_fit + b, c='red', label='Best fit')
plt.legend()
plt.savefig('../Poster/Results/obj_3_MC.svg', dpi=300,
                bbox_inches='tight',
                transparent=True)

# Bulk Density
scatter_plot(trueValues=Y_actual[:,1], 
             predictions=Y_pred[:,1], 
             title="Bulk Density")
plt.xlim([min(min(Y_pred[:,1]), min(Y_actual[:,1]))-0.1, max(max(Y_pred[:,1]), max(Y_actual[:,1]))+0.1])
a, b = np.polyfit(Y_pred[:, 1], Y_actual[:, 1], 1) # y = ax + b
x_best_fit = np.arange(0, max(max(Y_pred[:,1]), max(Y_actual[:,1]))+0.1, 0.1)
plt.plot(x_best_fit, a*x_best_fit + b, c='red', label='Best fit')
plt.legend()
plt.savefig('../Poster/Results/obj_3_BD.svg', dpi=300,
                bbox_inches='tight',
                transparent=True)
# Out:
# Elapsed time: 0.0315 seconds
# Maxval here is:  25.067114
# Maxval here is:  0.9417909

# %% [markdown]
# # Error analysis
# - R squared calculation
# - Mean accuracy error

# %% [markdown]
# Now we will compare with the results from Trabelsi's paper. This is single moisture prediction
#
# R^2 : 0.993\
# Mean Squared Error: 0.028\
# Mean absolute Error: 0.135\
# Min. Absolute Error: 0.004\
# Max Absolute Error: 0.441

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,max_error, r2_score
from sigfig import round

mc_r2_score = r2_score(y_true=Y_actual[:, 0], y_pred=Y_pred[:, 0])
print("R^2: {:#.4g}".format(mc_r2_score))
mse_mc = mean_squared_error(Y_actual[:, 0], Y_pred[:, 0], squared=True)
print('Mean Squared Error: ', "{0:.4g}".format(mse_mc))
mae_mc = mean_absolute_error(Y_actual[:, 0], Y_pred[:, 0])
print('Mean Absolute Error: ', "{0:.4g}".format(mae_mc))

sums = []
for i in range(len(Y_actual[:,0])):
    sum = Y_actual[:,0][i] - Y_pred[:,0][i]
    #print(Y_actual[:,0][i]," - ",Y_pred[:,0][i],'=',sum)
    sums.append(abs(sum))
print("Min Absolute Error: ",min(sums))
print("Max Absolute Error: ",max(sums))
# Out:
# R^2: 0.9973
# Mean Squared Error:  0.03861
# Mean Absolute Error:  0.1328
# Min Absolute Error:  7.041931152329539e-05
# Max Absolute Error:  0.8976951599121108

# %%
mc_r2_score = r2_score(Y_actual_entire[:, 0], Y_pred_entire[:, 0])
print("R^2: {:#.4g}".format(mc_r2_score))
mse_mc = mean_squared_error(Y_actual_entire[:, 0], Y_pred_entire[:, 0], squared=True)
print('Mean Squared Error: ', "{0:.4g}".format(mse_mc))
mae_mc = mean_absolute_error(Y_actual_entire[:, 0], Y_pred_entire[:, 0])
print('Mean Absolute Error: ', "{0:.4g}".format(mae_mc))

sums = []
for i in range(len(Y_actual_entire[:,0])):
    sum = Y_actual_entire[:,0][i] - Y_pred_entire[:,0][i]
    #print(Y_actual[:,0][i]," - ",Y_pred[:,0][i],'=',sum)
    sums.append(abs(sum))
print("Min Absolute Error: ",min(sums))
print("Max Absolute Error: ",max(sums))
# Out:
# R^2: 0.9979
# Mean Squared Error:  0.03033
# Mean Absolute Error:  0.1143
# Min Absolute Error:  7.041931152329539e-05
# Max Absolute Error:  1.3132623672485355
