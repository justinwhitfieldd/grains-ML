# %%
#Import libraries
import requests
import pandas as pd


#Data visualization
import seaborn as sn
import matplotlib.pyplot as plt
import random
#Data Manipulation
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
# Machine Learning
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, Activation
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn.compose import ColumnTransformer
np.random.seed(39)
random.seed(39)
tf.random.set_seed(39)
print(tf.__version__)
# Out:
# 2.4.1

# %%
LEARNING_RATE = 0.00033
EPOCH = 1100
BATCH_SIZE = 8

# %%
#GRAIN_TYPE = 'Wheat'
GRAIN_TYPE = 'Combined_Grains'
FILENAME_BEST_MODEL = 'Best models/target_2/hybrid_models/' + GRAIN_TYPE + 'classifyVariety.h5'
URL = "../../Datasets/processed/" + GRAIN_TYPE + ".csv"
df = pd.read_csv(URL)
# Convert to numpy array
#df = df.groupby('Variety').head(120)
df = df.groupby('Grain Type').head(366)
df_features = df[[ 
                    'Freq', 
                    'd(cm)', 
                  #  'Attn', 
                    'Phase_Corr', 
                    'Permittivity_real', 
                    'Permittivity_imaginary',
                    ]]

df_targets = df[['Grain Type']]
# df_targets = df[['Density', 'M%']]

dataset_x = df_features.to_numpy()
scaler = StandardScaler()
dataset_x = scaler.fit_transform(dataset_x)
dataset_y = df_targets.to_numpy()

# %%
from sklearn.preprocessing import LabelEncoder

# Getting the number of unique varieties
num_varieties = df_targets['Grain Type'].nunique()
varieties = df_targets['Grain Type'].unique()
print(f'There are {num_varieties} different varieties.')

# Encode the 'Grain Type' labels
label_encoder = LabelEncoder()
# Step 1: Convert varieties into number ex. 1 2 3... and store in a single list
integer_encoded = label_encoder.fit_transform(df_targets['Grain Type'])
# Step 2: Get the number of different classes
depth = num_varieties
# Step 3: Pass in the list of numerical values and the number of classes and vectors are created 
#         For example the value 4 would be passed and converted to [0. 0. 0. 0. 1.]
one_hot_encoded = tf.one_hot(integer_encoded, depth)
# Step 4: Convert to numpy arr
y_one_hot = one_hot_encoded.numpy()  # If using TensorFlow's one_hot
# Out:
# There are 5 different varieties.

# %%
'''
Uncomment this to have the dataset split be uniform in test set but not train set, no val included.
'''

# from sklearn.model_selection import train_test_split
# import tensorflow as tf

# # Assume other parts of the code (dataset_x, y_integers, depth) are defined as in previous examples

# # Perform stratified train-test split on the data to maintain class distribution
# X_train, X_temp, y_train_integer, y_temp_integer = train_test_split(
#     dataset_x, integer_encoded, test_size=0.20, stratify=integer_encoded, random_state=42
# )
# # Convert the integer labels back to one-hot encoding for TensorFlow/Keras for the training set
# y_train = tf.one_hot(y_train_integer, depth).numpy()

# # Now create a balanced test set from X_temp and y_temp_integer
# unique_classes = np.unique(y_train_integer)
# samples_per_class = min(np.bincount(y_temp_integer))  # Find the smallest class size in the test set

# # Create a list to store the sampled indices
# indices_to_keep = []

# for cls in unique_classes:
#     # Get the indices for each class
#     class_indices = np.where(y_temp_integer == cls)[0]
#     # Randomly choose 'samples_per_class' indices from each class
#     chosen_indices = np.random.choice(class_indices, size=samples_per_class, replace=False)
#     indices_to_keep.extend(chosen_indices)

# # Use the indices to create the balanced test set
# X_test = X_temp[indices_to_keep]
# y_test_integer = y_temp_integer[indices_to_keep]

# # Convert the integer labels back to one-hot encoding for TensorFlow/Keras for the test set
# y_test = tf.one_hot(y_test_integer, depth).numpy()
# Out:
# '\nUncomment this to have the dataset split be uniform in test set but not train set, no val included.\n'

# %%
# Convert the one-hot encoded labels back to integer encoded labels for stratification
y_integers = np.argmax(y_one_hot, axis=1)

# Perform stratified train-test split on the data
X_train, X_test, y_train_integer, y_test_integer = train_test_split(
    dataset_x, y_integers, test_size=0.20, stratify=y_integers, random_state=42
)

# Convert the integer labels back to one-hot encoding for TensorFlow/Keras
y_train = tf.one_hot(y_train_integer, depth).numpy()
y_test = tf.one_hot(y_test_integer, depth).numpy()

# # Stratified split for the validation set
# X_train, X_val, y_train_integer, y_val_integer = train_test_split(
#     X_trainVal, y_trainVal_integer, test_size=0.15, stratify=y_trainVal_integer, random_state=42
# )

# Convert the integer labels back to one-hot encoding for TensorFlow/Keras
y_train = tf.one_hot(y_train_integer, depth).numpy()
y_val = tf.one_hot(y_val_integer, depth).numpy()

# %%
def print_dataset_split(y_train_integer,y_test_integer):
    # Create a DataFrame for the training set class distribution
    train_counts = pd.DataFrame({
        'Class Name': label_encoder.inverse_transform(np.unique(y_train_integer)),
        'Train': np.bincount(y_train_integer)
    })

    # Create a DataFrame for the balanced test set class distribution
    test_counts = pd.DataFrame({
        'Class Name': label_encoder.inverse_transform(np.unique(y_test_integer)),
        'Test': np.bincount(y_test_integer)
    })
    # val_counts = pd.DataFrame({
    #     'Class Name': label_encoder.inverse_transform(np.unique(y_val_integer)),
    #     'Val': np.bincount(y_val_integer)
    # })
    # Merge the two DataFrames on Class Name
    acombined_counts = pd.merge(train_counts, test_counts, on='Class Name', how='outer').fillna(0)
    # acombined_counts = pd.merge(combined_counts, val_counts, on='Class Name', how='outer').fillna(0)
    # Converts to integer type
    acombined_counts['Train'] = acombined_counts['Train'].astype(int)
    acombined_counts['Test'] = acombined_counts['Test'].astype(int)
    # acombined_counts['Val'] = acombined_counts['Val'].astype(int)

    # Set display options for pandas
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 1000)
    pd.set_option('display.colheader_justify', 'center')
    pd.set_option('display.precision', 3)

    # Print combined class counts in a tabular format
    print(acombined_counts.to_string(index=False, justify='right'))
print_dataset_split(y_train_integer,y_test_integer)
# Out:
# Class Name  Train  Test
#     Barley    293    73
#       Corn    293    73
#       Oats    293    73
#    Sorghum    292    74
#      Wheat    293    73

# %%
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2

# Define model
model = tf.keras.Sequential([
    Dense(256, activation='relu'),
    
    Dense(256, activation='relu'),
    
    Dense(256, activation='relu'),
    
    Dense(5, activation='softmax')  # Changed to softmax for multi-class
])

# Compile model with per-class precision and recall
metrics = ['accuracy']  # General accuracy for all classes

# Add precision and recall for each class
for i in range(depth):
    metrics.append(tf.keras.metrics.Precision(class_id=i, name=f'precision_class_{i}'))
    metrics.append(tf.keras.metrics.Recall(class_id=i, name=f'recall_class_{i}'))

model.compile(
    loss='categorical_crossentropy',  # Correct loss for multi-class classification
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),  
    metrics=metrics
)
history = model.fit(X_train, y_train, epochs=EPOCH, batch_size=BATCH_SIZE)
model.save(FILENAME_BEST_MODEL)
# Out:
# Epoch 1/800
# 183/183 [==============================] - 1s 754us/step - loss: 1.3022 - accuracy: 0.4546 - precision_class_0: 0.4231 - recall_class_0: 0.0219 - precision_class_1: 0.8250 - recall_class_1: 0.2591 - precision_class_2: 0.7555 - recall_class_2: 0.4429 - precision_class_3: 0.1653 - recall_class_3: 0.0067 - precision_class_4: 0.0000e+00 - recall_class_4: 0.0000e+00
# Epoch 2/800
# 183/183 [==============================] - 0s 710us/step - loss: 0.9240 - accuracy: 0.5717 - precision_class_0: 0.7686 - recall_class_0: 0.3620 - precision_class_1: 0.8526 - recall_class_1: 0.3600 - precision_class_2: 0.8883 - recall_class_2: 0.9330 - precision_class_3: 0.8396 - recall_class_3: 0.2727 - precision_class_4: 0.1087 - recall_class_4: 0.0011
# Epoch 3/800
# 183/183 [==============================] - 0s 733us/step - loss: 0.7819 - accuracy: 0.6578 - precision_class_0: 0.8030 - recall_class_0: 0.5513 - precision_class_1: 0.9118 - recall_class_1: 0.4624 - precision_class_2: 0.9570 - recall_class_2: 0.9447 - precision_class_3: 0.8380 - recall_class_3: 0.3673 - precision_class_4: 0.2666 - recall_class_4: 0.0050
# Epoch 4/800
# 183/183 [==============================] - 0s 729us/step - loss: 0.7044 - accuracy: 0.7024 - precision_class_0: 0.8236 - recall_class_0: 0.6364 - precision_class_1: 0.9125 - recall_class_1: 0.4674 - precision_class_2: 0.9563 - recall_class_2: 0.9334 - precision_class_3: 0.7996 - recall_class_3: 0.5726 - precision_class_4: 0.6724 - recall_class_4: 0.0639
# Epoch 5/800
# 183/183 [==============================] - 0s 750us/step - loss: 0.6498 - accuracy: 0.7154 - precision_class_0: 0.8864 - recall_class_0: 0.6187 - precision_class_1: 0.9144 - recall_class_1: 0.4740 - precision_class_2: 0.9813 - recall_class_2: 0.9654 - precision_class_3: 0.8457 - recall_class_3: 0.5531 - precision_class_4: 0.7249 - recall_class_4: 0.1059
# Epoch 6/800
# 183/183 [==============================] - 0s 727us/step - loss: 0.5775 - accuracy: 0.7450 - precision_class_0: 0.8655 - recall_class_0: 0.6113 - precision_class_1: 0.8406 - recall_class_1: 0.5663 - precision_class_2: 0.9719 - recall_class_2: 0.9774 - precision_class_3: 0.8521 - recall_class_3: 0.7069 - precision_class_4: 0.6626 - recall_class_4: 0.1848
# Epoch 7/800
# 183/183 [==============================] - 0s 716us/step - loss: 0.5539 - accuracy: 0.7438 - precision_class_0: 0.8646 - recall_class_0: 0.6741 - precision_class_1: 0.8937 - recall_class_1: 0.5860 - precision_class_2: 1.0000 - recall_class_2: 0.9783 - precision_class_3: 0.8414 - recall_class_3: 0.7218 - precision_class_4: 0.6634 - recall_class_4: 0.2938
# Epoch 8/800
# 183/183 [==============================] - 0s 696us/step - loss: 0.5520 - accuracy: 0.7592 - precision_class_0: 0.9011 - recall_class_0: 0.6480 - precision_class_1: 0.9068 - recall_class_1: 0.6136 - precision_class_2: 0.9941 - recall_class_2: 0.9798 - precision_class_3: 0.8075 - recall_class_3: 0.6912 - precision_class_4: 0.5273 - recall_class_4: 0.3485
# Epoch 9/800
# 183/183 [==============================] - 0s 730us/step - loss: 0.5100 - accuracy: 0.7921 - precision_class_0: 0.8799 - recall_class_0: 0.6416 - precision_class_1: 0.8778 - recall_class_1: 0.6012 - precision_class_2: 0.9880 - recall_class_2: 0.9926 - precision_class_3: 0.8866 - recall_class_3: 0.7940 - precision_class_4: 0.6668 - recall_class_4: 0.3417
# Epoch 10/800
# 183/183 [==============================] - 0s 729us/step - loss: 0.4958 - accuracy: 0.7794 - precision_class_0: 0.8406 - recall_class_0: 0.7620 - precision_class_1: 0.8754 - recall_class_1: 0.6389 - precision_class_2: 0.9911 - recall_class_2: 0.9907 - precision_class_3: 0.8255 - recall_class_3: 0.7342 - precision_class_4: 0.6736 - recall_class_4: 0.3586
# Epoch 11/800
# 183/183 [==============================] - 0s 706us/step - loss: 0.4787 - accuracy: 0.7955 - precision_class_0: 0.8727 - recall_class_0: 0.6776 - precision_class_1: 0.9060 - recall_class_1: 0.6674 - precision_class_2: 0.9689 - recall_class_2: 0.9865 - precision_class_3: 0.8412 - recall_class_3: 0.7670 - precision_class_4: 0.7262 - recall_class_4: 0.4279
# Epoch 12/800
# 183/183 [==============================] - 0s 694us/step - loss: 0.4309 - accuracy: 0.8003 - precision_class_0: 0.8712 - recall_class_0: 0.7771 - precision_class_1: 0.8801 - recall_class_1: 0.7072 - precision_class_2: 0.9940 - recall_class_2: 1.0000 - precision_class_3: 0.8577 - recall_class_3: 0.7583 - precision_class_4: 0.6582 - recall_class_4: 0.3866
# Epoch 13/800
# 183/183 [==============================] - 0s 705us/step - loss: 0.4338 - accuracy: 0.8032 - precision_class_0: 0.8748 - recall_class_0: 0.6773 - precision_class_1: 0.8881 - recall_class_1: 0.7043 - precision_class_2: 1.0000 - recall_class_2: 0.9895 - precision_class_3: 0.8596 - recall_class_3: 0.7826 - precision_class_4: 0.6646 - recall_class_4: 0.4692
# Epoch 14/800
# 183/183 [==============================] - 0s 715us/step - loss: 0.3960 - accuracy: 0.8280 - precision_class_0: 0.8984 - recall_class_0: 0.7090 - precision_class_1: 0.8676 - recall_class_1: 0.7771 - precision_class_2: 0.9999 - recall_class_2: 1.0000 - precision_class_3: 0.8152 - recall_class_3: 0.7930 - precision_class_4: 0.7582 - recall_class_4: 0.5550
# Epoch 15/800
# 183/183 [==============================] - 0s 867us/step - loss: 0.3908 - accuracy: 0.8330 - precision_class_0: 0.9027 - recall_class_0: 0.6902 - precision_class_1: 0.9347 - recall_class_1: 0.9101 - precision_class_2: 0.9858 - recall_class_2: 0.9875 - precision_class_3: 0.8773 - recall_class_3: 0.7857 - precision_class_4: 0.7588 - recall_class_4: 0.5467
# Epoch 16/800
# 183/183 [==============================] - 0s 738us/step - loss: 0.3537 - accuracy: 0.8609 - precision_class_0: 0.8862 - recall_class_0: 0.7926 - precision_class_1: 0.9214 - recall_class_1: 0.8567 - precision_class_2: 0.9938 - recall_class_2: 0.9946 - precision_class_3: 0.8641 - recall_class_3: 0.7601 - precision_class_4: 0.7597 - recall_class_4: 0.5235
# Epoch 17/800
# 183/183 [==============================] - 0s 707us/step - loss: 0.3656 - accuracy: 0.8437 - precision_class_0: 0.8601 - recall_class_0: 0.8299 - precision_class_1: 0.8888 - recall_class_1: 0.8530 - precision_class_2: 0.9963 - recall_class_2: 1.0000 - precision_class_3: 0.8725 - recall_class_3: 0.7805 - precision_class_4: 0.7609 - recall_class_4: 0.5442
# Epoch 18/800
# 183/183 [==============================] - 0s 696us/step - loss: 0.3555 - accuracy: 0.8496 - precision_class_0: 0.8551 - recall_class_0: 0.7659 - precision_class_1: 0.9041 - recall_class_1: 0.8664 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.8738 - recall_class_3: 0.7698 - precision_class_4: 0.7171 - recall_class_4: 0.6414
# Epoch 19/800
# 183/183 [==============================] - 0s 699us/step - loss: 0.3357 - accuracy: 0.8394 - precision_class_0: 0.8767 - recall_class_0: 0.7598 - precision_class_1: 0.8983 - recall_class_1: 0.9117 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.8363 - recall_class_3: 0.7343 - precision_class_4: 0.7535 - recall_class_4: 0.6352
# Epoch 20/800
# 183/183 [==============================] - 0s 708us/step - loss: 0.2978 - accuracy: 0.8716 - precision_class_0: 0.8571 - recall_class_0: 0.8235 - precision_class_1: 0.9401 - recall_class_1: 0.9168 - precision_class_2: 0.9964 - recall_class_2: 0.9967 - precision_class_3: 0.9058 - recall_class_3: 0.7811 - precision_class_4: 0.8496 - recall_class_4: 0.6399
# Epoch 21/800
# 183/183 [==============================] - 0s 699us/step - loss: 0.2949 - accuracy: 0.8883 - precision_class_0: 0.8492 - recall_class_0: 0.8371 - precision_class_1: 0.9270 - recall_class_1: 0.9337 - precision_class_2: 0.9998 - recall_class_2: 1.0000 - precision_class_3: 0.9047 - recall_class_3: 0.8135 - precision_class_4: 0.8463 - recall_class_4: 0.7064
# Epoch 22/800
# 183/183 [==============================] - 0s 698us/step - loss: 0.2904 - accuracy: 0.8790 - precision_class_0: 0.8838 - recall_class_0: 0.8070 - precision_class_1: 0.9199 - recall_class_1: 0.9296 - precision_class_2: 0.9946 - recall_class_2: 0.9831 - precision_class_3: 0.8819 - recall_class_3: 0.8240 - precision_class_4: 0.8007 - recall_class_4: 0.7419
# Epoch 23/800
# 183/183 [==============================] - 0s 706us/step - loss: 0.2889 - accuracy: 0.8771 - precision_class_0: 0.8944 - recall_class_0: 0.8078 - precision_class_1: 0.9264 - recall_class_1: 0.9047 - precision_class_2: 0.9938 - recall_class_2: 1.0000 - precision_class_3: 0.8488 - recall_class_3: 0.8331 - precision_class_4: 0.8009 - recall_class_4: 0.6804
# Epoch 24/800
# 183/183 [==============================] - 0s 705us/step - loss: 0.2564 - accuracy: 0.8948 - precision_class_0: 0.9128 - recall_class_0: 0.8422 - precision_class_1: 0.9326 - recall_class_1: 0.9211 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.8624 - recall_class_3: 0.8497 - precision_class_4: 0.8352 - recall_class_4: 0.7446
# Epoch 25/800
# 183/183 [==============================] - 0s 708us/step - loss: 0.2643 - accuracy: 0.8912 - precision_class_0: 0.9399 - recall_class_0: 0.8290 - precision_class_1: 0.9333 - recall_class_1: 0.9186 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.8977 - recall_class_3: 0.8226 - precision_class_4: 0.7964 - recall_class_4: 0.7745
# Epoch 26/800
# 183/183 [==============================] - 0s 697us/step - loss: 0.2770 - accuracy: 0.8918 - precision_class_0: 0.9471 - recall_class_0: 0.7774 - precision_class_1: 0.9360 - recall_class_1: 0.9073 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9111 - recall_class_3: 0.8515 - precision_class_4: 0.8081 - recall_class_4: 0.7793
# Epoch 27/800
# 183/183 [==============================] - 0s 716us/step - loss: 0.2501 - accuracy: 0.9029 - precision_class_0: 0.9057 - recall_class_0: 0.8108 - precision_class_1: 0.9497 - recall_class_1: 0.9364 - precision_class_2: 0.9809 - recall_class_2: 0.9759 - precision_class_3: 0.9488 - recall_class_3: 0.8974 - precision_class_4: 0.8130 - recall_class_4: 0.8247
# Epoch 28/800
# 183/183 [==============================] - 0s 729us/step - loss: 0.2630 - accuracy: 0.8962 - precision_class_0: 0.8885 - recall_class_0: 0.8215 - precision_class_1: 0.9407 - recall_class_1: 0.9403 - precision_class_2: 0.9901 - recall_class_2: 0.9858 - precision_class_3: 0.8896 - recall_class_3: 0.8829 - precision_class_4: 0.8113 - recall_class_4: 0.7651
# Epoch 29/800
# 183/183 [==============================] - 0s 710us/step - loss: 0.2383 - accuracy: 0.9048 - precision_class_0: 0.9238 - recall_class_0: 0.8499 - precision_class_1: 0.9435 - recall_class_1: 0.9132 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.8928 - recall_class_3: 0.8544 - precision_class_4: 0.8309 - recall_class_4: 0.8150
# Epoch 30/800
# 183/183 [==============================] - 0s 718us/step - loss: 0.2293 - accuracy: 0.9155 - precision_class_0: 0.9436 - recall_class_0: 0.8093 - precision_class_1: 0.9488 - recall_class_1: 0.9726 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9394 - recall_class_3: 0.8547 - precision_class_4: 0.7949 - recall_class_4: 0.8037
# Epoch 31/800
# 183/183 [==============================] - 0s 707us/step - loss: 0.2290 - accuracy: 0.8971 - precision_class_0: 0.9506 - recall_class_0: 0.8112 - precision_class_1: 0.9383 - recall_class_1: 0.9007 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9333 - recall_class_3: 0.8628 - precision_class_4: 0.7811 - recall_class_4: 0.8504
# Epoch 32/800
# 183/183 [==============================] - 0s 713us/step - loss: 0.2053 - accuracy: 0.9127 - precision_class_0: 0.9630 - recall_class_0: 0.8551 - precision_class_1: 0.9499 - recall_class_1: 0.9650 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9117 - recall_class_3: 0.8303 - precision_class_4: 0.8328 - recall_class_4: 0.8445
# Epoch 33/800
# 183/183 [==============================] - 0s 695us/step - loss: 0.1911 - accuracy: 0.9188 - precision_class_0: 0.9262 - recall_class_0: 0.8461 - precision_class_1: 0.9411 - recall_class_1: 0.9663 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9412 - recall_class_3: 0.9219 - precision_class_4: 0.8414 - recall_class_4: 0.8171
# Epoch 34/800
# 183/183 [==============================] - 0s 713us/step - loss: 0.2624 - accuracy: 0.8933 - precision_class_0: 0.8956 - recall_class_0: 0.8173 - precision_class_1: 0.9227 - recall_class_1: 0.8920 - precision_class_2: 0.9987 - recall_class_2: 0.9991 - precision_class_3: 0.8913 - recall_class_3: 0.8767 - precision_class_4: 0.8075 - recall_class_4: 0.7839
# Epoch 35/800
# 183/183 [==============================] - 0s 714us/step - loss: 0.2047 - accuracy: 0.9162 - precision_class_0: 0.9300 - recall_class_0: 0.8186 - precision_class_1: 0.9714 - recall_class_1: 0.9436 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9398 - recall_class_3: 0.9138 - precision_class_4: 0.7978 - recall_class_4: 0.8500
# Epoch 36/800
# 183/183 [==============================] - 0s 910us/step - loss: 0.1902 - accuracy: 0.9186 - precision_class_0: 0.9316 - recall_class_0: 0.8256 - precision_class_1: 0.9578 - recall_class_1: 0.9548 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9525 - recall_class_3: 0.9053 - precision_class_4: 0.8179 - recall_class_4: 0.8552
# Epoch 37/800
# 183/183 [==============================] - 0s 747us/step - loss: 0.2187 - accuracy: 0.9098 - precision_class_0: 0.9331 - recall_class_0: 0.8563 - precision_class_1: 0.9776 - recall_class_1: 0.9240 - precision_class_2: 0.9997 - recall_class_2: 1.0000 - precision_class_3: 0.9208 - recall_class_3: 0.8672 - precision_class_4: 0.8086 - recall_class_4: 0.8018
# Epoch 38/800
# 183/183 [==============================] - 0s 726us/step - loss: 0.1914 - accuracy: 0.9218 - precision_class_0: 0.9395 - recall_class_0: 0.8337 - precision_class_1: 0.9587 - recall_class_1: 0.9333 - precision_class_2: 1.0000 - recall_class_2: 0.9898 - precision_class_3: 0.9702 - recall_class_3: 0.9294 - precision_class_4: 0.8015 - recall_class_4: 0.8454
# Epoch 39/800
# 183/183 [==============================] - 0s 685us/step - loss: 0.1802 - accuracy: 0.9253 - precision_class_0: 0.9570 - recall_class_0: 0.8284 - precision_class_1: 0.9548 - recall_class_1: 0.9513 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9558 - recall_class_3: 0.9267 - precision_class_4: 0.8160 - recall_class_4: 0.8761
# Epoch 40/800
# 183/183 [==============================] - 0s 694us/step - loss: 0.1977 - accuracy: 0.9205 - precision_class_0: 0.9604 - recall_class_0: 0.8424 - precision_class_1: 0.9434 - recall_class_1: 0.9444 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9119 - recall_class_3: 0.8805 - precision_class_4: 0.8532 - recall_class_4: 0.8607
# Epoch 41/800
# 183/183 [==============================] - 0s 705us/step - loss: 0.1968 - accuracy: 0.9171 - precision_class_0: 0.9236 - recall_class_0: 0.8130 - precision_class_1: 0.9570 - recall_class_1: 0.9805 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9691 - recall_class_3: 0.9112 - precision_class_4: 0.8003 - recall_class_4: 0.8268
# Epoch 42/800
# 183/183 [==============================] - 0s 723us/step - loss: 0.1870 - accuracy: 0.9212 - precision_class_0: 0.9294 - recall_class_0: 0.8711 - precision_class_1: 0.9360 - recall_class_1: 0.9339 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9416 - recall_class_3: 0.8687 - precision_class_4: 0.8440 - recall_class_4: 0.8717
# Epoch 43/800
# 183/183 [==============================] - 0s 715us/step - loss: 0.1728 - accuracy: 0.9313 - precision_class_0: 0.9396 - recall_class_0: 0.8643 - precision_class_1: 0.9595 - recall_class_1: 0.9630 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9758 - recall_class_3: 0.8973 - precision_class_4: 0.8387 - recall_class_4: 0.8889
# Epoch 44/800
# 183/183 [==============================] - 0s 741us/step - loss: 0.2013 - accuracy: 0.9118 - precision_class_0: 0.9412 - recall_class_0: 0.8376 - precision_class_1: 0.9581 - recall_class_1: 0.9562 - precision_class_2: 0.9755 - recall_class_2: 0.9767 - precision_class_3: 0.9337 - recall_class_3: 0.8965 - precision_class_4: 0.8005 - recall_class_4: 0.8215
# Epoch 45/800
# 183/183 [==============================] - 0s 746us/step - loss: 0.1984 - accuracy: 0.9254 - precision_class_0: 0.9386 - recall_class_0: 0.8317 - precision_class_1: 0.9678 - recall_class_1: 0.9565 - precision_class_2: 0.9789 - recall_class_2: 0.9856 - precision_class_3: 0.9422 - recall_class_3: 0.9006 - precision_class_4: 0.8271 - recall_class_4: 0.9017
# Epoch 46/800
# 183/183 [==============================] - 0s 682us/step - loss: 0.1880 - accuracy: 0.9224 - precision_class_0: 0.9798 - recall_class_0: 0.8346 - precision_class_1: 0.9520 - recall_class_1: 0.9346 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9295 - recall_class_3: 0.8954 - precision_class_4: 0.8165 - recall_class_4: 0.8810
# Epoch 47/800
# 183/183 [==============================] - 0s 707us/step - loss: 0.1530 - accuracy: 0.9380 - precision_class_0: 0.9598 - recall_class_0: 0.8692 - precision_class_1: 0.9663 - recall_class_1: 0.9506 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9358 - recall_class_3: 0.9328 - precision_class_4: 0.8581 - recall_class_4: 0.8393
# Epoch 48/800
# 183/183 [==============================] - 0s 699us/step - loss: 0.1687 - accuracy: 0.9284 - precision_class_0: 0.9314 - recall_class_0: 0.8517 - precision_class_1: 0.9630 - recall_class_1: 0.9631 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9452 - recall_class_3: 0.8957 - precision_class_4: 0.8368 - recall_class_4: 0.8630
# Epoch 49/800
# 183/183 [==============================] - 0s 733us/step - loss: 0.1655 - accuracy: 0.9344 - precision_class_0: 0.9517 - recall_class_0: 0.8357 - precision_class_1: 0.9598 - recall_class_1: 0.9587 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9614 - recall_class_3: 0.9077 - precision_class_4: 0.8460 - recall_class_4: 0.9228
# Epoch 50/800
# 183/183 [==============================] - 0s 709us/step - loss: 0.1735 - accuracy: 0.9165 - precision_class_0: 0.9137 - recall_class_0: 0.8261 - precision_class_1: 0.9519 - recall_class_1: 0.9635 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9531 - recall_class_3: 0.9122 - precision_class_4: 0.8080 - recall_class_4: 0.8485
# Epoch 51/800
# 183/183 [==============================] - 0s 712us/step - loss: 0.1435 - accuracy: 0.9388 - precision_class_0: 0.9617 - recall_class_0: 0.8696 - precision_class_1: 0.9702 - recall_class_1: 0.9499 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9496 - recall_class_3: 0.9320 - precision_class_4: 0.8598 - recall_class_4: 0.8882
# Epoch 52/800
# 183/183 [==============================] - 0s 703us/step - loss: 0.1513 - accuracy: 0.9430 - precision_class_0: 0.9557 - recall_class_0: 0.8822 - precision_class_1: 0.9758 - recall_class_1: 0.9392 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9669 - recall_class_3: 0.9257 - precision_class_4: 0.8481 - recall_class_4: 0.9174
# Epoch 53/800
# 183/183 [==============================] - 0s 896us/step - loss: 0.1377 - accuracy: 0.9425 - precision_class_0: 0.9558 - recall_class_0: 0.8590 - precision_class_1: 0.9857 - recall_class_1: 0.9625 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9605 - recall_class_3: 0.9127 - precision_class_4: 0.8477 - recall_class_4: 0.9382
# Epoch 54/800
# 183/183 [==============================] - 0s 749us/step - loss: 0.1596 - accuracy: 0.9264 - precision_class_0: 0.9226 - recall_class_0: 0.8709 - precision_class_1: 0.9618 - recall_class_1: 0.9521 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9568 - recall_class_3: 0.9056 - precision_class_4: 0.8409 - recall_class_4: 0.8342
# Epoch 55/800
# 183/183 [==============================] - 0s 696us/step - loss: 0.1410 - accuracy: 0.9424 - precision_class_0: 0.9530 - recall_class_0: 0.8752 - precision_class_1: 0.9723 - recall_class_1: 0.9559 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9640 - recall_class_3: 0.9049 - precision_class_4: 0.8656 - recall_class_4: 0.9434
# Epoch 56/800
# 183/183 [==============================] - 0s 717us/step - loss: 0.1407 - accuracy: 0.9368 - precision_class_0: 0.9675 - recall_class_0: 0.8772 - precision_class_1: 0.9613 - recall_class_1: 0.9440 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9534 - recall_class_3: 0.9157 - precision_class_4: 0.8405 - recall_class_4: 0.9041
# Epoch 57/800
# 183/183 [==============================] - 0s 727us/step - loss: 0.1439 - accuracy: 0.9374 - precision_class_0: 0.9583 - recall_class_0: 0.8575 - precision_class_1: 0.9763 - recall_class_1: 0.9574 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9350 - recall_class_3: 0.9484 - precision_class_4: 0.8486 - recall_class_4: 0.8904
# Epoch 58/800
# 183/183 [==============================] - 0s 685us/step - loss: 0.1556 - accuracy: 0.9348 - precision_class_0: 0.9217 - recall_class_0: 0.8750 - precision_class_1: 0.9775 - recall_class_1: 0.9518 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9247 - recall_class_3: 0.9295 - precision_class_4: 0.8553 - recall_class_4: 0.8742
# Epoch 59/800
# 183/183 [==============================] - 0s 698us/step - loss: 0.1468 - accuracy: 0.9343 - precision_class_0: 0.9738 - recall_class_0: 0.8718 - precision_class_1: 0.9615 - recall_class_1: 0.9539 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9644 - recall_class_3: 0.9268 - precision_class_4: 0.8535 - recall_class_4: 0.8861
# Epoch 60/800
# 183/183 [==============================] - 0s 731us/step - loss: 0.1217 - accuracy: 0.9526 - precision_class_0: 0.9756 - recall_class_0: 0.8903 - precision_class_1: 0.9715 - recall_class_1: 0.9589 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9624 - recall_class_3: 0.9516 - precision_class_4: 0.8844 - recall_class_4: 0.9277
# Epoch 61/800
# 183/183 [==============================] - 0s 733us/step - loss: 0.1357 - accuracy: 0.9403 - precision_class_0: 0.9434 - recall_class_0: 0.8398 - precision_class_1: 0.9765 - recall_class_1: 0.9673 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9464 - recall_class_3: 0.9233 - precision_class_4: 0.8481 - recall_class_4: 0.9108
# Epoch 62/800
# 183/183 [==============================] - 0s 710us/step - loss: 0.1261 - accuracy: 0.9434 - precision_class_0: 0.9497 - recall_class_0: 0.8766 - precision_class_1: 0.9674 - recall_class_1: 0.9719 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9749 - recall_class_3: 0.9414 - precision_class_4: 0.8493 - recall_class_4: 0.9034
# Epoch 63/800
# 183/183 [==============================] - 0s 698us/step - loss: 0.1296 - accuracy: 0.9405 - precision_class_0: 0.9586 - recall_class_0: 0.8877 - precision_class_1: 0.9674 - recall_class_1: 0.9572 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9766 - recall_class_3: 0.9291 - precision_class_4: 0.8425 - recall_class_4: 0.8916
# Epoch 64/800
# 183/183 [==============================] - 0s 710us/step - loss: 0.1254 - accuracy: 0.9421 - precision_class_0: 0.9348 - recall_class_0: 0.8617 - precision_class_1: 0.9730 - recall_class_1: 0.9642 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9790 - recall_class_3: 0.9260 - precision_class_4: 0.8469 - recall_class_4: 0.9318
# Epoch 65/800
# 183/183 [==============================] - 0s 706us/step - loss: 0.1468 - accuracy: 0.9267 - precision_class_0: 0.9513 - recall_class_0: 0.8722 - precision_class_1: 0.9459 - recall_class_1: 0.9559 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9404 - recall_class_3: 0.8997 - precision_class_4: 0.8510 - recall_class_4: 0.8821
# Epoch 66/800
# 183/183 [==============================] - 0s 720us/step - loss: 0.1220 - accuracy: 0.9487 - precision_class_0: 0.9495 - recall_class_0: 0.8790 - precision_class_1: 0.9794 - recall_class_1: 0.9742 - precision_class_2: 0.9889 - recall_class_2: 0.9883 - precision_class_3: 0.9730 - recall_class_3: 0.9500 - precision_class_4: 0.8712 - recall_class_4: 0.9039
# Epoch 67/800
# 183/183 [==============================] - 0s 707us/step - loss: 0.2498 - accuracy: 0.9186 - precision_class_0: 0.9301 - recall_class_0: 0.8221 - precision_class_1: 0.9470 - recall_class_1: 0.9448 - precision_class_2: 0.9318 - recall_class_2: 0.9626 - precision_class_3: 0.9555 - recall_class_3: 0.9211 - precision_class_4: 0.8630 - recall_class_4: 0.9260
# Epoch 68/800
# 183/183 [==============================] - 0s 891us/step - loss: 0.1220 - accuracy: 0.9493 - precision_class_0: 0.9468 - recall_class_0: 0.8917 - precision_class_1: 0.9765 - recall_class_1: 0.9621 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9585 - recall_class_3: 0.9168 - precision_class_4: 0.8698 - recall_class_4: 0.9310
# Epoch 69/800
# 183/183 [==============================] - 0s 735us/step - loss: 0.1230 - accuracy: 0.9442 - precision_class_0: 0.9426 - recall_class_0: 0.8710 - precision_class_1: 0.9620 - recall_class_1: 0.9910 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9841 - recall_class_3: 0.9432 - precision_class_4: 0.8535 - recall_class_4: 0.9026
# Epoch 70/800
# 183/183 [==============================] - 0s 721us/step - loss: 0.1201 - accuracy: 0.9523 - precision_class_0: 0.9614 - recall_class_0: 0.9008 - precision_class_1: 0.9559 - recall_class_1: 0.9718 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9746 - recall_class_3: 0.9443 - precision_class_4: 0.8880 - recall_class_4: 0.9069
# Epoch 71/800
# 183/183 [==============================] - 0s 724us/step - loss: 0.1201 - accuracy: 0.9442 - precision_class_0: 0.9484 - recall_class_0: 0.8769 - precision_class_1: 0.9694 - recall_class_1: 0.9640 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9570 - recall_class_3: 0.9542 - precision_class_4: 0.8497 - recall_class_4: 0.8838
# Epoch 72/800
# 183/183 [==============================] - 0s 712us/step - loss: 0.1515 - accuracy: 0.9361 - precision_class_0: 0.9330 - recall_class_0: 0.8976 - precision_class_1: 0.9621 - recall_class_1: 0.9615 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9550 - recall_class_3: 0.9469 - precision_class_4: 0.8382 - recall_class_4: 0.8437
# Epoch 73/800
# 183/183 [==============================] - 0s 720us/step - loss: 0.1226 - accuracy: 0.9433 - precision_class_0: 0.9525 - recall_class_0: 0.8485 - precision_class_1: 0.9830 - recall_class_1: 0.9864 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9631 - recall_class_3: 0.9371 - precision_class_4: 0.8399 - recall_class_4: 0.9032
# Epoch 74/800
# 183/183 [==============================] - 0s 716us/step - loss: 0.1250 - accuracy: 0.9507 - precision_class_0: 0.9562 - recall_class_0: 0.8425 - precision_class_1: 0.9743 - recall_class_1: 0.9713 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9767 - recall_class_3: 0.9734 - precision_class_4: 0.8627 - recall_class_4: 0.9374
# Epoch 75/800
# 183/183 [==============================] - 0s 725us/step - loss: 0.1331 - accuracy: 0.9447 - precision_class_0: 0.9582 - recall_class_0: 0.8575 - precision_class_1: 0.9713 - recall_class_1: 0.9689 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9681 - recall_class_3: 0.9352 - precision_class_4: 0.8421 - recall_class_4: 0.9161
# Epoch 76/800
# 183/183 [==============================] - 0s 689us/step - loss: 0.1028 - accuracy: 0.9552 - precision_class_0: 0.9618 - recall_class_0: 0.8802 - precision_class_1: 0.9930 - recall_class_1: 0.9709 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9643 - recall_class_3: 0.9512 - precision_class_4: 0.8720 - recall_class_4: 0.9497
# Epoch 77/800
# 183/183 [==============================] - 0s 713us/step - loss: 0.1284 - accuracy: 0.9335 - precision_class_0: 0.9340 - recall_class_0: 0.8511 - precision_class_1: 0.9728 - recall_class_1: 0.9678 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9815 - recall_class_3: 0.9331 - precision_class_4: 0.8284 - recall_class_4: 0.8781
# Epoch 78/800
# 183/183 [==============================] - 0s 688us/step - loss: 0.1079 - accuracy: 0.9557 - precision_class_0: 0.9622 - recall_class_0: 0.8985 - precision_class_1: 0.9893 - recall_class_1: 0.9707 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9730 - recall_class_3: 0.9529 - precision_class_4: 0.8846 - recall_class_4: 0.9354
# Epoch 79/800
# 183/183 [==============================] - 0s 688us/step - loss: 0.1132 - accuracy: 0.9539 - precision_class_0: 0.9747 - recall_class_0: 0.9063 - precision_class_1: 0.9617 - recall_class_1: 0.9708 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9705 - recall_class_3: 0.9493 - precision_class_4: 0.8683 - recall_class_4: 0.9145
# Epoch 80/800
# 183/183 [==============================] - 0s 709us/step - loss: 0.1203 - accuracy: 0.9472 - precision_class_0: 0.9632 - recall_class_0: 0.8683 - precision_class_1: 0.9654 - recall_class_1: 0.9674 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9864 - recall_class_3: 0.9602 - precision_class_4: 0.8644 - recall_class_4: 0.9223
# Epoch 81/800
# 183/183 [==============================] - 0s 710us/step - loss: 0.1144 - accuracy: 0.9464 - precision_class_0: 0.9332 - recall_class_0: 0.9068 - precision_class_1: 0.9728 - recall_class_1: 0.9335 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9840 - recall_class_3: 0.9473 - precision_class_4: 0.8478 - recall_class_4: 0.9124
# Epoch 82/800
# 183/183 [==============================] - 0s 707us/step - loss: 0.1177 - accuracy: 0.9384 - precision_class_0: 0.9349 - recall_class_0: 0.8508 - precision_class_1: 0.9815 - recall_class_1: 0.9756 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9474 - recall_class_3: 0.9333 - precision_class_4: 0.8461 - recall_class_4: 0.9159
# Epoch 83/800
# 183/183 [==============================] - 0s 897us/step - loss: 0.1219 - accuracy: 0.9499 - precision_class_0: 0.9613 - recall_class_0: 0.8719 - precision_class_1: 0.9727 - recall_class_1: 0.9751 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9646 - recall_class_3: 0.9649 - precision_class_4: 0.8787 - recall_class_4: 0.9359
# Epoch 84/800
# 183/183 [==============================] - 0s 739us/step - loss: 0.1760 - accuracy: 0.9319 - precision_class_0: 0.9390 - recall_class_0: 0.8908 - precision_class_1: 0.9361 - recall_class_1: 0.9346 - precision_class_2: 0.9908 - recall_class_2: 0.9875 - precision_class_3: 0.9360 - recall_class_3: 0.8944 - precision_class_4: 0.8776 - recall_class_4: 0.9242
# Epoch 85/800
# 183/183 [==============================] - 0s 712us/step - loss: 0.1225 - accuracy: 0.9466 - precision_class_0: 0.9064 - recall_class_0: 0.8880 - precision_class_1: 0.9612 - recall_class_1: 0.9677 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9763 - recall_class_3: 0.9480 - precision_class_4: 0.8812 - recall_class_4: 0.8901
# Epoch 86/800
# 183/183 [==============================] - 0s 709us/step - loss: 0.1125 - accuracy: 0.9465 - precision_class_0: 0.9477 - recall_class_0: 0.8885 - precision_class_1: 0.9657 - recall_class_1: 0.9788 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9620 - recall_class_3: 0.9410 - precision_class_4: 0.8658 - recall_class_4: 0.9008
# Epoch 87/800
# 183/183 [==============================] - 0s 708us/step - loss: 0.0769 - accuracy: 0.9666 - precision_class_0: 0.9564 - recall_class_0: 0.9219 - precision_class_1: 0.9894 - recall_class_1: 0.9798 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9911 - recall_class_3: 0.9765 - precision_class_4: 0.8902 - recall_class_4: 0.9328
# Epoch 88/800
# 183/183 [==============================] - 0s 707us/step - loss: 0.1123 - accuracy: 0.9545 - precision_class_0: 0.9583 - recall_class_0: 0.9072 - precision_class_1: 0.9591 - recall_class_1: 0.9493 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9633 - recall_class_3: 0.9618 - precision_class_4: 0.8905 - recall_class_4: 0.9122
# Epoch 89/800
# 183/183 [==============================] - 0s 707us/step - loss: 0.1046 - accuracy: 0.9623 - precision_class_0: 0.9661 - recall_class_0: 0.9100 - precision_class_1: 0.9921 - recall_class_1: 0.9581 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9862 - recall_class_3: 0.9707 - precision_class_4: 0.8865 - recall_class_4: 0.9547
# Epoch 90/800
# 183/183 [==============================] - 0s 686us/step - loss: 0.1130 - accuracy: 0.9498 - precision_class_0: 0.9568 - recall_class_0: 0.8960 - precision_class_1: 0.9777 - recall_class_1: 0.9655 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9640 - recall_class_3: 0.9622 - precision_class_4: 0.8823 - recall_class_4: 0.9138
# Epoch 91/800
# 183/183 [==============================] - 0s 691us/step - loss: 0.0969 - accuracy: 0.9582 - precision_class_0: 0.9296 - recall_class_0: 0.9144 - precision_class_1: 0.9868 - recall_class_1: 0.9802 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9895 - recall_class_3: 0.9763 - precision_class_4: 0.8889 - recall_class_4: 0.9133
# Epoch 92/800
# 183/183 [==============================] - 0s 684us/step - loss: 0.0955 - accuracy: 0.9551 - precision_class_0: 0.9308 - recall_class_0: 0.9121 - precision_class_1: 0.9746 - recall_class_1: 0.9748 - precision_class_2: 0.9998 - recall_class_2: 1.0000 - precision_class_3: 0.9715 - recall_class_3: 0.9548 - precision_class_4: 0.8899 - recall_class_4: 0.9169
# Epoch 93/800
# 183/183 [==============================] - 0s 703us/step - loss: 0.2041 - accuracy: 0.9354 - precision_class_0: 0.9045 - recall_class_0: 0.8485 - precision_class_1: 0.9767 - recall_class_1: 0.9779 - precision_class_2: 0.9594 - recall_class_2: 0.9505 - precision_class_3: 0.9546 - recall_class_3: 0.9716 - precision_class_4: 0.8810 - recall_class_4: 0.9045
# Epoch 94/800
# 183/183 [==============================] - 0s 698us/step - loss: 0.1049 - accuracy: 0.9508 - precision_class_0: 0.9342 - recall_class_0: 0.8749 - precision_class_1: 0.9921 - recall_class_1: 0.9822 - precision_class_2: 0.9891 - recall_class_2: 0.9891 - precision_class_3: 0.9850 - recall_class_3: 0.9551 - precision_class_4: 0.8603 - recall_class_4: 0.9246
# Epoch 95/800
# 183/183 [==============================] - 0s 715us/step - loss: 0.1269 - accuracy: 0.9324 - precision_class_0: 0.9386 - recall_class_0: 0.8897 - precision_class_1: 0.9255 - recall_class_1: 0.9464 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9535 - recall_class_3: 0.9404 - precision_class_4: 0.8488 - recall_class_4: 0.8641
# Epoch 96/800
# 183/183 [==============================] - 0s 708us/step - loss: 0.0889 - accuracy: 0.9630 - precision_class_0: 0.9613 - recall_class_0: 0.9137 - precision_class_1: 0.9907 - recall_class_1: 0.9759 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9805 - recall_class_3: 0.9605 - precision_class_4: 0.8909 - recall_class_4: 0.9529
# Epoch 97/800
# 183/183 [==============================] - 0s 963us/step - loss: 0.1107 - accuracy: 0.9492 - precision_class_0: 0.9184 - recall_class_0: 0.9336 - precision_class_1: 0.9826 - recall_class_1: 0.9720 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9308 - recall_class_3: 0.9735 - precision_class_4: 0.9063 - recall_class_4: 0.8441
# Epoch 98/800
# 183/183 [==============================] - 0s 731us/step - loss: 0.0890 - accuracy: 0.9671 - precision_class_0: 0.9661 - recall_class_0: 0.9334 - precision_class_1: 0.9766 - recall_class_1: 0.9723 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9940 - recall_class_3: 0.9773 - precision_class_4: 0.9095 - recall_class_4: 0.9420
# Epoch 99/800
# 183/183 [==============================] - 0s 702us/step - loss: 0.0782 - accuracy: 0.9654 - precision_class_0: 0.9564 - recall_class_0: 0.9338 - precision_class_1: 0.9912 - recall_class_1: 0.9648 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9757 - recall_class_3: 0.9821 - precision_class_4: 0.9019 - recall_class_4: 0.9343
# Epoch 100/800
# 183/183 [==============================] - 0s 685us/step - loss: 0.0900 - accuracy: 0.9661 - precision_class_0: 0.9639 - recall_class_0: 0.8954 - precision_class_1: 0.9853 - recall_class_1: 0.9806 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9892 - recall_class_3: 0.9717 - precision_class_4: 0.9053 - recall_class_4: 0.9636
# Epoch 101/800
# 183/183 [==============================] - 0s 697us/step - loss: 0.0915 - accuracy: 0.9596 - precision_class_0: 0.9647 - recall_class_0: 0.9200 - precision_class_1: 0.9763 - recall_class_1: 0.9611 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9861 - recall_class_3: 0.9414 - precision_class_4: 0.8851 - recall_class_4: 0.9564
# Epoch 102/800
# 183/183 [==============================] - 0s 693us/step - loss: 0.0977 - accuracy: 0.9569 - precision_class_0: 0.9500 - recall_class_0: 0.9170 - precision_class_1: 0.9667 - recall_class_1: 0.9785 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9908 - recall_class_3: 0.9706 - precision_class_4: 0.8855 - recall_class_4: 0.8816
# Epoch 103/800
# 183/183 [==============================] - 0s 694us/step - loss: 0.1341 - accuracy: 0.9408 - precision_class_0: 0.9293 - recall_class_0: 0.9204 - precision_class_1: 0.9449 - recall_class_1: 0.9728 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9654 - recall_class_3: 0.9271 - precision_class_4: 0.8648 - recall_class_4: 0.8923
# Epoch 104/800
# 183/183 [==============================] - 0s 698us/step - loss: 0.0907 - accuracy: 0.9551 - precision_class_0: 0.9610 - recall_class_0: 0.8979 - precision_class_1: 0.9855 - recall_class_1: 0.9767 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9891 - recall_class_3: 0.9703 - precision_class_4: 0.8477 - recall_class_4: 0.9293
# Epoch 105/800
# 183/183 [==============================] - 0s 699us/step - loss: 0.1039 - accuracy: 0.9431 - precision_class_0: 0.9313 - recall_class_0: 0.8929 - precision_class_1: 0.9579 - recall_class_1: 0.9713 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9710 - recall_class_3: 0.9596 - precision_class_4: 0.8429 - recall_class_4: 0.8746
# Epoch 106/800
# 183/183 [==============================] - 0s 703us/step - loss: 0.0872 - accuracy: 0.9601 - precision_class_0: 0.9724 - recall_class_0: 0.9083 - precision_class_1: 0.9839 - recall_class_1: 0.9658 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9905 - recall_class_3: 0.9459 - precision_class_4: 0.8675 - recall_class_4: 0.9283
# Epoch 107/800
# 183/183 [==============================] - 0s 703us/step - loss: 0.0811 - accuracy: 0.9689 - precision_class_0: 0.9706 - recall_class_0: 0.9155 - precision_class_1: 0.9902 - recall_class_1: 0.9865 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9889 - recall_class_3: 0.9811 - precision_class_4: 0.9026 - recall_class_4: 0.9509
# Epoch 108/800
# 183/183 [==============================] - 0s 705us/step - loss: 0.0912 - accuracy: 0.9604 - precision_class_0: 0.9406 - recall_class_0: 0.8901 - precision_class_1: 0.9882 - recall_class_1: 0.9852 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9763 - recall_class_3: 0.9845 - precision_class_4: 0.9048 - recall_class_4: 0.9184
# Epoch 109/800
# 183/183 [==============================] - 0s 700us/step - loss: 0.0875 - accuracy: 0.9629 - precision_class_0: 0.9479 - recall_class_0: 0.8693 - precision_class_1: 0.9845 - recall_class_1: 0.9810 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9880 - recall_class_3: 0.9725 - precision_class_4: 0.8885 - recall_class_4: 0.9526
# Epoch 110/800
# 183/183 [==============================] - 0s 868us/step - loss: 0.0830 - accuracy: 0.9623 - precision_class_0: 0.9436 - recall_class_0: 0.9334 - precision_class_1: 0.9826 - recall_class_1: 0.9908 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9935 - recall_class_3: 0.9496 - precision_class_4: 0.9076 - recall_class_4: 0.9319
# Epoch 111/800
# 183/183 [==============================] - 0s 743us/step - loss: 0.0920 - accuracy: 0.9574 - precision_class_0: 0.9554 - recall_class_0: 0.9206 - precision_class_1: 0.9545 - recall_class_1: 0.9918 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9809 - recall_class_3: 0.9635 - precision_class_4: 0.9067 - recall_class_4: 0.9080
# Epoch 112/800
# 183/183 [==============================] - 0s 726us/step - loss: 0.0758 - accuracy: 0.9629 - precision_class_0: 0.9615 - recall_class_0: 0.9117 - precision_class_1: 0.9832 - recall_class_1: 0.9758 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9871 - recall_class_3: 0.9696 - precision_class_4: 0.8870 - recall_class_4: 0.9520
# Epoch 113/800
# 183/183 [==============================] - 0s 694us/step - loss: 0.0845 - accuracy: 0.9577 - precision_class_0: 0.9376 - recall_class_0: 0.8908 - precision_class_1: 0.9862 - recall_class_1: 0.9912 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9946 - recall_class_3: 0.9665 - precision_class_4: 0.8661 - recall_class_4: 0.9286
# Epoch 114/800
# 183/183 [==============================] - 0s 703us/step - loss: 0.0904 - accuracy: 0.9547 - precision_class_0: 0.9579 - recall_class_0: 0.8947 - precision_class_1: 0.9895 - recall_class_1: 0.9760 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9847 - recall_class_3: 0.9576 - precision_class_4: 0.8453 - recall_class_4: 0.9360
# Epoch 115/800
# 183/183 [==============================] - 0s 696us/step - loss: 0.0942 - accuracy: 0.9586 - precision_class_0: 0.9381 - recall_class_0: 0.9071 - precision_class_1: 0.9825 - recall_class_1: 0.9787 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9907 - recall_class_3: 0.9727 - precision_class_4: 0.8897 - recall_class_4: 0.9184
# Epoch 116/800
# 183/183 [==============================] - 0s 689us/step - loss: 0.0891 - accuracy: 0.9649 - precision_class_0: 0.9584 - recall_class_0: 0.9207 - precision_class_1: 0.9880 - recall_class_1: 0.9759 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9716 - recall_class_3: 0.9696 - precision_class_4: 0.9150 - recall_class_4: 0.9515
# Epoch 117/800
# 183/183 [==============================] - 0s 695us/step - loss: 0.1085 - accuracy: 0.9588 - precision_class_0: 0.9640 - recall_class_0: 0.9115 - precision_class_1: 0.9617 - recall_class_1: 0.9654 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9906 - recall_class_3: 0.9843 - precision_class_4: 0.8873 - recall_class_4: 0.9198
# Epoch 118/800
# 183/183 [==============================] - 0s 698us/step - loss: 0.0718 - accuracy: 0.9713 - precision_class_0: 0.9823 - recall_class_0: 0.9145 - precision_class_1: 0.9816 - recall_class_1: 0.9814 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9774 - recall_class_3: 0.9936 - precision_class_4: 0.9109 - recall_class_4: 0.9319
# Epoch 119/800
# 183/183 [==============================] - 0s 711us/step - loss: 0.0787 - accuracy: 0.9656 - precision_class_0: 0.9420 - recall_class_0: 0.9323 - precision_class_1: 0.9718 - recall_class_1: 0.9646 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9964 - recall_class_3: 0.9834 - precision_class_4: 0.9105 - recall_class_4: 0.9274
# Epoch 120/800
# 183/183 [==============================] - 0s 696us/step - loss: 0.0776 - accuracy: 0.9654 - precision_class_0: 0.9594 - recall_class_0: 0.9086 - precision_class_1: 0.9985 - recall_class_1: 0.9961 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9855 - recall_class_3: 0.9637 - precision_class_4: 0.8751 - recall_class_4: 0.9320
# Epoch 121/800
# 183/183 [==============================] - 0s 708us/step - loss: 0.0722 - accuracy: 0.9685 - precision_class_0: 0.9655 - recall_class_0: 0.9294 - precision_class_1: 0.9909 - recall_class_1: 0.9864 - precision_class_2: 1.0000 - recall_class_2: 0.9999 - precision_class_3: 0.9783 - recall_class_3: 0.9684 - precision_class_4: 0.9154 - recall_class_4: 0.9552
# Epoch 122/800
# 183/183 [==============================] - 0s 708us/step - loss: 0.1172 - accuracy: 0.9499 - precision_class_0: 0.9240 - recall_class_0: 0.8766 - precision_class_1: 0.9812 - recall_class_1: 0.9870 - precision_class_2: 0.9698 - recall_class_2: 0.9766 - precision_class_3: 0.9836 - recall_class_3: 0.9856 - precision_class_4: 0.8851 - recall_class_4: 0.9134
# Epoch 123/800
# 183/183 [==============================] - 0s 700us/step - loss: 0.0660 - accuracy: 0.9738 - precision_class_0: 0.9797 - recall_class_0: 0.9203 - precision_class_1: 0.9840 - recall_class_1: 0.9737 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9834 - recall_class_3: 0.9898 - precision_class_4: 0.9219 - recall_class_4: 0.9706
# Epoch 124/800
# 183/183 [==============================] - 0s 856us/step - loss: 0.0759 - accuracy: 0.9670 - precision_class_0: 0.9516 - recall_class_0: 0.9389 - precision_class_1: 0.9882 - recall_class_1: 0.9797 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9922 - recall_class_3: 0.9849 - precision_class_4: 0.9128 - recall_class_4: 0.9339
# Epoch 125/800
# 183/183 [==============================] - 0s 762us/step - loss: 0.0736 - accuracy: 0.9676 - precision_class_0: 0.9915 - recall_class_0: 0.9248 - precision_class_1: 0.9812 - recall_class_1: 0.9811 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9872 - recall_class_3: 0.9734 - precision_class_4: 0.8982 - recall_class_4: 0.9579
# Epoch 126/800
# 183/183 [==============================] - 0s 707us/step - loss: 0.0858 - accuracy: 0.9577 - precision_class_0: 0.9566 - recall_class_0: 0.8789 - precision_class_1: 0.9747 - recall_class_1: 0.9902 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9889 - recall_class_3: 0.9792 - precision_class_4: 0.8818 - recall_class_4: 0.9422
# Epoch 127/800
# 183/183 [==============================] - 0s 710us/step - loss: 0.0636 - accuracy: 0.9735 - precision_class_0: 0.9687 - recall_class_0: 0.9265 - precision_class_1: 0.9885 - recall_class_1: 0.9872 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9879 - recall_class_3: 0.9974 - precision_class_4: 0.9264 - recall_class_4: 0.9428
# Epoch 128/800
# 183/183 [==============================] - 0s 687us/step - loss: 0.0828 - accuracy: 0.9653 - precision_class_0: 0.9666 - recall_class_0: 0.8817 - precision_class_1: 0.9946 - recall_class_1: 0.9751 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9774 - recall_class_3: 0.9866 - precision_class_4: 0.8976 - recall_class_4: 0.9712
# Epoch 129/800
# 183/183 [==============================] - 0s 686us/step - loss: 0.0786 - accuracy: 0.9662 - precision_class_0: 0.9633 - recall_class_0: 0.9367 - precision_class_1: 0.9804 - recall_class_1: 0.9751 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9853 - recall_class_3: 0.9865 - precision_class_4: 0.8974 - recall_class_4: 0.9183
# ...
# Epoch 759/800
# 183/183 [==============================] - 0s 733us/step - loss: 0.0053 - accuracy: 0.9989 - precision_class_0: 0.9994 - recall_class_0: 0.9950 - precision_class_1: 0.9946 - recall_class_1: 0.9946 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9950 - recall_class_4: 0.9994
# Epoch 760/800
# 183/183 [==============================] - 0s 692us/step - loss: 0.0070 - accuracy: 0.9980 - precision_class_0: 0.9931 - recall_class_0: 0.9972 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9971 - recall_class_4: 0.9928
# Epoch 761/800
# 183/183 [==============================] - 0s 854us/step - loss: 0.0096 - accuracy: 0.9962 - precision_class_0: 1.0000 - recall_class_0: 0.9824 - precision_class_1: 0.9973 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9855 - recall_class_4: 0.9974
# Epoch 762/800
# 183/183 [==============================] - 0s 749us/step - loss: 0.0065 - accuracy: 0.9981 - precision_class_0: 0.9999 - recall_class_0: 0.9976 - precision_class_1: 0.9993 - recall_class_1: 0.9942 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9913 - recall_class_4: 0.9992
# Epoch 763/800
# 183/183 [==============================] - 0s 714us/step - loss: 0.0204 - accuracy: 0.9885 - precision_class_0: 0.9745 - recall_class_0: 0.9812 - precision_class_1: 0.9968 - recall_class_1: 0.9925 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9945 - recall_class_3: 0.9942 - precision_class_4: 0.9756 - recall_class_4: 0.9725
# Epoch 764/800
# 183/183 [==============================] - 0s 701us/step - loss: 0.0145 - accuracy: 0.9955 - precision_class_0: 0.9970 - recall_class_0: 0.9986 - precision_class_1: 0.9962 - recall_class_1: 0.9910 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9937 - recall_class_3: 0.9971 - precision_class_4: 0.9854 - recall_class_4: 0.9859
# Epoch 765/800
# 183/183 [==============================] - 0s 881us/step - loss: 0.0297 - accuracy: 0.9936 - precision_class_0: 0.9941 - recall_class_0: 0.9984 - precision_class_1: 0.9848 - recall_class_1: 0.9855 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9850 - recall_class_3: 0.9893 - precision_class_4: 0.9984 - recall_class_4: 0.9894
# Epoch 766/800
# 183/183 [==============================] - 0s 753us/step - loss: 0.0089 - accuracy: 0.9975 - precision_class_0: 0.9914 - recall_class_0: 0.9957 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9959 - recall_class_4: 0.9919
# Epoch 767/800
# 183/183 [==============================] - 0s 706us/step - loss: 0.0055 - accuracy: 0.9975 - precision_class_0: 0.9970 - recall_class_0: 0.9905 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9907 - recall_class_4: 0.9971
# Epoch 768/800
# 183/183 [==============================] - 0s 904us/step - loss: 0.0043 - accuracy: 0.9985 - precision_class_0: 0.9976 - recall_class_0: 0.9954 - precision_class_1: 0.9946 - recall_class_1: 0.9946 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9949 - recall_class_4: 0.9975
# Epoch 769/800
# 183/183 [==============================] - 0s 742us/step - loss: 0.0330 - accuracy: 0.9912 - precision_class_0: 0.9772 - recall_class_0: 0.9821 - precision_class_1: 1.0000 - recall_class_1: 0.9999 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9806 - recall_class_4: 0.9751
# Epoch 770/800
# 183/183 [==============================] - 0s 706us/step - loss: 0.0060 - accuracy: 0.9977 - precision_class_0: 0.9981 - recall_class_0: 0.9893 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9905 - recall_class_4: 0.9982
# Epoch 771/800
# 183/183 [==============================] - 0s 705us/step - loss: 0.0039 - accuracy: 0.9994 - precision_class_0: 1.0000 - recall_class_0: 0.9972 - precision_class_1: 0.9946 - recall_class_1: 0.9946 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9972 - recall_class_4: 1.0000
# Epoch 772/800
# 183/183 [==============================] - 0s 959us/step - loss: 0.0108 - accuracy: 0.9954 - precision_class_0: 0.9884 - recall_class_0: 0.9899 - precision_class_1: 0.9946 - recall_class_1: 0.9946 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9893 - recall_class_4: 0.9878
# Epoch 773/800
# 183/183 [==============================] - 0s 752us/step - loss: 0.0109 - accuracy: 0.9953 - precision_class_0: 0.9838 - recall_class_0: 0.9961 - precision_class_1: 0.9941 - recall_class_1: 0.9946 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9990 - recall_class_3: 0.9995 - precision_class_4: 0.9899 - recall_class_4: 0.9752
# Epoch 774/800
# 183/183 [==============================] - 0s 877us/step - loss: 0.0357 - accuracy: 0.9888 - precision_class_0: 0.9964 - recall_class_0: 0.9958 - precision_class_1: 0.9871 - recall_class_1: 0.9818 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9794 - recall_class_3: 0.9781 - precision_class_4: 0.9823 - recall_class_4: 0.9884
# Epoch 775/800
# 183/183 [==============================] - 0s 862us/step - loss: 0.0337 - accuracy: 0.9889 - precision_class_0: 0.9794 - recall_class_0: 0.9881 - precision_class_1: 0.9780 - recall_class_1: 0.9980 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9946 - recall_class_3: 0.9895 - precision_class_4: 0.9866 - recall_class_4: 0.9605
# Epoch 776/800
# 183/183 [==============================] - 0s 745us/step - loss: 0.0045 - accuracy: 0.9992 - precision_class_0: 0.9964 - recall_class_0: 1.0000 - precision_class_1: 0.9999 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 1.0000 - recall_class_4: 0.9964
# Epoch 777/800
# 183/183 [==============================] - 0s 945us/step - loss: 0.0082 - accuracy: 0.9966 - precision_class_0: 1.0000 - recall_class_0: 0.9962 - precision_class_1: 0.9958 - recall_class_1: 0.9910 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9877 - recall_class_4: 0.9957
# Epoch 778/800
# 183/183 [==============================] - 0s 781us/step - loss: 0.0044 - accuracy: 0.9981 - precision_class_0: 0.9929 - recall_class_0: 0.9893 - precision_class_1: 0.9974 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9897 - recall_class_4: 0.9904
# Epoch 779/800
# 183/183 [==============================] - 0s 749us/step - loss: 0.0072 - accuracy: 0.9966 - precision_class_0: 0.9853 - recall_class_0: 0.9968 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9916 - recall_class_4: 0.9799
# Epoch 780/800
# 183/183 [==============================] - 0s 897us/step - loss: 0.0105 - accuracy: 0.9937 - precision_class_0: 0.9874 - recall_class_0: 0.9881 - precision_class_1: 0.9952 - recall_class_1: 1.0000 - precision_class_2: 0.9891 - recall_class_2: 0.9891 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9816 - recall_class_4: 0.9759
# Epoch 781/800
# 183/183 [==============================] - 0s 738us/step - loss: 0.0136 - accuracy: 0.9944 - precision_class_0: 0.9788 - recall_class_0: 0.9819 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9878 - recall_class_4: 0.9846
# Epoch 782/800
# 183/183 [==============================] - 0s 713us/step - loss: 0.0060 - accuracy: 0.9976 - precision_class_0: 0.9988 - recall_class_0: 0.9896 - precision_class_1: 0.9997 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9897 - recall_class_4: 0.9985
# Epoch 783/800
# 183/183 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 0.9986 - precision_class_0: 0.9955 - recall_class_0: 0.9979 - precision_class_1: 0.9996 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9946 - recall_class_3: 0.9946 - precision_class_4: 0.9979 - recall_class_4: 0.9950
# Epoch 784/800
# 183/183 [==============================] - 0s 723us/step - loss: 0.0497 - accuracy: 0.9814 - precision_class_0: 0.9790 - recall_class_0: 0.9781 - precision_class_1: 0.9796 - recall_class_1: 0.9904 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 0.9881 - recall_class_3: 0.9840 - precision_class_4: 0.9601 - recall_class_4: 0.9565
# Epoch 785/800
# 183/183 [==============================] - 0s 783us/step - loss: 0.0313 - accuracy: 0.9937 - precision_class_0: 0.9844 - recall_class_0: 0.9941 - precision_class_1: 1.0000 - recall_class_1: 0.9888 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 0.9923 - precision_class_4: 0.9810 - recall_class_4: 0.9871
# Epoch 786/800
# 183/183 [==============================] - 0s 957us/step - loss: 0.0068 - accuracy: 0.9964 - precision_class_0: 0.9906 - recall_class_0: 0.9912 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9857 - recall_class_4: 0.9851
# Epoch 787/800
# 183/183 [==============================] - 0s 757us/step - loss: 0.0318 - accuracy: 0.9872 - precision_class_0: 0.9645 - recall_class_0: 0.9611 - precision_class_1: 0.9977 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9664 - recall_class_4: 0.9688
# Epoch 788/800
# 183/183 [==============================] - 0s 757us/step - loss: 0.0245 - accuracy: 0.9905 - precision_class_0: 0.9844 - recall_class_0: 0.9806 - precision_class_1: 1.0000 - recall_class_1: 0.9893 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9946 - recall_class_3: 0.9946 - precision_class_4: 0.9698 - recall_class_4: 0.9844
# Epoch 789/800
# 183/183 [==============================] - 0s 969us/step - loss: 0.0047 - accuracy: 0.9978 - precision_class_0: 1.0000 - recall_class_0: 0.9959 - precision_class_1: 0.9968 - recall_class_1: 0.9963 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9922 - recall_class_4: 0.9968
# Epoch 790/800
# 183/183 [==============================] - 0s 765us/step - loss: 0.0209 - accuracy: 0.9924 - precision_class_0: 0.9888 - recall_class_0: 1.0000 - precision_class_1: 0.9935 - recall_class_1: 0.9901 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9954 - recall_class_3: 0.9953 - precision_class_4: 0.9843 - recall_class_4: 0.9749
# Epoch 791/800
# 183/183 [==============================] - 0s 741us/step - loss: 0.0118 - accuracy: 0.9962 - precision_class_0: 0.9944 - recall_class_0: 0.9892 - precision_class_1: 0.9990 - recall_class_1: 0.9986 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9984 - recall_class_3: 0.9990 - precision_class_4: 0.9891 - recall_class_4: 0.9941
# Epoch 792/800
# 183/183 [==============================] - 0s 940us/step - loss: 0.0545 - accuracy: 0.9868 - precision_class_0: 0.9825 - recall_class_0: 0.9813 - precision_class_1: 0.9762 - recall_class_1: 0.9984 - precision_class_2: 0.9953 - recall_class_2: 0.9934 - precision_class_3: 0.9985 - recall_class_3: 0.9718 - precision_class_4: 0.9821 - recall_class_4: 0.9897
# Epoch 793/800
# 183/183 [==============================] - 0s 761us/step - loss: 0.0197 - accuracy: 0.9938 - precision_class_0: 0.9833 - recall_class_0: 0.9830 - precision_class_1: 0.9915 - recall_class_1: 1.0000 - precision_class_2: 0.9989 - recall_class_2: 0.9919 - precision_class_3: 1.0000 - recall_class_3: 0.9914 - precision_class_4: 0.9902 - recall_class_4: 0.9970
# Epoch 794/800
# 183/183 [==============================] - 0s 760us/step - loss: 0.0094 - accuracy: 0.9981 - precision_class_0: 0.9951 - recall_class_0: 0.9954 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9900 - recall_class_4: 0.9894
# Epoch 795/800
# 183/183 [==============================] - 0s 709us/step - loss: 0.0051 - accuracy: 0.9976 - precision_class_0: 0.9905 - recall_class_0: 0.9976 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9980 - recall_class_3: 0.9963 - precision_class_4: 0.9996 - recall_class_4: 0.9943
# Epoch 796/800
# 183/183 [==============================] - 0s 943us/step - loss: 0.0028 - accuracy: 0.9988 - precision_class_0: 0.9958 - recall_class_0: 0.9980 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9925 - recall_class_4: 0.9903
# Epoch 797/800
# 183/183 [==============================] - 0s 749us/step - loss: 0.0028 - accuracy: 0.9985 - precision_class_0: 0.9973 - recall_class_0: 0.9967 - precision_class_1: 0.9989 - recall_class_1: 0.9996 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9963 - recall_class_4: 0.9962
# Epoch 798/800
# 183/183 [==============================] - 0s 759us/step - loss: 0.0183 - accuracy: 0.9924 - precision_class_0: 0.9865 - recall_class_0: 0.9881 - precision_class_1: 0.9913 - recall_class_1: 0.9957 - precision_class_2: 0.9946 - recall_class_2: 0.9946 - precision_class_3: 1.0000 - recall_class_3: 0.9942 - precision_class_4: 0.9840 - recall_class_4: 0.9842
# Epoch 799/800
# 183/183 [==============================] - 0s 979us/step - loss: 0.0039 - accuracy: 0.9991 - precision_class_0: 0.9993 - recall_class_0: 0.9962 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 0.9946 - recall_class_3: 0.9946 - precision_class_4: 0.9906 - recall_class_4: 0.9939
# Epoch 800/800
# 183/183 [==============================] - 0s 760us/step - loss: 0.0043 - accuracy: 0.9998 - precision_class_0: 1.0000 - recall_class_0: 0.9988 - precision_class_1: 1.0000 - recall_class_1: 1.0000 - precision_class_2: 1.0000 - recall_class_2: 1.0000 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9988 - recall_class_4: 1.0000

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

rcParams['figure.figsize'] = (28, 21)
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False

# Correcting the range of epochs to match the actual number of epochs trained
epochs_trained = len(history.history['loss']) 

# Plot Loss and Accuracy
plt.plot(
    np.arange(1, epochs_trained + 1),
    history.history['loss'], label='Loss'
)
plt.plot(
    np.arange(1, epochs_trained + 1),
    history.history['accuracy'], label='Accuracy'
)

# Plot Precision and Recall for each class
num_classes = 5  # Update this with the actual number of classes you have
for i in range(num_classes):
    precision_label = f'precision_class_{i}'
    recall_label = f'recall_class_{i}'
    
    # Check if precision and recall for each class are in history to avoid KeyError
    if precision_label in history.history:
        plt.plot(
            np.arange(1, epochs_trained + 1),
            history.history[precision_label], label=f'Precision Class {i}'
        )
    if recall_label in history.history:
        plt.plot(
            np.arange(1, epochs_trained + 1),
            history.history[recall_label], label=f'Recall Class {i}'
        )

plt.title('Evaluation metrics', size=20)
plt.xlabel('Epoch', size=14)
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
test_loss, test_accuracy, *test_metrics = model.evaluate(X_test, y_test,verbose=0)
y_pred = model.predict(X_test,verbose=0)

# Assuming the order of metrics is consistent with how we added them:
# test_metrics[0] -> precision_class_0, test_metrics[1] -> recall_class_0, etc.
metrics_per_class = {
    'Loss': test_loss,
    'Accuracy': test_accuracy,
}

num_classes = 5  # Update this with the actual number of classes you have
class_names = label_encoder.inverse_transform(np.unique(y_train_integer))

def compute_confusion_matrix(true, pred):
    classes = np.unique(true)
    conf_mat = [[0] * len(classes) for i in range(len(classes))]
    for i in range(len(true)):
        conf_mat[pred[i]][true[i]]+=1
    print("       Actual")
    print("      _",end="")
    for item in classes:
        print("____",end="")
    print()
    print("pred  |", end=" "),
    for item in classes:
        print("{:^3}".format(item), end=" ")
    print()
    for item in classes:
        print("{:^6}|".format(item), end=" ")
        for item2 in classes:
            print("{:^3}".format(conf_mat[item][item2]), end="|")
        print()
def compute_metrics_per_class(true, pred, test_metrics):
    classes = np.unique(true)
    conf_mat = np.zeros((len(classes), len(classes)), dtype=int)
    for i in range(len(true)):
        conf_mat[pred[i], true[i]] += 1

    num_classes = len(classes)
    max_class_name_length = max(len(name) for name in class_names)
    
    total_precision = 0
    total_recall = 0
    total_accuracy = 0

    for i in range(num_classes):
        precision = float(test_metrics[2 * i])  # Even indices for precision
        recall = float(test_metrics[2 * i + 1])  # Odd indices for recall
        accuracy = float(conf_mat[i, i]) / np.sum(conf_mat[:, i])  # Calculate accuracy for class i
        
        total_precision += precision
        total_recall += recall
        total_accuracy += accuracy

        print(f"{class_names[i]:<{max_class_name_length}} | Precision: {precision:.3f} | Recall: {recall:.3f} | Accuracy: {accuracy:.3f}")

    # Calculate and print the averages
    avg_precision = total_precision / num_classes
    avg_recall = total_recall / num_classes
    avg_accuracy = total_accuracy / num_classes
    print(f"\nAvg Precision: {avg_precision:.3f} | Avg Recall: {avg_recall:.3f} | Avg Accuracy: {avg_accuracy:.3f}")

y_pred_labels = np.argmax(y_pred, axis=1)
y_test_nums = np.argmax(y_test, axis=1)
print_dataset_split(y_train_integer,y_test_integer)
print()
print("=================================================================")

compute_confusion_matrix(y_test_nums.tolist(),y_pred_labels.tolist())
print()
print("=================================================================")
compute_metrics_per_class(y_test_nums.tolist(),y_pred_labels.tolist(),test_metrics)
print("HYPERPARAMS: LR:",LEARNING_RATE," EPOCH:",EPOCH," BATCH:",BATCH_SIZE)
print("<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>")
# Out:
# Class Name  Train  Test
#     Barley    293    73
#       Corn    293    73
#       Oats    293    73
#    Sorghum    292    74
#      Wheat    293    73
#
# =================================================================
#        Actual
#       _____________________
# pred  |  0   1   2   3   4
#   0   | 69 | 0 | 0 | 3 | 6 |
#   1   |  0 |73 | 0 | 0 | 0 |
#   2   |  0 | 0 |73 | 0 | 0 |
#   3   |  0 | 0 | 0 |71 | 0 |
#   4   |  4 | 0 | 0 | 0 |67 |
#
# =================================================================
# Barley  | Precision: 0.885 | Recall: 0.945 | Accuracy: 0.945
# Corn    | Precision: 1.000 | Recall: 1.000 | Accuracy: 1.000
# Oats    | Precision: 1.000 | Recall: 1.000 | Accuracy: 1.000
# Sorghum | Precision: 1.000 | Recall: 0.959 | Accuracy: 0.959
# Wheat   | Precision: 0.944 | Recall: 0.918 | Accuracy: 0.918
#
# Avg Precision: 0.966 | Avg Recall: 0.964 | Avg Accuracy: 0.964
# HYPERPARAMS: LR: 0.00033  EPOCH: 800  BATCH: 8
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
