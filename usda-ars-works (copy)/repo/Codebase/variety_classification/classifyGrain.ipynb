# %%
#Import libraries
import requests
import pandas as pd


#Data visualization
import seaborn as sn
import matplotlib.pyplot as plt
import random
#Data Manipulation
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
# Machine Learning
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Input, Activation
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn.compose import ColumnTransformer
np.random.seed(39)
random.seed(39)
tf.random.set_seed(39)
print(tf.__version__)
# Out:
# 2.4.1

# %%
LEARNING_RATE = 0.006738550781435328
EPOCH = 700
BATCH_SIZE = 16

# %%
#GRAIN_TYPE = 'Wheat'
GRAIN_TYPE = 'Combined_Grains'
FILENAME_BEST_MODEL = 'Best models/target_2/hybrid_models/' + GRAIN_TYPE + 'classifyVariety.h5'
URL = "../../Datasets/processed/" + GRAIN_TYPE + ".csv"
df = pd.read_csv(URL)
# Convert to numpy array
#df = df.groupby('Variety').head(120)
df_features = df[[ 
                    'Freq', 
                    'd(cm)', 
             #       'Attn', 
                    'Phase_Corr', 
                    'Permittivity_real', 
                    'Permittivity_imaginary',
                    ]]

df_targets = df[['Grain Type']]
# df_targets = df[['Density', 'M%']]

dataset_x = df_features.to_numpy()
scaler = StandardScaler()
dataset_x = scaler.fit_transform(dataset_x)
dataset_y = df_targets.to_numpy()

# %%
from sklearn.preprocessing import LabelEncoder

# Getting the number of unique varieties
num_varieties = df_targets['Grain Type'].nunique()
varieties = df_targets['Grain Type'].unique()
print(f'There are {num_varieties} different varieties.')

# Encode the 'variety' labels
label_encoder = LabelEncoder()
# Step 1: Convert varieties into number ex. 1 2 3... and store in a single list
integer_encoded = label_encoder.fit_transform(df_targets['Grain Type'])
# Step 2: Get the number of different classes
depth = num_varieties
# Step 3: Pass in the list of numerical values and the number of classes and vectors are created 
#         For example the value 4 would be passed and converted to [0. 0. 0. 0. 1.]
one_hot_encoded = tf.one_hot(integer_encoded, depth)
# Step 4: Convert to numpy arr
y_one_hot = one_hot_encoded.numpy()  # If using TensorFlow's one_hot
# Out:
# There are 5 different varieties.

# %%
'''
Uncomment this to have the dataset split be uniform in test set but not train set, no val included.
'''

from sklearn.model_selection import train_test_split
import tensorflow as tf

# Assume other parts of the code (dataset_x, y_integers, depth) are defined as in previous examples

# Perform stratified train-test split on the data to maintain class distribution
X_train, X_temp, y_train_integer, y_temp_integer = train_test_split(
    dataset_x, integer_encoded, test_size=0.20, stratify=integer_encoded, random_state=42
)
# Convert the integer labels back to one-hot encoding for TensorFlow/Keras for the training set
y_train = tf.one_hot(y_train_integer, depth).numpy()

# Now create a balanced test set from X_temp and y_temp_integer
unique_classes = np.unique(y_train_integer)
samples_per_class = min(np.bincount(y_temp_integer))  # Find the smallest class size in the test set

# Create a list to store the sampled indices
indices_to_keep = []

for cls in unique_classes:
    # Get the indices for each class
    class_indices = np.where(y_temp_integer == cls)[0]
    # Randomly choose 'samples_per_class' indices from each class
    chosen_indices = np.random.choice(class_indices, size=samples_per_class, replace=False)
    indices_to_keep.extend(chosen_indices)

# Use the indices to create the balanced test set
X_test = X_temp[indices_to_keep]
y_test_integer = y_temp_integer[indices_to_keep]

# Convert the integer labels back to one-hot encoding for TensorFlow/Keras for the test set
y_test = tf.one_hot(y_test_integer, depth).numpy()

# %%
# unique, counts = np.unique(integer_encoded, return_counts=True)
# min_class_size = min(counts)
# print(f"Minimum class size: {min_class_size}")

# # Calculate the number of samples for each class in the train and test sets
# # Here we are assuming an 80-20 split, adjust these values as necessary
# train_samples_per_class = int(min_class_size * 0.8)
# test_samples_per_class = int(min_class_size - train_samples_per_class - min_class_size * 0.15)
# val_samples_per_class = int(min_class_size - train_samples_per_class - min_class_size * 0.15)
# # Initialize lists to store the training and test indices
# train_indices = []
# test_indices = []
# val_indices = []
# # Sample indices for the train and test sets
# for cls in unique:
#     # Get the indices for each class
#     class_indices = np.where(integer_encoded == cls)[0]
    
#     # Shuffle class indices to randomize selection
#     np.random.shuffle(class_indices)
    
#     # Split class indices into train and test samples
#     train_indices.extend(class_indices[:train_samples_per_class])
#     test_indices.extend(class_indices[train_samples_per_class:train_samples_per_class + test_samples_per_class])
#     val_indices.extend(class_indices[train_samples_per_class:train_samples_per_class + test_samples_per_class + val_samples_per_class])
# # Shuffle the train and test indices to mix the classes
# np.random.shuffle(train_indices)
# np.random.shuffle(test_indices)

# # Create the balanced train and test sets
# X_train = dataset_x[train_indices]
# y_train_integer = integer_encoded[train_indices]
# X_test = dataset_x[test_indices]
# y_test_integer = integer_encoded[test_indices]
# y_val_integer = integer_encoded[val_indices]
# # Convert the integer labels back to one-hot encoding for TensorFlow/Keras
# y_train = tf.one_hot(y_train_integer, depth).numpy()
# y_test = tf.one_hot(y_test_integer, depth).numpy()
# y_val = tf.one_hot(y_val_integer, depth).numpy()

# %%
def print_dataset_split(y_train_integer,y_test_integer):
    # Create a DataFrame for the training set class distribution
    train_counts = pd.DataFrame({
        'Class Name': label_encoder.inverse_transform(np.unique(y_train_integer)),
        'Train': np.bincount(y_train_integer)
    })

    # Create a DataFrame for the balanced test set class distribution
    test_counts = pd.DataFrame({
        'Class Name': label_encoder.inverse_transform(np.unique(y_test_integer)),
        'Test': np.bincount(y_test_integer)
    })
    # val_counts = pd.DataFrame({
    #     'Class Name': label_encoder.inverse_transform(np.unique(y_val_integer)),
    #     'Val': np.bincount(y_val_integer)
    # })
    # Merge the two DataFrames on Class Name
    acombined_counts = pd.merge(train_counts, test_counts, on='Class Name', how='outer').fillna(0)
    # acombined_counts = pd.merge(combined_counts, val_counts, on='Class Name', how='outer').fillna(0)
    # Converts to integer type
    acombined_counts['Train'] = acombined_counts['Train'].astype(int)
    acombined_counts['Test'] = acombined_counts['Test'].astype(int)
    # acombined_counts['Val'] = acombined_counts['Val'].astype(int)

    # Set display options for pandas
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 1000)
    pd.set_option('display.colheader_justify', 'center')
    pd.set_option('display.precision', 3)

    # Print combined class counts in a tabular format
    print(acombined_counts.to_string(index=False, justify='right'))
print_dataset_split(y_train_integer,y_test_integer)
# Out:
# Class Name  Train  Test
#     Barley    293    73
#       Corn   1060    73
#       Oats    388    73
#    Sorghum    319    73
#      Wheat    644    73

# %%
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2

# Define model
model = tf.keras.Sequential([
    Dense(256, activation='relu'),
    
    Dense(256, activation='relu'),
    
    Dense(256, activation='relu'),
    
    Dense(5, activation='softmax')  # Changed to softmax for multi-class
])

# Compile model with per-class precision and recall
metrics = ['accuracy']  # General accuracy for all classes

# Add precision and recall for each class
for i in range(depth):
    metrics.append(tf.keras.metrics.Precision(class_id=i, name=f'precision_class_{i}'))
    metrics.append(tf.keras.metrics.Recall(class_id=i, name=f'recall_class_{i}'))

model.compile(
    loss='categorical_crossentropy',  # Correct loss for multi-class classification
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),  
    metrics=metrics
)
history = model.fit(X_train, y_train, epochs=EPOCH, batch_size=BATCH_SIZE)
model.save(FILENAME_BEST_MODEL)
# Out:
# Epoch 1/700
# 169/169 [==============================] - 1s 591us/step - loss: 1.0505 - accuracy: 0.5262 - precision_class_0: 0.5863 - recall_class_0: 0.1436 - precision_class_1: 0.8089 - recall_class_1: 0.5161 - precision_class_2: 0.8529 - recall_class_2: 0.7049 - precision_class_3: 0.2933 - recall_class_3: 0.0145 - precision_class_4: 0.4004 - recall_class_4: 0.0706
# Epoch 2/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.8717 - accuracy: 0.6070 - precision_class_0: 0.6350 - recall_class_0: 0.2394 - precision_class_1: 0.8847 - recall_class_1: 0.5356 - precision_class_2: 0.8594 - recall_class_2: 0.8529 - precision_class_3: 0.6533 - recall_class_3: 0.1196 - precision_class_4: 0.5132 - recall_class_4: 0.1523
# Epoch 3/700
# 169/169 [==============================] - 0s 580us/step - loss: 0.7342 - accuracy: 0.6797 - precision_class_0: 0.7254 - recall_class_0: 0.4112 - precision_class_1: 0.9022 - recall_class_1: 0.5809 - precision_class_2: 0.9360 - recall_class_2: 0.8762 - precision_class_3: 0.6692 - recall_class_3: 0.4017 - precision_class_4: 0.5821 - recall_class_4: 0.3280
# Epoch 4/700
# 169/169 [==============================] - 0s 579us/step - loss: 0.7515 - accuracy: 0.6580 - precision_class_0: 0.6680 - recall_class_0: 0.3846 - precision_class_1: 0.8808 - recall_class_1: 0.6015 - precision_class_2: 0.8770 - recall_class_2: 0.7930 - precision_class_3: 0.7480 - recall_class_3: 0.4405 - precision_class_4: 0.5784 - recall_class_4: 0.3843
# Epoch 5/700
# 169/169 [==============================] - 0s 575us/step - loss: 0.6685 - accuracy: 0.7014 - precision_class_0: 0.6837 - recall_class_0: 0.4733 - precision_class_1: 0.8293 - recall_class_1: 0.6621 - precision_class_2: 0.8838 - recall_class_2: 0.8077 - precision_class_3: 0.7402 - recall_class_3: 0.4774 - precision_class_4: 0.6229 - recall_class_4: 0.4601
# Epoch 6/700
# 169/169 [==============================] - 0s 573us/step - loss: 0.5811 - accuracy: 0.7543 - precision_class_0: 0.8429 - recall_class_0: 0.5728 - precision_class_1: 0.8246 - recall_class_1: 0.7628 - precision_class_2: 0.9502 - recall_class_2: 0.8770 - precision_class_3: 0.8555 - recall_class_3: 0.5712 - precision_class_4: 0.6829 - recall_class_4: 0.5480
# Epoch 7/700
# 169/169 [==============================] - 0s 577us/step - loss: 0.5760 - accuracy: 0.7415 - precision_class_0: 0.7605 - recall_class_0: 0.5813 - precision_class_1: 0.8120 - recall_class_1: 0.7669 - precision_class_2: 0.9441 - recall_class_2: 0.8727 - precision_class_3: 0.7610 - recall_class_3: 0.5635 - precision_class_4: 0.6522 - recall_class_4: 0.5625
# Epoch 8/700
# 169/169 [==============================] - 0s 580us/step - loss: 0.5376 - accuracy: 0.7789 - precision_class_0: 0.7518 - recall_class_0: 0.5066 - precision_class_1: 0.8498 - recall_class_1: 0.8058 - precision_class_2: 0.9266 - recall_class_2: 0.8774 - precision_class_3: 0.8137 - recall_class_3: 0.5870 - precision_class_4: 0.6832 - recall_class_4: 0.6693
# Epoch 9/700
# 169/169 [==============================] - 0s 574us/step - loss: 0.4757 - accuracy: 0.7894 - precision_class_0: 0.8024 - recall_class_0: 0.5805 - precision_class_1: 0.8872 - recall_class_1: 0.8241 - precision_class_2: 0.9344 - recall_class_2: 0.8935 - precision_class_3: 0.8432 - recall_class_3: 0.6161 - precision_class_4: 0.7101 - recall_class_4: 0.6920
# Epoch 10/700
# 169/169 [==============================] - 0s 586us/step - loss: 0.4438 - accuracy: 0.8037 - precision_class_0: 0.8321 - recall_class_0: 0.4781 - precision_class_1: 0.8898 - recall_class_1: 0.8201 - precision_class_2: 0.9080 - recall_class_2: 0.9173 - precision_class_3: 0.8439 - recall_class_3: 0.6832 - precision_class_4: 0.7563 - recall_class_4: 0.7277
# Epoch 11/700
# 169/169 [==============================] - 0s 565us/step - loss: 0.4456 - accuracy: 0.8058 - precision_class_0: 0.8257 - recall_class_0: 0.5948 - precision_class_1: 0.8906 - recall_class_1: 0.8221 - precision_class_2: 0.9099 - recall_class_2: 0.8724 - precision_class_3: 0.8429 - recall_class_3: 0.6880 - precision_class_4: 0.7498 - recall_class_4: 0.7708
# Epoch 12/700
# 169/169 [==============================] - 0s 572us/step - loss: 0.4812 - accuracy: 0.7870 - precision_class_0: 0.7937 - recall_class_0: 0.6333 - precision_class_1: 0.8701 - recall_class_1: 0.8095 - precision_class_2: 0.9639 - recall_class_2: 0.8979 - precision_class_3: 0.8441 - recall_class_3: 0.5453 - precision_class_4: 0.7382 - recall_class_4: 0.6715
# Epoch 13/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.4000 - accuracy: 0.8379 - precision_class_0: 0.8478 - recall_class_0: 0.6211 - precision_class_1: 0.9123 - recall_class_1: 0.8297 - precision_class_2: 0.9602 - recall_class_2: 0.9585 - precision_class_3: 0.8649 - recall_class_3: 0.7537 - precision_class_4: 0.7673 - recall_class_4: 0.7707
# Epoch 14/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.3669 - accuracy: 0.8363 - precision_class_0: 0.8773 - recall_class_0: 0.7006 - precision_class_1: 0.8967 - recall_class_1: 0.8590 - precision_class_2: 0.9704 - recall_class_2: 0.9509 - precision_class_3: 0.8115 - recall_class_3: 0.6693 - precision_class_4: 0.7824 - recall_class_4: 0.7443
# Epoch 15/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.4277 - accuracy: 0.8106 - precision_class_0: 0.8335 - recall_class_0: 0.5875 - precision_class_1: 0.8886 - recall_class_1: 0.8193 - precision_class_2: 0.9437 - recall_class_2: 0.9183 - precision_class_3: 0.8206 - recall_class_3: 0.6868 - precision_class_4: 0.7077 - recall_class_4: 0.7513
# Epoch 16/700
# 169/169 [==============================] - 0s 565us/step - loss: 0.4070 - accuracy: 0.8284 - precision_class_0: 0.8322 - recall_class_0: 0.5675 - precision_class_1: 0.9104 - recall_class_1: 0.8429 - precision_class_2: 0.9655 - recall_class_2: 0.9223 - precision_class_3: 0.8293 - recall_class_3: 0.7483 - precision_class_4: 0.7311 - recall_class_4: 0.7712
# Epoch 17/700
# 169/169 [==============================] - 0s 569us/step - loss: 0.4807 - accuracy: 0.8124 - precision_class_0: 0.7195 - recall_class_0: 0.5146 - precision_class_1: 0.8894 - recall_class_1: 0.8376 - precision_class_2: 0.9044 - recall_class_2: 0.8829 - precision_class_3: 0.8215 - recall_class_3: 0.6806 - precision_class_4: 0.7425 - recall_class_4: 0.8052
# Epoch 18/700
# 169/169 [==============================] - 0s 578us/step - loss: 0.3395 - accuracy: 0.8547 - precision_class_0: 0.8716 - recall_class_0: 0.7143 - precision_class_1: 0.8946 - recall_class_1: 0.8506 - precision_class_2: 0.9787 - recall_class_2: 0.9442 - precision_class_3: 0.8660 - recall_class_3: 0.7299 - precision_class_4: 0.7958 - recall_class_4: 0.8329
# Epoch 19/700
# 169/169 [==============================] - 0s 575us/step - loss: 0.3479 - accuracy: 0.8428 - precision_class_0: 0.9023 - recall_class_0: 0.6807 - precision_class_1: 0.9176 - recall_class_1: 0.8381 - precision_class_2: 0.9700 - recall_class_2: 0.9658 - precision_class_3: 0.8687 - recall_class_3: 0.7591 - precision_class_4: 0.7282 - recall_class_4: 0.8130
# Epoch 20/700
# 169/169 [==============================] - 0s 579us/step - loss: 0.3679 - accuracy: 0.8354 - precision_class_0: 0.8618 - recall_class_0: 0.6895 - precision_class_1: 0.9035 - recall_class_1: 0.8168 - precision_class_2: 0.9815 - recall_class_2: 0.8741 - precision_class_3: 0.8347 - recall_class_3: 0.7482 - precision_class_4: 0.7546 - recall_class_4: 0.8425
# Epoch 21/700
# 169/169 [==============================] - 0s 572us/step - loss: 0.3498 - accuracy: 0.8506 - precision_class_0: 0.8820 - recall_class_0: 0.7195 - precision_class_1: 0.9160 - recall_class_1: 0.8487 - precision_class_2: 0.9743 - recall_class_2: 0.9563 - precision_class_3: 0.8368 - recall_class_3: 0.7339 - precision_class_4: 0.7566 - recall_class_4: 0.8068
# Epoch 22/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.3477 - accuracy: 0.8545 - precision_class_0: 0.9336 - recall_class_0: 0.6444 - precision_class_1: 0.8911 - recall_class_1: 0.8491 - precision_class_2: 0.9772 - recall_class_2: 0.9543 - precision_class_3: 0.8647 - recall_class_3: 0.7603 - precision_class_4: 0.7750 - recall_class_4: 0.7932
# Epoch 23/700
# 169/169 [==============================] - 0s 573us/step - loss: 0.3468 - accuracy: 0.8541 - precision_class_0: 0.8742 - recall_class_0: 0.6483 - precision_class_1: 0.9031 - recall_class_1: 0.8431 - precision_class_2: 0.9691 - recall_class_2: 0.9447 - precision_class_3: 0.8935 - recall_class_3: 0.7954 - precision_class_4: 0.7881 - recall_class_4: 0.8370
# Epoch 24/700
# 169/169 [==============================] - 0s 574us/step - loss: 0.3522 - accuracy: 0.8400 - precision_class_0: 0.8025 - recall_class_0: 0.6032 - precision_class_1: 0.9134 - recall_class_1: 0.8425 - precision_class_2: 0.9356 - recall_class_2: 0.9204 - precision_class_3: 0.9079 - recall_class_3: 0.7807 - precision_class_4: 0.7658 - recall_class_4: 0.8394
# Epoch 25/700
# 169/169 [==============================] - 0s 569us/step - loss: 0.3843 - accuracy: 0.8383 - precision_class_0: 0.9050 - recall_class_0: 0.6947 - precision_class_1: 0.8986 - recall_class_1: 0.8498 - precision_class_2: 0.9774 - recall_class_2: 0.9504 - precision_class_3: 0.8196 - recall_class_3: 0.7051 - precision_class_4: 0.7484 - recall_class_4: 0.7368
# Epoch 26/700
# 169/169 [==============================] - 0s 571us/step - loss: 0.3205 - accuracy: 0.8490 - precision_class_0: 0.8429 - recall_class_0: 0.6746 - precision_class_1: 0.9418 - recall_class_1: 0.8518 - precision_class_2: 0.9469 - recall_class_2: 0.9413 - precision_class_3: 0.9042 - recall_class_3: 0.7335 - precision_class_4: 0.7585 - recall_class_4: 0.8477
# Epoch 27/700
# 169/169 [==============================] - 0s 568us/step - loss: 0.3739 - accuracy: 0.8466 - precision_class_0: 0.8641 - recall_class_0: 0.5966 - precision_class_1: 0.9043 - recall_class_1: 0.8535 - precision_class_2: 0.9466 - recall_class_2: 0.9569 - precision_class_3: 0.8581 - recall_class_3: 0.7519 - precision_class_4: 0.7644 - recall_class_4: 0.8309
# Epoch 28/700
# 169/169 [==============================] - 0s 572us/step - loss: 0.3523 - accuracy: 0.8531 - precision_class_0: 0.8864 - recall_class_0: 0.6554 - precision_class_1: 0.9190 - recall_class_1: 0.8484 - precision_class_2: 0.9790 - recall_class_2: 0.9425 - precision_class_3: 0.8749 - recall_class_3: 0.8074 - precision_class_4: 0.7370 - recall_class_4: 0.8302
# Epoch 29/700
# 169/169 [==============================] - 0s 576us/step - loss: 0.3354 - accuracy: 0.8585 - precision_class_0: 0.8910 - recall_class_0: 0.6536 - precision_class_1: 0.9256 - recall_class_1: 0.8528 - precision_class_2: 0.9649 - recall_class_2: 0.9519 - precision_class_3: 0.8654 - recall_class_3: 0.8058 - precision_class_4: 0.7556 - recall_class_4: 0.8294
# Epoch 30/700
# 169/169 [==============================] - 0s 572us/step - loss: 0.3081 - accuracy: 0.8642 - precision_class_0: 0.8912 - recall_class_0: 0.7070 - precision_class_1: 0.9268 - recall_class_1: 0.8627 - precision_class_2: 0.9821 - recall_class_2: 0.9618 - precision_class_3: 0.8267 - recall_class_3: 0.7901 - precision_class_4: 0.7759 - recall_class_4: 0.8341
# Epoch 31/700
# 169/169 [==============================] - 0s 573us/step - loss: 0.2800 - accuracy: 0.8671 - precision_class_0: 0.9021 - recall_class_0: 0.6203 - precision_class_1: 0.9381 - recall_class_1: 0.8642 - precision_class_2: 0.9658 - recall_class_2: 0.9606 - precision_class_3: 0.8812 - recall_class_3: 0.8690 - precision_class_4: 0.7710 - recall_class_4: 0.8795
# Epoch 32/700
# 169/169 [==============================] - 0s 559us/step - loss: 0.2695 - accuracy: 0.8890 - precision_class_0: 0.8809 - recall_class_0: 0.7161 - precision_class_1: 0.9528 - recall_class_1: 0.8790 - precision_class_2: 0.9910 - recall_class_2: 0.9587 - precision_class_3: 0.8992 - recall_class_3: 0.8562 - precision_class_4: 0.7912 - recall_class_4: 0.9016
# Epoch 33/700
# 169/169 [==============================] - 0s 569us/step - loss: 0.2926 - accuracy: 0.8646 - precision_class_0: 0.9067 - recall_class_0: 0.5958 - precision_class_1: 0.9107 - recall_class_1: 0.8608 - precision_class_2: 0.9403 - recall_class_2: 0.9361 - precision_class_3: 0.9087 - recall_class_3: 0.8507 - precision_class_4: 0.7907 - recall_class_4: 0.8740
# Epoch 34/700
# 169/169 [==============================] - 0s 569us/step - loss: 0.2780 - accuracy: 0.8809 - precision_class_0: 0.8979 - recall_class_0: 0.6792 - precision_class_1: 0.9254 - recall_class_1: 0.8695 - precision_class_2: 0.9741 - recall_class_2: 0.9706 - precision_class_3: 0.8823 - recall_class_3: 0.8510 - precision_class_4: 0.8004 - recall_class_4: 0.8683
# Epoch 35/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.2688 - accuracy: 0.8915 - precision_class_0: 0.9250 - recall_class_0: 0.6383 - precision_class_1: 0.9510 - recall_class_1: 0.8940 - precision_class_2: 0.9557 - recall_class_2: 0.9594 - precision_class_3: 0.9246 - recall_class_3: 0.8988 - precision_class_4: 0.8119 - recall_class_4: 0.8974
# Epoch 36/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.3261 - accuracy: 0.8578 - precision_class_0: 0.8637 - recall_class_0: 0.7000 - precision_class_1: 0.9197 - recall_class_1: 0.8592 - precision_class_2: 0.9781 - recall_class_2: 0.9688 - precision_class_3: 0.9011 - recall_class_3: 0.8188 - precision_class_4: 0.7637 - recall_class_4: 0.8152
# Epoch 37/700
# 169/169 [==============================] - 0s 563us/step - loss: 0.3656 - accuracy: 0.8583 - precision_class_0: 0.8657 - recall_class_0: 0.6375 - precision_class_1: 0.9287 - recall_class_1: 0.8693 - precision_class_2: 0.9655 - recall_class_2: 0.9658 - precision_class_3: 0.9014 - recall_class_3: 0.7977 - precision_class_4: 0.7626 - recall_class_4: 0.8493
# Epoch 38/700
# 169/169 [==============================] - 0s 588us/step - loss: 0.4542 - accuracy: 0.8222 - precision_class_0: 0.8320 - recall_class_0: 0.5650 - precision_class_1: 0.8926 - recall_class_1: 0.8134 - precision_class_2: 0.9376 - recall_class_2: 0.9534 - precision_class_3: 0.8234 - recall_class_3: 0.7079 - precision_class_4: 0.7338 - recall_class_4: 0.6844
# Epoch 39/700
# 169/169 [==============================] - 0s 568us/step - loss: 0.2631 - accuracy: 0.8848 - precision_class_0: 0.9122 - recall_class_0: 0.7034 - precision_class_1: 0.9466 - recall_class_1: 0.8676 - precision_class_2: 0.9757 - recall_class_2: 0.9704 - precision_class_3: 0.8973 - recall_class_3: 0.8318 - precision_class_4: 0.7953 - recall_class_4: 0.8732
# Epoch 40/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.2858 - accuracy: 0.8662 - precision_class_0: 0.8684 - recall_class_0: 0.7027 - precision_class_1: 0.9463 - recall_class_1: 0.8558 - precision_class_2: 0.9899 - recall_class_2: 0.9488 - precision_class_3: 0.9366 - recall_class_3: 0.8046 - precision_class_4: 0.7519 - recall_class_4: 0.8283
# Epoch 41/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.2602 - accuracy: 0.8874 - precision_class_0: 0.9145 - recall_class_0: 0.7261 - precision_class_1: 0.9444 - recall_class_1: 0.8819 - precision_class_2: 0.9878 - recall_class_2: 0.9769 - precision_class_3: 0.9108 - recall_class_3: 0.8627 - precision_class_4: 0.8081 - recall_class_4: 0.8904
# Epoch 42/700
# 169/169 [==============================] - 0s 563us/step - loss: 0.2878 - accuracy: 0.8796 - precision_class_0: 0.9242 - recall_class_0: 0.6611 - precision_class_1: 0.9535 - recall_class_1: 0.8666 - precision_class_2: 0.9485 - recall_class_2: 0.9626 - precision_class_3: 0.8736 - recall_class_3: 0.8836 - precision_class_4: 0.7865 - recall_class_4: 0.8936
# Epoch 43/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.3030 - accuracy: 0.8774 - precision_class_0: 0.8613 - recall_class_0: 0.6706 - precision_class_1: 0.9346 - recall_class_1: 0.8830 - precision_class_2: 0.9635 - recall_class_2: 0.9336 - precision_class_3: 0.8983 - recall_class_3: 0.8385 - precision_class_4: 0.8031 - recall_class_4: 0.8923
# Epoch 44/700
# 169/169 [==============================] - 0s 561us/step - loss: 0.3192 - accuracy: 0.8614 - precision_class_0: 0.9208 - recall_class_0: 0.7583 - precision_class_1: 0.9146 - recall_class_1: 0.8544 - precision_class_2: 0.9795 - recall_class_2: 0.9756 - precision_class_3: 0.8553 - recall_class_3: 0.7743 - precision_class_4: 0.7866 - recall_class_4: 0.8261
# Epoch 45/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.2401 - accuracy: 0.8915 - precision_class_0: 0.9198 - recall_class_0: 0.7554 - precision_class_1: 0.9507 - recall_class_1: 0.8700 - precision_class_2: 0.9951 - recall_class_2: 0.9774 - precision_class_3: 0.9106 - recall_class_3: 0.8744 - precision_class_4: 0.8111 - recall_class_4: 0.8899
# Epoch 46/700
# 169/169 [==============================] - 0s 609us/step - loss: 0.2543 - accuracy: 0.8817 - precision_class_0: 0.9090 - recall_class_0: 0.6670 - precision_class_1: 0.9489 - recall_class_1: 0.8779 - precision_class_2: 0.9697 - recall_class_2: 0.9581 - precision_class_3: 0.9428 - recall_class_3: 0.9109 - precision_class_4: 0.7793 - recall_class_4: 0.8802
# Epoch 47/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.2577 - accuracy: 0.8847 - precision_class_0: 0.8996 - recall_class_0: 0.6813 - precision_class_1: 0.9573 - recall_class_1: 0.8831 - precision_class_2: 0.9847 - recall_class_2: 0.9757 - precision_class_3: 0.9012 - recall_class_3: 0.8325 - precision_class_4: 0.7853 - recall_class_4: 0.8715
# Epoch 48/700
# 169/169 [==============================] - 0s 568us/step - loss: 0.3429 - accuracy: 0.8418 - precision_class_0: 0.8738 - recall_class_0: 0.6236 - precision_class_1: 0.9168 - recall_class_1: 0.8204 - precision_class_2: 0.9720 - recall_class_2: 0.9721 - precision_class_3: 0.8126 - recall_class_3: 0.8158 - precision_class_4: 0.7169 - recall_class_4: 0.8235
# Epoch 49/700
# 169/169 [==============================] - 0s 569us/step - loss: 0.2613 - accuracy: 0.8812 - precision_class_0: 0.8755 - recall_class_0: 0.6603 - precision_class_1: 0.9351 - recall_class_1: 0.8794 - precision_class_2: 0.9940 - recall_class_2: 0.9840 - precision_class_3: 0.8948 - recall_class_3: 0.8405 - precision_class_4: 0.7860 - recall_class_4: 0.8845
# Epoch 50/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.2545 - accuracy: 0.8747 - precision_class_0: 0.9130 - recall_class_0: 0.7298 - precision_class_1: 0.9345 - recall_class_1: 0.8723 - precision_class_2: 0.9922 - recall_class_2: 0.9735 - precision_class_3: 0.9082 - recall_class_3: 0.8723 - precision_class_4: 0.7550 - recall_class_4: 0.8397
# Epoch 51/700
# 169/169 [==============================] - 0s 562us/step - loss: 0.2985 - accuracy: 0.8756 - precision_class_0: 0.8699 - recall_class_0: 0.6488 - precision_class_1: 0.9386 - recall_class_1: 0.8791 - precision_class_2: 0.9472 - recall_class_2: 0.9461 - precision_class_3: 0.9216 - recall_class_3: 0.8758 - precision_class_4: 0.7843 - recall_class_4: 0.8808
# Epoch 52/700
# 169/169 [==============================] - 0s 568us/step - loss: 0.2290 - accuracy: 0.9007 - precision_class_0: 0.9113 - recall_class_0: 0.7331 - precision_class_1: 0.9528 - recall_class_1: 0.8918 - precision_class_2: 0.9936 - recall_class_2: 0.9632 - precision_class_3: 0.9488 - recall_class_3: 0.9042 - precision_class_4: 0.7981 - recall_class_4: 0.9030
# Epoch 53/700
# 169/169 [==============================] - 0s 570us/step - loss: 0.2633 - accuracy: 0.8825 - precision_class_0: 0.8208 - recall_class_0: 0.7059 - precision_class_1: 0.9369 - recall_class_1: 0.8905 - precision_class_2: 0.9840 - recall_class_2: 0.9075 - precision_class_3: 0.9615 - recall_class_3: 0.8930 - precision_class_4: 0.8097 - recall_class_4: 0.8754
# Epoch 54/700
# 169/169 [==============================] - 0s 570us/step - loss: 0.2425 - accuracy: 0.8903 - precision_class_0: 0.8802 - recall_class_0: 0.6575 - precision_class_1: 0.9498 - recall_class_1: 0.8919 - precision_class_2: 0.9796 - recall_class_2: 0.9543 - precision_class_3: 0.9681 - recall_class_3: 0.9356 - precision_class_4: 0.7590 - recall_class_4: 0.8674
# Epoch 55/700
# 169/169 [==============================] - 0s 571us/step - loss: 0.2396 - accuracy: 0.8974 - precision_class_0: 0.8817 - recall_class_0: 0.7097 - precision_class_1: 0.9572 - recall_class_1: 0.8937 - precision_class_2: 0.9721 - recall_class_2: 0.9570 - precision_class_3: 0.9427 - recall_class_3: 0.9115 - precision_class_4: 0.8233 - recall_class_4: 0.9212
# Epoch 56/700
# 169/169 [==============================] - 0s 572us/step - loss: 0.2291 - accuracy: 0.9026 - precision_class_0: 0.9286 - recall_class_0: 0.7466 - precision_class_1: 0.9491 - recall_class_1: 0.8925 - precision_class_2: 0.9856 - recall_class_2: 0.9760 - precision_class_3: 0.9283 - recall_class_3: 0.9080 - precision_class_4: 0.8048 - recall_class_4: 0.8972
# Epoch 57/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.3035 - accuracy: 0.8758 - precision_class_0: 0.8424 - recall_class_0: 0.6677 - precision_class_1: 0.9433 - recall_class_1: 0.8816 - precision_class_2: 0.9805 - recall_class_2: 0.9457 - precision_class_3: 0.9016 - recall_class_3: 0.8567 - precision_class_4: 0.7711 - recall_class_4: 0.8511
# Epoch 58/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.2281 - accuracy: 0.8948 - precision_class_0: 0.8976 - recall_class_0: 0.7349 - precision_class_1: 0.9418 - recall_class_1: 0.8926 - precision_class_2: 0.9979 - recall_class_2: 0.9852 - precision_class_3: 0.9548 - recall_class_3: 0.9001 - precision_class_4: 0.7995 - recall_class_4: 0.8816
# Epoch 59/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.2360 - accuracy: 0.8876 - precision_class_0: 0.8965 - recall_class_0: 0.7165 - precision_class_1: 0.9487 - recall_class_1: 0.8818 - precision_class_2: 0.9938 - recall_class_2: 0.9785 - precision_class_3: 0.9280 - recall_class_3: 0.8908 - precision_class_4: 0.7803 - recall_class_4: 0.8723
# Epoch 60/700
# 169/169 [==============================] - 0s 562us/step - loss: 0.2972 - accuracy: 0.8748 - precision_class_0: 0.8974 - recall_class_0: 0.7043 - precision_class_1: 0.9283 - recall_class_1: 0.8683 - precision_class_2: 0.9700 - recall_class_2: 0.9669 - precision_class_3: 0.9082 - recall_class_3: 0.8036 - precision_class_4: 0.7752 - recall_class_4: 0.8784
# Epoch 61/700
# 169/169 [==============================] - 0s 592us/step - loss: 0.2209 - accuracy: 0.8944 - precision_class_0: 0.9238 - recall_class_0: 0.7937 - precision_class_1: 0.9441 - recall_class_1: 0.8876 - precision_class_2: 0.9914 - recall_class_2: 0.9795 - precision_class_3: 0.9173 - recall_class_3: 0.8980 - precision_class_4: 0.7896 - recall_class_4: 0.8708
# Epoch 62/700
# 169/169 [==============================] - 0s 563us/step - loss: 0.2471 - accuracy: 0.8812 - precision_class_0: 0.8814 - recall_class_0: 0.7233 - precision_class_1: 0.9489 - recall_class_1: 0.8626 - precision_class_2: 0.9909 - recall_class_2: 0.9635 - precision_class_3: 0.9182 - recall_class_3: 0.8889 - precision_class_4: 0.7837 - recall_class_4: 0.8815
# Epoch 63/700
# 169/169 [==============================] - 0s 565us/step - loss: 0.2096 - accuracy: 0.9069 - precision_class_0: 0.8582 - recall_class_0: 0.6870 - precision_class_1: 0.9565 - recall_class_1: 0.9007 - precision_class_2: 0.9912 - recall_class_2: 0.9814 - precision_class_3: 0.9360 - recall_class_3: 0.8804 - precision_class_4: 0.8137 - recall_class_4: 0.9100
# Epoch 64/700
# 169/169 [==============================] - 0s 572us/step - loss: 0.2225 - accuracy: 0.9010 - precision_class_0: 0.8707 - recall_class_0: 0.6683 - precision_class_1: 0.9543 - recall_class_1: 0.9053 - precision_class_2: 0.9904 - recall_class_2: 0.9869 - precision_class_3: 0.9750 - recall_class_3: 0.9194 - precision_class_4: 0.8120 - recall_class_4: 0.8984
# Epoch 65/700
# 169/169 [==============================] - 0s 572us/step - loss: 0.2425 - accuracy: 0.8890 - precision_class_0: 0.9072 - recall_class_0: 0.7290 - precision_class_1: 0.9318 - recall_class_1: 0.8917 - precision_class_2: 0.9854 - recall_class_2: 0.9660 - precision_class_3: 0.9299 - recall_class_3: 0.8938 - precision_class_4: 0.7914 - recall_class_4: 0.8674
# Epoch 66/700
# 169/169 [==============================] - 0s 570us/step - loss: 0.2095 - accuracy: 0.9043 - precision_class_0: 0.9253 - recall_class_0: 0.7633 - precision_class_1: 0.9555 - recall_class_1: 0.8901 - precision_class_2: 0.9898 - recall_class_2: 0.9758 - precision_class_3: 0.9438 - recall_class_3: 0.9241 - precision_class_4: 0.8114 - recall_class_4: 0.8927
# Epoch 67/700
# 169/169 [==============================] - 0s 570us/step - loss: 0.2456 - accuracy: 0.8939 - precision_class_0: 0.8984 - recall_class_0: 0.7092 - precision_class_1: 0.9480 - recall_class_1: 0.8943 - precision_class_2: 0.9780 - recall_class_2: 0.9690 - precision_class_3: 0.9483 - recall_class_3: 0.9174 - precision_class_4: 0.8077 - recall_class_4: 0.8820
# Epoch 68/700
# 169/169 [==============================] - 0s 560us/step - loss: 0.1975 - accuracy: 0.9063 - precision_class_0: 0.9280 - recall_class_0: 0.7033 - precision_class_1: 0.9609 - recall_class_1: 0.8974 - precision_class_2: 0.9864 - recall_class_2: 0.9837 - precision_class_3: 0.9772 - recall_class_3: 0.9372 - precision_class_4: 0.7947 - recall_class_4: 0.9084
# Epoch 69/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.2305 - accuracy: 0.9025 - precision_class_0: 0.9558 - recall_class_0: 0.7130 - precision_class_1: 0.9533 - recall_class_1: 0.8921 - precision_class_2: 0.9959 - recall_class_2: 0.9945 - precision_class_3: 0.9557 - recall_class_3: 0.9076 - precision_class_4: 0.8077 - recall_class_4: 0.9213
# Epoch 70/700
# 169/169 [==============================] - 0s 569us/step - loss: 0.2275 - accuracy: 0.8952 - precision_class_0: 0.9084 - recall_class_0: 0.7470 - precision_class_1: 0.9553 - recall_class_1: 0.8758 - precision_class_2: 0.9659 - recall_class_2: 0.9801 - precision_class_3: 0.9489 - recall_class_3: 0.9202 - precision_class_4: 0.7955 - recall_class_4: 0.8962
# Epoch 71/700
# 169/169 [==============================] - 0s 563us/step - loss: 0.3164 - accuracy: 0.8669 - precision_class_0: 0.8126 - recall_class_0: 0.6326 - precision_class_1: 0.9406 - recall_class_1: 0.8747 - precision_class_2: 0.9182 - recall_class_2: 0.9147 - precision_class_3: 0.8953 - recall_class_3: 0.8394 - precision_class_4: 0.7720 - recall_class_4: 0.8710
# Epoch 72/700
# 169/169 [==============================] - 0s 563us/step - loss: 0.2240 - accuracy: 0.9010 - precision_class_0: 0.8964 - recall_class_0: 0.7282 - precision_class_1: 0.9562 - recall_class_1: 0.8959 - precision_class_2: 0.9878 - recall_class_2: 0.9655 - precision_class_3: 0.9632 - recall_class_3: 0.9093 - precision_class_4: 0.8025 - recall_class_4: 0.9018
# Epoch 73/700
# 169/169 [==============================] - 0s 560us/step - loss: 0.2316 - accuracy: 0.8972 - precision_class_0: 0.9069 - recall_class_0: 0.7149 - precision_class_1: 0.9571 - recall_class_1: 0.8789 - precision_class_2: 0.9796 - recall_class_2: 0.9804 - precision_class_3: 0.9386 - recall_class_3: 0.9055 - precision_class_4: 0.8010 - recall_class_4: 0.9146
# Epoch 74/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.2135 - accuracy: 0.9119 - precision_class_0: 0.8818 - recall_class_0: 0.7713 - precision_class_1: 0.9600 - recall_class_1: 0.9133 - precision_class_2: 0.9810 - recall_class_2: 0.9601 - precision_class_3: 0.9639 - recall_class_3: 0.9335 - precision_class_4: 0.8313 - recall_class_4: 0.8633
# Epoch 75/700
# 169/169 [==============================] - 0s 591us/step - loss: 0.2581 - accuracy: 0.8792 - precision_class_0: 0.8729 - recall_class_0: 0.7037 - precision_class_1: 0.9264 - recall_class_1: 0.8740 - precision_class_2: 0.9809 - recall_class_2: 0.9713 - precision_class_3: 0.8972 - recall_class_3: 0.8471 - precision_class_4: 0.7884 - recall_class_4: 0.8330
# Epoch 76/700
# 169/169 [==============================] - 0s 565us/step - loss: 0.2221 - accuracy: 0.9015 - precision_class_0: 0.8958 - recall_class_0: 0.7287 - precision_class_1: 0.9630 - recall_class_1: 0.8955 - precision_class_2: 0.9802 - recall_class_2: 0.9826 - precision_class_3: 0.9342 - recall_class_3: 0.8714 - precision_class_4: 0.7922 - recall_class_4: 0.9043
# Epoch 77/700
# 169/169 [==============================] - 0s 569us/step - loss: 0.2147 - accuracy: 0.8990 - precision_class_0: 0.8725 - recall_class_0: 0.7663 - precision_class_1: 0.9442 - recall_class_1: 0.8805 - precision_class_2: 0.9654 - recall_class_2: 0.9777 - precision_class_3: 0.9623 - recall_class_3: 0.9233 - precision_class_4: 0.8295 - recall_class_4: 0.8836
# Epoch 78/700
# 169/169 [==============================] - 0s 565us/step - loss: 0.2180 - accuracy: 0.8995 - precision_class_0: 0.8669 - recall_class_0: 0.6826 - precision_class_1: 0.9634 - recall_class_1: 0.8987 - precision_class_2: 0.9627 - recall_class_2: 0.9760 - precision_class_3: 0.9244 - recall_class_3: 0.9055 - precision_class_4: 0.8341 - recall_class_4: 0.9023
# Epoch 79/700
# 169/169 [==============================] - 0s 568us/step - loss: 0.3186 - accuracy: 0.8867 - precision_class_0: 0.8795 - recall_class_0: 0.7535 - precision_class_1: 0.9243 - recall_class_1: 0.8933 - precision_class_2: 0.9789 - recall_class_2: 0.9684 - precision_class_3: 0.9262 - recall_class_3: 0.8588 - precision_class_4: 0.7945 - recall_class_4: 0.8140
# Epoch 80/700
# 169/169 [==============================] - 0s 571us/step - loss: 0.2072 - accuracy: 0.9013 - precision_class_0: 0.9540 - recall_class_0: 0.7480 - precision_class_1: 0.9595 - recall_class_1: 0.8792 - precision_class_2: 0.9984 - recall_class_2: 0.9912 - precision_class_3: 0.9079 - recall_class_3: 0.8697 - precision_class_4: 0.7965 - recall_class_4: 0.9228
# Epoch 81/700
# 169/169 [==============================] - 0s 569us/step - loss: 0.1881 - accuracy: 0.9140 - precision_class_0: 0.9004 - recall_class_0: 0.7864 - precision_class_1: 0.9585 - recall_class_1: 0.8999 - precision_class_2: 0.9981 - recall_class_2: 0.9886 - precision_class_3: 0.9673 - recall_class_3: 0.9213 - precision_class_4: 0.8430 - recall_class_4: 0.9069
# Epoch 82/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.3065 - accuracy: 0.8766 - precision_class_0: 0.8937 - recall_class_0: 0.7012 - precision_class_1: 0.9246 - recall_class_1: 0.8770 - precision_class_2: 0.9676 - recall_class_2: 0.9569 - precision_class_3: 0.9175 - recall_class_3: 0.8470 - precision_class_4: 0.7903 - recall_class_4: 0.8361
# Epoch 83/700
# 169/169 [==============================] - 0s 570us/step - loss: 0.2494 - accuracy: 0.8864 - precision_class_0: 0.8032 - recall_class_0: 0.7010 - precision_class_1: 0.9687 - recall_class_1: 0.8794 - precision_class_2: 0.9570 - recall_class_2: 0.9499 - precision_class_3: 0.9490 - recall_class_3: 0.8955 - precision_class_4: 0.8201 - recall_class_4: 0.8883
# Epoch 84/700
# 169/169 [==============================] - 0s 557us/step - loss: 0.2027 - accuracy: 0.9049 - precision_class_0: 0.8321 - recall_class_0: 0.7443 - precision_class_1: 0.9821 - recall_class_1: 0.8990 - precision_class_2: 0.9753 - recall_class_2: 0.9409 - precision_class_3: 0.9586 - recall_class_3: 0.9571 - precision_class_4: 0.7954 - recall_class_4: 0.9103
# Epoch 85/700
# 169/169 [==============================] - 0s 561us/step - loss: 0.1983 - accuracy: 0.9066 - precision_class_0: 0.8355 - recall_class_0: 0.7538 - precision_class_1: 0.9460 - recall_class_1: 0.8976 - precision_class_2: 0.9976 - recall_class_2: 0.9730 - precision_class_3: 0.9534 - recall_class_3: 0.9384 - precision_class_4: 0.8313 - recall_class_4: 0.8647
# Epoch 86/700
# 169/169 [==============================] - 0s 560us/step - loss: 0.1894 - accuracy: 0.9077 - precision_class_0: 0.9002 - recall_class_0: 0.7669 - precision_class_1: 0.9578 - recall_class_1: 0.9080 - precision_class_2: 0.9985 - recall_class_2: 0.9855 - precision_class_3: 0.9638 - recall_class_3: 0.9591 - precision_class_4: 0.8248 - recall_class_4: 0.8759
# Epoch 87/700
# 169/169 [==============================] - 0s 551us/step - loss: 0.2215 - accuracy: 0.9041 - precision_class_0: 0.8596 - recall_class_0: 0.7091 - precision_class_1: 0.9503 - recall_class_1: 0.9009 - precision_class_2: 0.9798 - recall_class_2: 0.9781 - precision_class_3: 0.9512 - recall_class_3: 0.9273 - precision_class_4: 0.8172 - recall_class_4: 0.8894
# Epoch 88/700
# 169/169 [==============================] - 0s 560us/step - loss: 0.2331 - accuracy: 0.9005 - precision_class_0: 0.8973 - recall_class_0: 0.7540 - precision_class_1: 0.9451 - recall_class_1: 0.8796 - precision_class_2: 0.9912 - recall_class_2: 0.9828 - precision_class_3: 0.9316 - recall_class_3: 0.8817 - precision_class_4: 0.8168 - recall_class_4: 0.9038
# Epoch 89/700
# 169/169 [==============================] - 0s 556us/step - loss: 0.1817 - accuracy: 0.9105 - precision_class_0: 0.8863 - recall_class_0: 0.8106 - precision_class_1: 0.9569 - recall_class_1: 0.9117 - precision_class_2: 0.9812 - recall_class_2: 0.9866 - precision_class_3: 0.9657 - recall_class_3: 0.9294 - precision_class_4: 0.8407 - recall_class_4: 0.8503
# Epoch 90/700
# 169/169 [==============================] - 0s 560us/step - loss: 0.1938 - accuracy: 0.9162 - precision_class_0: 0.8994 - recall_class_0: 0.7900 - precision_class_1: 0.9676 - recall_class_1: 0.8946 - precision_class_2: 0.9806 - recall_class_2: 0.9709 - precision_class_3: 0.9578 - recall_class_3: 0.9418 - precision_class_4: 0.8314 - recall_class_4: 0.9270
# Epoch 91/700
# 169/169 [==============================] - 0s 557us/step - loss: 0.2465 - accuracy: 0.8884 - precision_class_0: 0.8818 - recall_class_0: 0.7196 - precision_class_1: 0.9496 - recall_class_1: 0.8802 - precision_class_2: 0.9938 - recall_class_2: 0.9615 - precision_class_3: 0.9039 - recall_class_3: 0.8950 - precision_class_4: 0.7858 - recall_class_4: 0.8971
# Epoch 92/700
# 169/169 [==============================] - 0s 556us/step - loss: 0.3191 - accuracy: 0.8757 - precision_class_0: 0.8344 - recall_class_0: 0.6783 - precision_class_1: 0.9553 - recall_class_1: 0.8698 - precision_class_2: 0.9710 - recall_class_2: 0.9538 - precision_class_3: 0.8991 - recall_class_3: 0.8959 - precision_class_4: 0.7917 - recall_class_4: 0.8789
# Epoch 93/700
# 169/169 [==============================] - 0s 554us/step - loss: 0.2321 - accuracy: 0.8954 - precision_class_0: 0.9227 - recall_class_0: 0.6642 - precision_class_1: 0.9647 - recall_class_1: 0.8784 - precision_class_2: 0.9852 - recall_class_2: 0.9717 - precision_class_3: 0.9719 - recall_class_3: 0.9017 - precision_class_4: 0.7773 - recall_class_4: 0.9176
# Epoch 94/700
# 169/169 [==============================] - 0s 558us/step - loss: 0.2405 - accuracy: 0.8865 - precision_class_0: 0.8137 - recall_class_0: 0.7431 - precision_class_1: 0.9472 - recall_class_1: 0.8839 - precision_class_2: 0.9771 - recall_class_2: 0.9701 - precision_class_3: 0.9343 - recall_class_3: 0.9247 - precision_class_4: 0.8175 - recall_class_4: 0.8472
# Epoch 95/700
# 169/169 [==============================] - 0s 558us/step - loss: 0.1987 - accuracy: 0.9126 - precision_class_0: 0.9216 - recall_class_0: 0.7879 - precision_class_1: 0.9675 - recall_class_1: 0.8874 - precision_class_2: 0.9838 - recall_class_2: 0.9913 - precision_class_3: 0.9782 - recall_class_3: 0.9364 - precision_class_4: 0.8105 - recall_class_4: 0.9011
# Epoch 96/700
# 169/169 [==============================] - 0s 560us/step - loss: 0.3112 - accuracy: 0.8851 - precision_class_0: 0.8712 - recall_class_0: 0.6713 - precision_class_1: 0.9490 - recall_class_1: 0.8792 - precision_class_2: 0.9725 - recall_class_2: 0.9599 - precision_class_3: 0.9298 - recall_class_3: 0.8948 - precision_class_4: 0.7761 - recall_class_4: 0.9077
# Epoch 97/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.1978 - accuracy: 0.9009 - precision_class_0: 0.9318 - recall_class_0: 0.7067 - precision_class_1: 0.9757 - recall_class_1: 0.8842 - precision_class_2: 0.9931 - recall_class_2: 0.9866 - precision_class_3: 0.9655 - recall_class_3: 0.9413 - precision_class_4: 0.7978 - recall_class_4: 0.9045
# Epoch 98/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.1976 - accuracy: 0.9034 - precision_class_0: 0.8847 - recall_class_0: 0.7665 - precision_class_1: 0.9389 - recall_class_1: 0.8894 - precision_class_2: 0.9931 - recall_class_2: 0.9861 - precision_class_3: 0.9538 - recall_class_3: 0.9278 - precision_class_4: 0.8169 - recall_class_4: 0.8881
# Epoch 99/700
# 169/169 [==============================] - 0s 590us/step - loss: 0.2602 - accuracy: 0.8871 - precision_class_0: 0.8737 - recall_class_0: 0.7851 - precision_class_1: 0.9387 - recall_class_1: 0.8704 - precision_class_2: 0.9985 - recall_class_2: 0.9922 - precision_class_3: 0.9258 - recall_class_3: 0.9005 - precision_class_4: 0.7701 - recall_class_4: 0.8224
# Epoch 100/700
# 169/169 [==============================] - 0s 573us/step - loss: 0.2072 - accuracy: 0.9100 - precision_class_0: 0.9164 - recall_class_0: 0.6850 - precision_class_1: 0.9623 - recall_class_1: 0.9015 - precision_class_2: 0.9765 - recall_class_2: 0.9696 - precision_class_3: 0.9906 - recall_class_3: 0.9431 - precision_class_4: 0.8198 - recall_class_4: 0.9228
# Epoch 101/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.1930 - accuracy: 0.9184 - precision_class_0: 0.9133 - recall_class_0: 0.8056 - precision_class_1: 0.9663 - recall_class_1: 0.9091 - precision_class_2: 0.9853 - recall_class_2: 0.9683 - precision_class_3: 0.9520 - recall_class_3: 0.9533 - precision_class_4: 0.8138 - recall_class_4: 0.8977
# Epoch 102/700
# 169/169 [==============================] - 0s 562us/step - loss: 0.1581 - accuracy: 0.9227 - precision_class_0: 0.9395 - recall_class_0: 0.7440 - precision_class_1: 0.9644 - recall_class_1: 0.9149 - precision_class_2: 0.9955 - recall_class_2: 0.9920 - precision_class_3: 0.9821 - recall_class_3: 0.9635 - precision_class_4: 0.8417 - recall_class_4: 0.9172
# Epoch 103/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.1816 - accuracy: 0.9154 - precision_class_0: 0.8965 - recall_class_0: 0.7646 - precision_class_1: 0.9687 - recall_class_1: 0.9152 - precision_class_2: 0.9969 - recall_class_2: 0.9872 - precision_class_3: 0.9614 - recall_class_3: 0.9454 - precision_class_4: 0.8225 - recall_class_4: 0.8975
# Epoch 104/700
# 169/169 [==============================] - 0s 565us/step - loss: 0.1985 - accuracy: 0.9067 - precision_class_0: 0.8587 - recall_class_0: 0.7506 - precision_class_1: 0.9513 - recall_class_1: 0.8954 - precision_class_2: 0.9909 - recall_class_2: 0.9726 - precision_class_3: 0.9516 - recall_class_3: 0.9446 - precision_class_4: 0.8361 - recall_class_4: 0.8926
# Epoch 105/700
# 169/169 [==============================] - 0s 560us/step - loss: 0.2466 - accuracy: 0.9018 - precision_class_0: 0.8502 - recall_class_0: 0.6684 - precision_class_1: 0.9448 - recall_class_1: 0.9153 - precision_class_2: 0.9699 - recall_class_2: 0.9431 - precision_class_3: 0.9552 - recall_class_3: 0.9404 - precision_class_4: 0.8442 - recall_class_4: 0.8938
# Epoch 106/700
# 169/169 [==============================] - 0s 565us/step - loss: 0.2740 - accuracy: 0.8846 - precision_class_0: 0.8365 - recall_class_0: 0.6872 - precision_class_1: 0.9441 - recall_class_1: 0.8849 - precision_class_2: 0.9696 - recall_class_2: 0.9537 - precision_class_3: 0.9277 - recall_class_3: 0.8881 - precision_class_4: 0.8030 - recall_class_4: 0.8866
# Epoch 107/700
# 169/169 [==============================] - 0s 560us/step - loss: 0.1975 - accuracy: 0.8975 - precision_class_0: 0.8457 - recall_class_0: 0.7684 - precision_class_1: 0.9480 - recall_class_1: 0.8933 - precision_class_2: 0.9750 - recall_class_2: 0.9766 - precision_class_3: 0.9632 - recall_class_3: 0.9268 - precision_class_4: 0.8156 - recall_class_4: 0.8497
# Epoch 108/700
# 169/169 [==============================] - 0s 563us/step - loss: 0.1687 - accuracy: 0.9080 - precision_class_0: 0.9071 - recall_class_0: 0.7632 - precision_class_1: 0.9504 - recall_class_1: 0.9064 - precision_class_2: 0.9886 - recall_class_2: 0.9855 - precision_class_3: 0.9862 - recall_class_3: 0.9513 - precision_class_4: 0.7922 - recall_class_4: 0.8759
# Epoch 109/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.2170 - accuracy: 0.8969 - precision_class_0: 0.8494 - recall_class_0: 0.7780 - precision_class_1: 0.9433 - recall_class_1: 0.8884 - precision_class_2: 0.9974 - recall_class_2: 0.9796 - precision_class_3: 0.9318 - recall_class_3: 0.9099 - precision_class_4: 0.8063 - recall_class_4: 0.8658
# Epoch 110/700
# 169/169 [==============================] - 0s 563us/step - loss: 0.1791 - accuracy: 0.9122 - precision_class_0: 0.9566 - recall_class_0: 0.7268 - precision_class_1: 0.9589 - recall_class_1: 0.8996 - precision_class_2: 0.9879 - recall_class_2: 0.9859 - precision_class_3: 0.9458 - recall_class_3: 0.9354 - precision_class_4: 0.8212 - recall_class_4: 0.9328
# Epoch 111/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.1964 - accuracy: 0.9093 - precision_class_0: 0.9009 - recall_class_0: 0.6923 - precision_class_1: 0.9659 - recall_class_1: 0.9095 - precision_class_2: 0.9901 - recall_class_2: 0.9777 - precision_class_3: 0.9754 - recall_class_3: 0.9435 - precision_class_4: 0.8184 - recall_class_4: 0.9320
# Epoch 112/700
# 169/169 [==============================] - 0s 569us/step - loss: 0.2942 - accuracy: 0.8822 - precision_class_0: 0.8503 - recall_class_0: 0.8021 - precision_class_1: 0.9205 - recall_class_1: 0.8803 - precision_class_2: 0.9790 - recall_class_2: 0.9763 - precision_class_3: 0.9289 - recall_class_3: 0.9011 - precision_class_4: 0.8017 - recall_class_4: 0.8133
# Epoch 113/700
# 169/169 [==============================] - 0s 568us/step - loss: 0.2601 - accuracy: 0.8924 - precision_class_0: 0.8856 - recall_class_0: 0.7404 - precision_class_1: 0.9582 - recall_class_1: 0.8767 - precision_class_2: 0.9971 - recall_class_2: 0.9584 - precision_class_3: 0.9610 - recall_class_3: 0.9292 - precision_class_4: 0.7876 - recall_class_4: 0.8704
# Epoch 114/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.1709 - accuracy: 0.9107 - precision_class_0: 0.9378 - recall_class_0: 0.6941 - precision_class_1: 0.9711 - recall_class_1: 0.8995 - precision_class_2: 0.9935 - recall_class_2: 0.9779 - precision_class_3: 0.9741 - recall_class_3: 0.9787 - precision_class_4: 0.8233 - recall_class_4: 0.9095
# Epoch 115/700
# 169/169 [==============================] - 0s 565us/step - loss: 0.1732 - accuracy: 0.9203 - precision_class_0: 0.8960 - recall_class_0: 0.7937 - precision_class_1: 0.9618 - recall_class_1: 0.9111 - precision_class_2: 0.9940 - recall_class_2: 0.9803 - precision_class_3: 0.9581 - recall_class_3: 0.9522 - precision_class_4: 0.8382 - recall_class_4: 0.8854
# Epoch 116/700
# 169/169 [==============================] - 0s 581us/step - loss: 0.2407 - accuracy: 0.8888 - precision_class_0: 0.8143 - recall_class_0: 0.7042 - precision_class_1: 0.9471 - recall_class_1: 0.8885 - precision_class_2: 0.9857 - recall_class_2: 0.9823 - precision_class_3: 0.9508 - recall_class_3: 0.9400 - precision_class_4: 0.7916 - recall_class_4: 0.8687
# Epoch 117/700
# 169/169 [==============================] - 0s 573us/step - loss: 0.2125 - accuracy: 0.8952 - precision_class_0: 0.8797 - recall_class_0: 0.7567 - precision_class_1: 0.9492 - recall_class_1: 0.8723 - precision_class_2: 0.9894 - recall_class_2: 0.9843 - precision_class_3: 0.9702 - recall_class_3: 0.9191 - precision_class_4: 0.8075 - recall_class_4: 0.8793
# Epoch 118/700
# 169/169 [==============================] - 0s 572us/step - loss: 0.1498 - accuracy: 0.9291 - precision_class_0: 0.9115 - recall_class_0: 0.7992 - precision_class_1: 0.9769 - recall_class_1: 0.9161 - precision_class_2: 1.0000 - recall_class_2: 0.9763 - precision_class_3: 0.9846 - recall_class_3: 0.9757 - precision_class_4: 0.8367 - recall_class_4: 0.9275
# Epoch 119/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.1649 - accuracy: 0.9226 - precision_class_0: 0.9440 - recall_class_0: 0.7205 - precision_class_1: 0.9589 - recall_class_1: 0.9219 - precision_class_2: 0.9965 - recall_class_2: 0.9921 - precision_class_3: 0.9685 - recall_class_3: 0.9487 - precision_class_4: 0.8356 - recall_class_4: 0.9230
# Epoch 120/700
# 169/169 [==============================] - 0s 583us/step - loss: 0.1944 - accuracy: 0.9082 - precision_class_0: 0.8765 - recall_class_0: 0.7899 - precision_class_1: 0.9634 - recall_class_1: 0.8886 - precision_class_2: 0.9857 - recall_class_2: 0.9718 - precision_class_3: 0.9446 - recall_class_3: 0.9289 - precision_class_4: 0.8124 - recall_class_4: 0.9044
# Epoch 121/700
# 169/169 [==============================] - 0s 574us/step - loss: 0.2055 - accuracy: 0.9023 - precision_class_0: 0.8590 - recall_class_0: 0.7599 - precision_class_1: 0.9609 - recall_class_1: 0.9010 - precision_class_2: 0.9724 - recall_class_2: 0.9569 - precision_class_3: 0.9526 - recall_class_3: 0.9578 - precision_class_4: 0.8331 - recall_class_4: 0.8947
# Epoch 122/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.3058 - accuracy: 0.8925 - precision_class_0: 0.8429 - recall_class_0: 0.7149 - precision_class_1: 0.9344 - recall_class_1: 0.9252 - precision_class_2: 0.9296 - recall_class_2: 0.9470 - precision_class_3: 0.9470 - recall_class_3: 0.9126 - precision_class_4: 0.8391 - recall_class_4: 0.8363
# Epoch 123/700
# 169/169 [==============================] - 0s 565us/step - loss: 0.2439 - accuracy: 0.8861 - precision_class_0: 0.9274 - recall_class_0: 0.7352 - precision_class_1: 0.9622 - recall_class_1: 0.8731 - precision_class_2: 0.9841 - recall_class_2: 0.9800 - precision_class_3: 0.8890 - recall_class_3: 0.8517 - precision_class_4: 0.7840 - recall_class_4: 0.8961
# Epoch 124/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.1589 - accuracy: 0.9218 - precision_class_0: 0.8743 - recall_class_0: 0.7524 - precision_class_1: 0.9626 - recall_class_1: 0.9097 - precision_class_2: 0.9915 - recall_class_2: 0.9866 - precision_class_3: 0.9826 - recall_class_3: 0.9702 - precision_class_4: 0.8476 - recall_class_4: 0.8986
# Epoch 125/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.1576 - accuracy: 0.9239 - precision_class_0: 0.8881 - recall_class_0: 0.7431 - precision_class_1: 0.9832 - recall_class_1: 0.9194 - precision_class_2: 0.9893 - recall_class_2: 0.9870 - precision_class_3: 0.9769 - recall_class_3: 0.9604 - precision_class_4: 0.8295 - recall_class_4: 0.9279
# Epoch 126/700
# 169/169 [==============================] - 0s 560us/step - loss: 0.1646 - accuracy: 0.9218 - precision_class_0: 0.9354 - recall_class_0: 0.7915 - precision_class_1: 0.9616 - recall_class_1: 0.9110 - precision_class_2: 0.9971 - recall_class_2: 0.9866 - precision_class_3: 0.9580 - recall_class_3: 0.9602 - precision_class_4: 0.8475 - recall_class_4: 0.9098
# Epoch 127/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.1895 - accuracy: 0.9102 - precision_class_0: 0.8784 - recall_class_0: 0.7843 - precision_class_1: 0.9550 - recall_class_1: 0.8908 - precision_class_2: 0.9938 - recall_class_2: 0.9853 - precision_class_3: 0.9757 - recall_class_3: 0.9469 - precision_class_4: 0.8194 - recall_class_4: 0.9092
# Epoch 128/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.1842 - accuracy: 0.9226 - precision_class_0: 0.9114 - recall_class_0: 0.7769 - precision_class_1: 0.9696 - recall_class_1: 0.9230 - precision_class_2: 0.9992 - recall_class_2: 0.9925 - precision_class_3: 0.9627 - recall_class_3: 0.9388 - precision_class_4: 0.8487 - recall_class_4: 0.8953
# Epoch 129/700
# 169/169 [==============================] - 0s 568us/step - loss: 0.2470 - accuracy: 0.8914 - precision_class_0: 0.8752 - recall_class_0: 0.7571 - precision_class_1: 0.9411 - recall_class_1: 0.8833 - precision_class_2: 0.9855 - recall_class_2: 0.9688 - precision_class_3: 0.9309 - recall_class_3: 0.9180 - precision_class_4: 0.7859 - recall_class_4: 0.8532
# Epoch 130/700
# ...
# Epoch 658/700
# 169/169 [==============================] - 0s 584us/step - loss: 0.1318 - accuracy: 0.9385 - precision_class_0: 0.8998 - recall_class_0: 0.8118 - precision_class_1: 0.9702 - recall_class_1: 0.9467 - precision_class_2: 0.9684 - recall_class_2: 0.9747 - precision_class_3: 0.9962 - recall_class_3: 0.9999 - precision_class_4: 0.8642 - recall_class_4: 0.9202
# Epoch 659/700
# 169/169 [==============================] - 0s 577us/step - loss: 0.1173 - accuracy: 0.9393 - precision_class_0: 0.8944 - recall_class_0: 0.8567 - precision_class_1: 0.9806 - recall_class_1: 0.9392 - precision_class_2: 0.9979 - recall_class_2: 0.9794 - precision_class_3: 0.9948 - recall_class_3: 0.9701 - precision_class_4: 0.8490 - recall_class_4: 0.9247
# Epoch 660/700
# 169/169 [==============================] - 0s 578us/step - loss: 0.1184 - accuracy: 0.9371 - precision_class_0: 0.8427 - recall_class_0: 0.8681 - precision_class_1: 0.9554 - recall_class_1: 0.9553 - precision_class_2: 0.9926 - recall_class_2: 0.9917 - precision_class_3: 0.9689 - recall_class_3: 0.9789 - precision_class_4: 0.9068 - recall_class_4: 0.8580
# Epoch 661/700
# 169/169 [==============================] - 0s 627us/step - loss: 0.1074 - accuracy: 0.9446 - precision_class_0: 0.9376 - recall_class_0: 0.8588 - precision_class_1: 0.9570 - recall_class_1: 0.9573 - precision_class_2: 0.9963 - recall_class_2: 0.9947 - precision_class_3: 1.0000 - recall_class_3: 0.9975 - precision_class_4: 0.8903 - recall_class_4: 0.9035
# Epoch 662/700
# 169/169 [==============================] - 0s 584us/step - loss: 0.0978 - accuracy: 0.9512 - precision_class_0: 0.8920 - recall_class_0: 0.9302 - precision_class_1: 0.9659 - recall_class_1: 0.9472 - precision_class_2: 1.0000 - recall_class_2: 0.9903 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9149 - recall_class_4: 0.9097
# Epoch 663/700
# 169/169 [==============================] - 0s 597us/step - loss: 0.0992 - accuracy: 0.9456 - precision_class_0: 0.8721 - recall_class_0: 0.8858 - precision_class_1: 0.9627 - recall_class_1: 0.9543 - precision_class_2: 0.9972 - recall_class_2: 0.9919 - precision_class_3: 0.9896 - recall_class_3: 0.9936 - precision_class_4: 0.9043 - recall_class_4: 0.8987
# Epoch 664/700
# 169/169 [==============================] - 0s 570us/step - loss: 0.1030 - accuracy: 0.9429 - precision_class_0: 0.8809 - recall_class_0: 0.8802 - precision_class_1: 0.9464 - recall_class_1: 0.9686 - precision_class_2: 1.0000 - recall_class_2: 0.9943 - precision_class_3: 0.9975 - recall_class_3: 0.9962 - precision_class_4: 0.9218 - recall_class_4: 0.8562
# Epoch 665/700
# 169/169 [==============================] - 0s 603us/step - loss: 0.1492 - accuracy: 0.9418 - precision_class_0: 0.8838 - recall_class_0: 0.8820 - precision_class_1: 0.9702 - recall_class_1: 0.9404 - precision_class_2: 0.9958 - recall_class_2: 0.9846 - precision_class_3: 0.9843 - recall_class_3: 0.9768 - precision_class_4: 0.8826 - recall_class_4: 0.9180
# Epoch 666/700
# 169/169 [==============================] - 0s 576us/step - loss: 0.2452 - accuracy: 0.9104 - precision_class_0: 0.9273 - recall_class_0: 0.8458 - precision_class_1: 0.9255 - recall_class_1: 0.9152 - precision_class_2: 0.9948 - recall_class_2: 0.9837 - precision_class_3: 0.9097 - recall_class_3: 0.9439 - precision_class_4: 0.8564 - recall_class_4: 0.8555
# Epoch 667/700
# 169/169 [==============================] - 0s 580us/step - loss: 0.1415 - accuracy: 0.9344 - precision_class_0: 0.8894 - recall_class_0: 0.8449 - precision_class_1: 0.9742 - recall_class_1: 0.9281 - precision_class_2: 0.9891 - recall_class_2: 0.9942 - precision_class_3: 0.9939 - recall_class_3: 0.9923 - precision_class_4: 0.8495 - recall_class_4: 0.9026
# Epoch 668/700
# 169/169 [==============================] - 0s 574us/step - loss: 0.1841 - accuracy: 0.9326 - precision_class_0: 0.8831 - recall_class_0: 0.8863 - precision_class_1: 0.9664 - recall_class_1: 0.9240 - precision_class_2: 0.9958 - recall_class_2: 0.9846 - precision_class_3: 0.9654 - recall_class_3: 0.9642 - precision_class_4: 0.8689 - recall_class_4: 0.8986
# Epoch 669/700
# 169/169 [==============================] - 0s 603us/step - loss: 0.2065 - accuracy: 0.9277 - precision_class_0: 0.9367 - recall_class_0: 0.7836 - precision_class_1: 0.9729 - recall_class_1: 0.9130 - precision_class_2: 0.9880 - recall_class_2: 0.9790 - precision_class_3: 0.9504 - recall_class_3: 0.9913 - precision_class_4: 0.8332 - recall_class_4: 0.9281
# Epoch 670/700
# 169/169 [==============================] - 0s 571us/step - loss: 0.1124 - accuracy: 0.9395 - precision_class_0: 0.8477 - recall_class_0: 0.8795 - precision_class_1: 0.9783 - recall_class_1: 0.9290 - precision_class_2: 0.9995 - recall_class_2: 0.9836 - precision_class_3: 0.9993 - recall_class_3: 0.9985 - precision_class_4: 0.8750 - recall_class_4: 0.9125
# Epoch 671/700
# 169/169 [==============================] - 0s 575us/step - loss: 0.0916 - accuracy: 0.9543 - precision_class_0: 0.8996 - recall_class_0: 0.9386 - precision_class_1: 0.9665 - recall_class_1: 0.9498 - precision_class_2: 1.0000 - recall_class_2: 0.9965 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9228 - recall_class_4: 0.9092
# Epoch 672/700
# 169/169 [==============================] - 0s 569us/step - loss: 0.0987 - accuracy: 0.9465 - precision_class_0: 0.9004 - recall_class_0: 0.8753 - precision_class_1: 0.9720 - recall_class_1: 0.9450 - precision_class_2: 1.0000 - recall_class_2: 0.9945 - precision_class_3: 0.9947 - recall_class_3: 0.9984 - precision_class_4: 0.8912 - recall_class_4: 0.9108
# Epoch 673/700
# 169/169 [==============================] - 0s 607us/step - loss: 0.0807 - accuracy: 0.9564 - precision_class_0: 0.8867 - recall_class_0: 0.9189 - precision_class_1: 0.9787 - recall_class_1: 0.9567 - precision_class_2: 0.9996 - recall_class_2: 0.9979 - precision_class_3: 0.9918 - recall_class_3: 0.9926 - precision_class_4: 0.9144 - recall_class_4: 0.9187
# Epoch 674/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.1273 - accuracy: 0.9418 - precision_class_0: 0.8729 - recall_class_0: 0.8769 - precision_class_1: 0.9575 - recall_class_1: 0.9580 - precision_class_2: 0.9919 - recall_class_2: 0.9856 - precision_class_3: 1.0000 - recall_class_3: 1.0000 - precision_class_4: 0.9121 - recall_class_4: 0.8836
# Epoch 675/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.1069 - accuracy: 0.9331 - precision_class_0: 0.8545 - recall_class_0: 0.9147 - precision_class_1: 0.9495 - recall_class_1: 0.9466 - precision_class_2: 0.9990 - recall_class_2: 0.9887 - precision_class_3: 0.9978 - recall_class_3: 1.0000 - precision_class_4: 0.8835 - recall_class_4: 0.8382
# Epoch 676/700
# 169/169 [==============================] - 0s 562us/step - loss: 0.1160 - accuracy: 0.9401 - precision_class_0: 0.8638 - recall_class_0: 0.8877 - precision_class_1: 0.9470 - recall_class_1: 0.9558 - precision_class_2: 0.9960 - recall_class_2: 0.9912 - precision_class_3: 0.9982 - recall_class_3: 1.0000 - precision_class_4: 0.9062 - recall_class_4: 0.8612
# Epoch 677/700
# 169/169 [==============================] - 0s 618us/step - loss: 0.2138 - accuracy: 0.9284 - precision_class_0: 0.8733 - recall_class_0: 0.8663 - precision_class_1: 0.9396 - recall_class_1: 0.9465 - precision_class_2: 0.9924 - recall_class_2: 0.9901 - precision_class_3: 0.9490 - recall_class_3: 0.9668 - precision_class_4: 0.9042 - recall_class_4: 0.8623
# Epoch 678/700
# 169/169 [==============================] - 0s 573us/step - loss: 0.1551 - accuracy: 0.9251 - precision_class_0: 0.8977 - recall_class_0: 0.8524 - precision_class_1: 0.9412 - recall_class_1: 0.9160 - precision_class_2: 0.9947 - recall_class_2: 0.9925 - precision_class_3: 0.9525 - recall_class_3: 0.9350 - precision_class_4: 0.8936 - recall_class_4: 0.8930
# Epoch 679/700
# 169/169 [==============================] - 0s 564us/step - loss: 0.1232 - accuracy: 0.9348 - precision_class_0: 0.9252 - recall_class_0: 0.8528 - precision_class_1: 0.9448 - recall_class_1: 0.9571 - precision_class_2: 0.9961 - recall_class_2: 0.9902 - precision_class_3: 0.9819 - recall_class_3: 0.9735 - precision_class_4: 0.8757 - recall_class_4: 0.8844
# Epoch 680/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.0998 - accuracy: 0.9427 - precision_class_0: 0.9180 - recall_class_0: 0.8490 - precision_class_1: 0.9650 - recall_class_1: 0.9453 - precision_class_2: 0.9836 - recall_class_2: 0.9937 - precision_class_3: 0.9983 - recall_class_3: 0.9923 - precision_class_4: 0.8858 - recall_class_4: 0.9204
# Epoch 681/700
# 169/169 [==============================] - 0s 605us/step - loss: 0.1096 - accuracy: 0.9463 - precision_class_0: 0.9387 - recall_class_0: 0.8324 - precision_class_1: 0.9621 - recall_class_1: 0.9610 - precision_class_2: 0.9915 - recall_class_2: 0.9857 - precision_class_3: 0.9941 - recall_class_3: 0.9893 - precision_class_4: 0.8846 - recall_class_4: 0.9239
# Epoch 682/700
# 169/169 [==============================] - 0s 580us/step - loss: 0.1176 - accuracy: 0.9372 - precision_class_0: 0.8434 - recall_class_0: 0.9200 - precision_class_1: 0.9645 - recall_class_1: 0.9262 - precision_class_2: 0.9935 - recall_class_2: 0.9842 - precision_class_3: 0.9811 - recall_class_3: 0.9944 - precision_class_4: 0.8918 - recall_class_4: 0.8897
# Epoch 683/700
# 169/169 [==============================] - 0s 571us/step - loss: 0.1314 - accuracy: 0.9472 - precision_class_0: 0.9033 - recall_class_0: 0.9320 - precision_class_1: 0.9597 - recall_class_1: 0.9520 - precision_class_2: 1.0000 - recall_class_2: 0.9901 - precision_class_3: 0.9834 - recall_class_3: 0.9800 - precision_class_4: 0.9009 - recall_class_4: 0.8846
# Epoch 684/700
# 169/169 [==============================] - 0s 614us/step - loss: 0.1336 - accuracy: 0.9336 - precision_class_0: 0.8837 - recall_class_0: 0.9017 - precision_class_1: 0.9376 - recall_class_1: 0.9640 - precision_class_2: 0.9992 - recall_class_2: 0.9960 - precision_class_3: 0.9782 - recall_class_3: 0.9712 - precision_class_4: 0.8934 - recall_class_4: 0.8278
# Epoch 685/700
# 169/169 [==============================] - 0s 574us/step - loss: 0.1517 - accuracy: 0.9327 - precision_class_0: 0.8856 - recall_class_0: 0.8521 - precision_class_1: 0.9503 - recall_class_1: 0.9415 - precision_class_2: 0.9850 - recall_class_2: 0.9962 - precision_class_3: 0.9786 - recall_class_3: 0.9680 - precision_class_4: 0.8874 - recall_class_4: 0.8866
# Epoch 686/700
# 169/169 [==============================] - 0s 576us/step - loss: 0.1168 - accuracy: 0.9420 - precision_class_0: 0.8427 - recall_class_0: 0.8716 - precision_class_1: 0.9685 - recall_class_1: 0.9435 - precision_class_2: 0.9977 - recall_class_2: 0.9970 - precision_class_3: 0.9736 - recall_class_3: 0.9907 - precision_class_4: 0.8900 - recall_class_4: 0.8787
# Epoch 687/700
# 169/169 [==============================] - 0s 571us/step - loss: 0.0879 - accuracy: 0.9513 - precision_class_0: 0.8844 - recall_class_0: 0.8967 - precision_class_1: 0.9714 - recall_class_1: 0.9573 - precision_class_2: 1.0000 - recall_class_2: 0.9965 - precision_class_3: 1.0000 - recall_class_3: 0.9980 - precision_class_4: 0.9064 - recall_class_4: 0.9126
# Epoch 688/700
# 169/169 [==============================] - 0s 610us/step - loss: 0.0929 - accuracy: 0.9522 - precision_class_0: 0.8942 - recall_class_0: 0.9216 - precision_class_1: 0.9641 - recall_class_1: 0.9555 - precision_class_2: 0.9939 - recall_class_2: 0.9984 - precision_class_3: 1.0000 - recall_class_3: 0.9993 - precision_class_4: 0.9228 - recall_class_4: 0.9067
# Epoch 689/700
# 169/169 [==============================] - 0s 568us/step - loss: 0.1000 - accuracy: 0.9425 - precision_class_0: 0.9102 - recall_class_0: 0.9280 - precision_class_1: 0.9385 - recall_class_1: 0.9582 - precision_class_2: 0.9998 - recall_class_2: 0.9875 - precision_class_3: 0.9908 - recall_class_3: 0.9668 - precision_class_4: 0.9134 - recall_class_4: 0.8694
# Epoch 690/700
# 169/169 [==============================] - 0s 565us/step - loss: 0.1285 - accuracy: 0.9375 - precision_class_0: 0.8990 - recall_class_0: 0.8501 - precision_class_1: 0.9537 - recall_class_1: 0.9456 - precision_class_2: 0.9971 - recall_class_2: 0.9785 - precision_class_3: 0.9808 - recall_class_3: 0.9944 - precision_class_4: 0.8985 - recall_class_4: 0.8912
# Epoch 691/700
# 169/169 [==============================] - 0s 563us/step - loss: 0.1659 - accuracy: 0.9325 - precision_class_0: 0.8711 - recall_class_0: 0.8466 - precision_class_1: 0.9652 - recall_class_1: 0.9390 - precision_class_2: 0.9901 - recall_class_2: 0.9971 - precision_class_3: 0.9657 - recall_class_3: 0.9692 - precision_class_4: 0.8670 - recall_class_4: 0.8945
# Epoch 692/700
# 169/169 [==============================] - 0s 561us/step - loss: 0.1098 - accuracy: 0.9393 - precision_class_0: 0.9030 - recall_class_0: 0.8687 - precision_class_1: 0.9439 - recall_class_1: 0.9586 - precision_class_2: 0.9894 - recall_class_2: 0.9870 - precision_class_3: 0.9941 - recall_class_3: 0.9941 - precision_class_4: 0.8990 - recall_class_4: 0.8715
# Epoch 693/700
# 169/169 [==============================] - 0s 566us/step - loss: 0.1075 - accuracy: 0.9481 - precision_class_0: 0.8998 - recall_class_0: 0.8959 - precision_class_1: 0.9558 - recall_class_1: 0.9594 - precision_class_2: 0.9856 - recall_class_2: 0.9924 - precision_class_3: 0.9908 - recall_class_3: 0.9948 - precision_class_4: 0.9209 - recall_class_4: 0.8923
# Epoch 694/700
# 169/169 [==============================] - 0s 582us/step - loss: 0.2923 - accuracy: 0.9258 - precision_class_0: 0.8658 - recall_class_0: 0.8360 - precision_class_1: 0.9631 - recall_class_1: 0.9447 - precision_class_2: 0.9978 - recall_class_2: 0.9896 - precision_class_3: 0.9296 - recall_class_3: 0.9652 - precision_class_4: 0.8689 - recall_class_4: 0.8497
# Epoch 695/700
# 169/169 [==============================] - 0s 607us/step - loss: 0.1398 - accuracy: 0.9396 - precision_class_0: 0.8831 - recall_class_0: 0.8465 - precision_class_1: 0.9645 - recall_class_1: 0.9478 - precision_class_2: 0.9917 - recall_class_2: 0.9910 - precision_class_3: 0.9908 - recall_class_3: 0.9941 - precision_class_4: 0.8763 - recall_class_4: 0.8930
# Epoch 696/700
# 169/169 [==============================] - 0s 570us/step - loss: 0.1203 - accuracy: 0.9389 - precision_class_0: 0.9104 - recall_class_0: 0.8504 - precision_class_1: 0.9545 - recall_class_1: 0.9436 - precision_class_2: 0.9988 - recall_class_2: 0.9909 - precision_class_3: 0.9935 - recall_class_3: 0.9924 - precision_class_4: 0.8782 - recall_class_4: 0.9025
# Epoch 697/700
# 169/169 [==============================] - 0s 571us/step - loss: 0.1987 - accuracy: 0.9219 - precision_class_0: 0.9009 - recall_class_0: 0.8526 - precision_class_1: 0.9353 - recall_class_1: 0.9402 - precision_class_2: 0.9838 - recall_class_2: 0.9873 - precision_class_3: 0.9598 - recall_class_3: 0.9760 - precision_class_4: 0.8551 - recall_class_4: 0.8409
# Epoch 698/700
# 169/169 [==============================] - 0s 567us/step - loss: 0.1100 - accuracy: 0.9365 - precision_class_0: 0.9186 - recall_class_0: 0.8228 - precision_class_1: 0.9607 - recall_class_1: 0.9295 - precision_class_2: 0.9994 - recall_class_2: 0.9901 - precision_class_3: 0.9975 - recall_class_3: 1.0000 - precision_class_4: 0.8578 - recall_class_4: 0.9254
# Epoch 699/700
# 169/169 [==============================] - 0s 582us/step - loss: 0.1360 - accuracy: 0.9267 - precision_class_0: 0.8997 - recall_class_0: 0.8143 - precision_class_1: 0.9460 - recall_class_1: 0.9366 - precision_class_2: 0.9915 - recall_class_2: 0.9813 - precision_class_3: 0.9911 - recall_class_3: 0.9959 - precision_class_4: 0.8544 - recall_class_4: 0.8773
# Epoch 700/700
# 169/169 [==============================] - 0s 575us/step - loss: 0.1454 - accuracy: 0.9390 - precision_class_0: 0.9368 - recall_class_0: 0.8019 - precision_class_1: 0.9371 - recall_class_1: 0.9641 - precision_class_2: 0.9908 - recall_class_2: 0.9898 - precision_class_3: 0.9785 - recall_class_3: 0.9979 - precision_class_4: 0.9060 - recall_class_4: 0.8951

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

rcParams['figure.figsize'] = (28, 21)
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False

# Correcting the range of epochs to match the actual number of epochs trained
epochs_trained = len(history.history['loss']) 

# Plot Loss and Accuracy
plt.plot(
    np.arange(1, epochs_trained + 1),
    history.history['loss'], label='Loss'
)
plt.plot(
    np.arange(1, epochs_trained + 1),
    history.history['accuracy'], label='Accuracy'
)

# Plot Precision and Recall for each class
num_classes = 5  # Update this with the actual number of classes you have
for i in range(num_classes):
    precision_label = f'precision_class_{i}'
    recall_label = f'recall_class_{i}'
    
    # Check if precision and recall for each class are in history to avoid KeyError
    if precision_label in history.history:
        plt.plot(
            np.arange(1, epochs_trained + 1),
            history.history[precision_label], label=f'Precision Class {i}'
        )
    if recall_label in history.history:
        plt.plot(
            np.arange(1, epochs_trained + 1),
            history.history[recall_label], label=f'Recall Class {i}'
        )

plt.title('Evaluation metrics', size=20)
plt.xlabel('Epoch', size=14)
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
test_loss, test_accuracy, *test_metrics = model.evaluate(X_test, y_test,verbose=0)
y_pred = model.predict(X_test,verbose=0)

# Assuming the order of metrics is consistent with how we added them:
# test_metrics[0] -> precision_class_0, test_metrics[1] -> recall_class_0, etc.
metrics_per_class = {
    'Loss': test_loss,
    'Accuracy': test_accuracy,
}

num_classes = 5  # Update this with the actual number of classes you have
class_names = label_encoder.inverse_transform(np.unique(y_train_integer))

def compute_confusion_matrix(true, pred):
    classes = np.unique(true)
    conf_mat = [[0] * len(classes) for i in range(len(classes))]
    for i in range(len(true)):
        conf_mat[pred[i]][true[i]]+=1
    print("       Actual")
    print("      _",end="")
    for item in classes:
        print("____",end="")
    print()
    print("pred  |", end=" "),
    for item in classes:
        print("{:^3}".format(item), end=" ")
    print()
    for item in classes:
        print("{:^6}|".format(item), end=" ")
        for item2 in classes:
            print("{:^3}".format(conf_mat[item][item2]), end="|")
        print()
def compute_metrics_per_class(true, pred, test_metrics):
    classes = np.unique(true)
    conf_mat = np.zeros((len(classes), len(classes)), dtype=int)
    for i in range(len(true)):
        conf_mat[pred[i], true[i]] += 1

    num_classes = len(classes)
    max_class_name_length = max(len(name) for name in class_names)
    
    total_precision = 0
    total_recall = 0
    total_accuracy = 0

    for i in range(num_classes):
        precision = float(test_metrics[2 * i])  # Even indices for precision
        recall = float(test_metrics[2 * i + 1])  # Odd indices for recall
        accuracy = float(conf_mat[i, i]) / np.sum(conf_mat[:, i])  # Calculate accuracy for class i
        
        total_precision += precision
        total_recall += recall
        total_accuracy += accuracy

        print(f"{class_names[i]:<{max_class_name_length}} | Precision: {precision:.3f} | Recall: {recall:.3f} | Accuracy: {accuracy:.3f}")

    # Calculate and print the averages
    avg_precision = total_precision / num_classes
    avg_recall = total_recall / num_classes
    avg_accuracy = total_accuracy / num_classes
    print(f"\nAvg Precision: {avg_precision:.3f} | Avg Recall: {avg_recall:.3f} | Avg Accuracy: {avg_accuracy:.3f}")

y_pred_labels = np.argmax(y_pred, axis=1)
y_test_nums = np.argmax(y_test, axis=1)
print_dataset_split(y_train_integer,y_test_integer)
print()
print("=================================================================")

compute_confusion_matrix(y_test_nums.tolist(),y_pred_labels.tolist())
print()
print("=================================================================")
compute_metrics_per_class(y_test_nums.tolist(),y_pred_labels.tolist(),test_metrics)
print("HYPERPARAMS: LR:",LEARNING_RATE," EPOCH:",EPOCH," BATCH:",BATCH_SIZE)
print("<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>")
# Out:
# Class Name  Train  Test
#     Barley    293    73
#       Corn   1060    73
#       Oats    388    73
#    Sorghum    319    73
#      Wheat    644    73
#
# =================================================================
#        Actual
#       _____________________
# pred  |  0   1   2   3   4
#   0   | 55 | 1 | 3 | 3 | 1 |
#   1   |  4 |71 | 0 | 2 | 5 |
#   2   |  1 | 0 |70 | 0 | 0 |
#   3   |  1 | 0 | 0 |68 | 1 |
#   4   | 12 | 1 | 0 | 0 |66 |
#
# =================================================================
# Barley  | Precision: 0.887 | Recall: 0.753 | Accuracy: 0.753
# Corn    | Precision: 0.877 | Recall: 0.973 | Accuracy: 0.973
# Oats    | Precision: 0.986 | Recall: 0.959 | Accuracy: 0.959
# Sorghum | Precision: 0.971 | Recall: 0.932 | Accuracy: 0.932
# Wheat   | Precision: 0.833 | Recall: 0.890 | Accuracy: 0.904
#
# Avg Precision: 0.911 | Avg Recall: 0.901 | Avg Accuracy: 0.904
# HYPERPARAMS: LR: 0.006738550781435328  EPOCH: 700  BATCH: 16
# =================================================================
