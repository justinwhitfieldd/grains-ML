# %%
GRAIN_TYPE = 'Wheat'
# GRAIN_TYPE = 'Oats'
# GRAIN_TYPE = 'Barley'
# GRAIN_TYPE = 'Sorghum'
# GRAIN_TYPE = 'Soybeans'
#GRAIN_TYPE = 'Corn'

# %%
import pandas as pd
#Data visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#url dataset
URL = "../Datasets/processed/" + GRAIN_TYPE + ".csv"

#read in excel format
df = pd.read_csv(URL)
df = df[df['Variety'] == 'SOUTH DAKOTA']

print("From USDA: ", URL)

df.head()
# Out:
# From USDA:  ../Datasets/processed/Wheat.csv
#    Unnamed: 0 Variety  Freq  d(cm)    M%  Density     Attn    Phase  \
# 0           0  KANSAS   7.0    8.9  11.3   0.7356   8.8258  -55.973
# 1           1  KANSAS   8.0    8.9  11.3   0.7356  10.2572 -114.289
# 2           2  KANSAS   9.0    8.9  11.3   0.7356  11.5679 -168.171
# 3           3  KANSAS  10.0    8.9  11.3   0.7356  12.8795  134.849
# 4           4  KANSAS  11.0    8.9  11.3   0.7356  13.7649   83.502
#
#    Phase_Corr  Permittivity_real  Permittivity_imaginary
# 0    -415.973              2.416                   0.243
# 1    -474.289              2.412                   0.246
# 2    -528.171              2.395                   0.246
# 3    -585.151              2.390                   0.246
# 4    -636.498              2.371                   0.238

# %%
# Sample data (replace with your data)
columns = [
    'Freq', 
    'Density', 
    'Attn',
    'Phase', 
    'Phase_Corr', 
    'Permittivity_real', 
    'Permittivity_imaginary',
    'M%', 
]

plotTitles = [
    'Frequency', 
    # 'M%', 
    'Bulk Density', 
    'Attenuation',
    'Phase', 
    'Phase Correlation', 
    'Permittivity (real)', 
    'Permittivity (imaginary)',
    'Moisture Content (%)'
]

colors = [
    '#FFB6C1',
    '#AEC6CF',
    '#98FB98',
    '#FFFF99',
    '#B19CD9',
    '#FFD700',
    '#FFDAB9',
    '#ADD8E6'
]

for i, col in enumerate(columns):
    plt.figure(figsize=(5, 6))
    # Create a violin plot
    ax = sns.violinplot(data=df[col], color=colors[i])

    # Remove x-axis ticks
    ax.set_xticks([])

    # Add labels and title
    plt.tight_layout()

    plt.title(plotTitles[i], fontsize=30)
    plt.tick_params(axis='y', labelsize=20)



    # Show the plot
    plt.savefig('saved_figures/violin-plots/' + GRAIN_TYPE + '_' + col + '.svg', 
                bbox_inches='tight',
                dpi=300, 
                # transparent=True
    )
    plt.show()
